# %% [markdown]
# ## 필요한 라이브러리 설치

# %%
# konlpy 설치
# !pip install konlpy
# Out:
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 34.2 MB/s eta 0:00:00
# Collecting JPype1>=0.7.0 (from konlpy)
#   Downloading JPype1-1.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (488 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 488.6/488.6 kB 39.2 MB/s eta 0:00:00
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from konlpy) (4.9.4)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.10/dist-packages (from konlpy) (1.25.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from JPype1>=0.7.0->konlpy) (24.0)
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-1.5.0 konlpy-0.6.0

# %%
# !git clone https://github.com/SOMJANG/Mecab-ko-for-Google-Colab.git
# Out:
# Cloning into 'Mecab-ko-for-Google-Colab'...
# remote: Enumerating objects: 138, done.
# remote: Counting objects: 100% (47/47), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 138 (delta 26), reused 22 (delta 8), pack-reused 91
# Receiving objects: 100% (138/138), 1.72 MiB | 15.54 MiB/s, done.
# Resolving deltas: 100% (65/65), done.

# %%
cd Mecab-ko-for-Google-Colab
# Out:
# /content/Mecab-ko-for-Google-Colab

# %%
# !bash install_mecab-ko_on_colab_light_220429.sh
# Out:
# Installing konlpy.....
# Requirement already satisfied: konlpy in /usr/local/lib/python3.10/dist-packages (0.6.0)
# Requirement already satisfied: JPype1>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from konlpy) (1.5.0)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from konlpy) (4.9.4)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.10/dist-packages (from konlpy) (1.25.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from JPype1>=0.7.0->konlpy) (24.0)
# Done
# Installing mecab-0.996-ko-0.9.2.tar.gz.....
# Downloading mecab-0.996-ko-0.9.2.tar.gz.......
# from https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# --2024-05-14 05:29:26--  https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# Resolving bitbucket.org (bitbucket.org)... 18.205.93.2, 18.205.93.1, 18.205.93.0, ...
# Connecting to bitbucket.org (bitbucket.org)|18.205.93.2|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://bbuseruploads.s3.amazonaws.com/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz?response-content-disposition=attachment%3B%20filename%3D%22mecab-0.996-ko-0.9.2.tar.gz%22&response-content-encoding=None&AWSAccessKeyId=ASIA6KOSE3BNKDHWFP7W&Signature=Ldmzlupyk3ZMLucTu2A5jvCeLyA%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEB4aCXVzLWVhc3QtMSJGMEQCID7R44qaGOdo62qoSAkPEnPZ5jcPOLnFF1wJomO5pIpIAiAP9tpG7bFoPF5X0KJk4H0qm2IHP3l%2FMgXWxLop0Y9yVCqwAgiH%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F8BEAAaDDk4NDUyNTEwMTE0NiIMssiFkfVjDM5%2F11c1KoQCuSro6hfCEDVh1tU0ZfjqTyEBcBp0f4U%2Bg1nsg2aj83FR30UBPyF3AlgL3%2BsM1yMzBiCGSw8SQt0rbJMt2TDgurXxwpmzTj6G%2FyGBTwF4p%2BNzU492vujDrN3b03jFePxx61k%2FyDzvwLkN%2Bb6Xc8PMebTJsxk6nhcEMW%2B1HrxZ0BzqQe3puwfwokHAPQ2zAzkxElZHsOyybP3WhvkvGj1rarxg4YXFn8VLo3st6GTI%2BCaQRRsw1P8CeTS6HSd0neeuAgd%2F6iSU%2FWPjMqpnYt8hOc6EHSwPPWqjbNkiQDT0NWB3bSG%2BHlLC8jQXvpGUfQ8jc2HkOOxO2iiPFJbXlZ2C3YUf8D4w7eyLsgY6ngG%2BCDU3XRyexr9j3eimtlbiej7rezB6g%2BBgCGQC9TuG1DisW%2F5vHio5X60WmbHkKiODwudancrNQp7LyVqsv3hfknomekmnrKgh3PEUtfuH4qfWRPrg5dueLTc5effZOWnqb69eYMwcA9yaHaYKsl0aS%2FGns02smqeORCQeM9Z0DDjuWR0WL0gaKSrmyiGv7qCD4ELP1MRUsrMli3vBUw%3D%3D&Expires=1715666293 [following]
# --2024-05-14 05:29:27--  https://bbuseruploads.s3.amazonaws.com/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz?response-content-disposition=attachment%3B%20filename%3D%22mecab-0.996-ko-0.9.2.tar.gz%22&response-content-encoding=None&AWSAccessKeyId=ASIA6KOSE3BNKDHWFP7W&Signature=Ldmzlupyk3ZMLucTu2A5jvCeLyA%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEB4aCXVzLWVhc3QtMSJGMEQCID7R44qaGOdo62qoSAkPEnPZ5jcPOLnFF1wJomO5pIpIAiAP9tpG7bFoPF5X0KJk4H0qm2IHP3l%2FMgXWxLop0Y9yVCqwAgiH%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F8BEAAaDDk4NDUyNTEwMTE0NiIMssiFkfVjDM5%2F11c1KoQCuSro6hfCEDVh1tU0ZfjqTyEBcBp0f4U%2Bg1nsg2aj83FR30UBPyF3AlgL3%2BsM1yMzBiCGSw8SQt0rbJMt2TDgurXxwpmzTj6G%2FyGBTwF4p%2BNzU492vujDrN3b03jFePxx61k%2FyDzvwLkN%2Bb6Xc8PMebTJsxk6nhcEMW%2B1HrxZ0BzqQe3puwfwokHAPQ2zAzkxElZHsOyybP3WhvkvGj1rarxg4YXFn8VLo3st6GTI%2BCaQRRsw1P8CeTS6HSd0neeuAgd%2F6iSU%2FWPjMqpnYt8hOc6EHSwPPWqjbNkiQDT0NWB3bSG%2BHlLC8jQXvpGUfQ8jc2HkOOxO2iiPFJbXlZ2C3YUf8D4w7eyLsgY6ngG%2BCDU3XRyexr9j3eimtlbiej7rezB6g%2BBgCGQC9TuG1DisW%2F5vHio5X60WmbHkKiODwudancrNQp7LyVqsv3hfknomekmnrKgh3PEUtfuH4qfWRPrg5dueLTc5effZOWnqb69eYMwcA9yaHaYKsl0aS%2FGns02smqeORCQeM9Z0DDjuWR0WL0gaKSrmyiGv7qCD4ELP1MRUsrMli3vBUw%3D%3D&Expires=1715666293
# Resolving bbuseruploads.s3.amazonaws.com (bbuseruploads.s3.amazonaws.com)... 52.216.53.249, 52.217.43.4, 3.5.21.251, ...
# Connecting to bbuseruploads.s3.amazonaws.com (bbuseruploads.s3.amazonaws.com)|52.216.53.249|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1414979 (1.3M) [application/x-tar]
# Saving to: ‘mecab-0.996-ko-0.9.2.tar.gz’
#
# mecab-0.996-ko-0.9. 100%[===================>]   1.35M  --.-KB/s    in 0.1s
#
# 2024-05-14 05:29:27 (11.2 MB/s) - ‘mecab-0.996-ko-0.9.2.tar.gz’ saved [1414979/1414979]
#
# Done
# Unpacking mecab-0.996-ko-0.9.2.tar.gz.......
# Done
# Change Directory to mecab-0.996-ko-0.9.2.......
# installing mecab-0.996-ko-0.9.2.tar.gz........
# configure
# make
# make check
# make install
# ldconfig
# Done
# Change Directory to /content
# Downloading mecab-ko-dic-2.1.1-20180720.tar.gz.......
# from https://bitbucket.org/eunjeon/mecab-ko-dic/downloads/mecab-ko-dic-2.1.1-20180720.tar.gz
# --2024-05-14 05:31:28--  https://bitbucket.org/eunjeon/mecab-ko-dic/downloads/mecab-ko-dic-2.1.1-20180720.tar.gz
# Resolving bitbucket.org (bitbucket.org)... 18.205.93.1, 18.205.93.2, 18.205.93.0, ...
# Connecting to bitbucket.org (bitbucket.org)|18.205.93.1|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://bbuseruploads.s3.amazonaws.com/a4fcd83e-34f1-454e-a6ac-c242c7d434d3/downloads/b5a0c703-7b64-45ed-a2d7-180e962710b6/mecab-ko-dic-2.1.1-20180720.tar.gz?response-content-disposition=attachment%3B%20filename%3D%22mecab-ko-dic-2.1.1-20180720.tar.gz%22&response-content-encoding=None&AWSAccessKeyId=ASIA6KOSE3BNDD2A2SHT&Signature=FWU0BCQgfd7MSBB%2FO9uZanTUsFg%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEB4aCXVzLWVhc3QtMSJHMEUCIBCUvoW6dGiOTuNaMjnxYn2zGuSXHq6xxjAe61th7MvxAiEA5YdVNW%2FcYHTewpmLZ8vBijLY1dvh%2BVB38hpqo7Tluo8qsAIIh%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FARAAGgw5ODQ1MjUxMDExNDYiDLQgdOsSmcdt4CaraSqEArQ2ipgVfHeV0OX3fJHlAWP7iubbX5abnpd1crNa5B3HAOYkzMFqw5Va8reyVCrMEzGNFjCBsCg19bq7X1Y47PKmcGDj6JFFg9GD3RFqEKOJevnDOUKlHCDP063PMr6Kp%2B34PX0aO0%2F2o9fY0kppmjM8kopAODQqGE59RUjtzatVsq6sNNjXUsq3yxdWcmjKLaUW7iuxKIz0ay%2BSqtxfIVTXcgrD5dDJrio0MSQ54qUjlfsrqzpGE9tEAswvUQDD9eZKVEtFjwOb89SJbJeGt2DijgqLDe%2BUzBXvavtsipcj7vexlTalMgpbFZc%2FPwy0yXuG5v4d5bXISXRYFaHJzcfT93fxMLDui7IGOp0BQ2CGdB2H9S%2Bcd6llrPaUxnZOj4eF7p16Rk6R2iabRYI80tk1zH82kimTCOQOWiyRyCnT%2Bdf4MKZtkDOUjPTaZ7whMjbL0I7N4bkbBPHmhiL5iFM5g8cRfQonq0Hm93XHxMo71KgApxqWB21qdo2pEQeYofr3ZY7XAZZGGHIMdI%2FslqwXb0jegRUjamSAgrvSsaEbsLwyePuqXUz9TA%3D%3D&Expires=1715666488 [following]
# --2024-05-14 05:31:28--  https://bbuseruploads.s3.amazonaws.com/a4fcd83e-34f1-454e-a6ac-c242c7d434d3/downloads/b5a0c703-7b64-45ed-a2d7-180e962710b6/mecab-ko-dic-2.1.1-20180720.tar.gz?response-content-disposition=attachment%3B%20filename%3D%22mecab-ko-dic-2.1.1-20180720.tar.gz%22&response-content-encoding=None&AWSAccessKeyId=ASIA6KOSE3BNDD2A2SHT&Signature=FWU0BCQgfd7MSBB%2FO9uZanTUsFg%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEB4aCXVzLWVhc3QtMSJHMEUCIBCUvoW6dGiOTuNaMjnxYn2zGuSXHq6xxjAe61th7MvxAiEA5YdVNW%2FcYHTewpmLZ8vBijLY1dvh%2BVB38hpqo7Tluo8qsAIIh%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FARAAGgw5ODQ1MjUxMDExNDYiDLQgdOsSmcdt4CaraSqEArQ2ipgVfHeV0OX3fJHlAWP7iubbX5abnpd1crNa5B3HAOYkzMFqw5Va8reyVCrMEzGNFjCBsCg19bq7X1Y47PKmcGDj6JFFg9GD3RFqEKOJevnDOUKlHCDP063PMr6Kp%2B34PX0aO0%2F2o9fY0kppmjM8kopAODQqGE59RUjtzatVsq6sNNjXUsq3yxdWcmjKLaUW7iuxKIz0ay%2BSqtxfIVTXcgrD5dDJrio0MSQ54qUjlfsrqzpGE9tEAswvUQDD9eZKVEtFjwOb89SJbJeGt2DijgqLDe%2BUzBXvavtsipcj7vexlTalMgpbFZc%2FPwy0yXuG5v4d5bXISXRYFaHJzcfT93fxMLDui7IGOp0BQ2CGdB2H9S%2Bcd6llrPaUxnZOj4eF7p16Rk6R2iabRYI80tk1zH82kimTCOQOWiyRyCnT%2Bdf4MKZtkDOUjPTaZ7whMjbL0I7N4bkbBPHmhiL5iFM5g8cRfQonq0Hm93XHxMo71KgApxqWB21qdo2pEQeYofr3ZY7XAZZGGHIMdI%2FslqwXb0jegRUjamSAgrvSsaEbsLwyePuqXUz9TA%3D%3D&Expires=1715666488
# Resolving bbuseruploads.s3.amazonaws.com (bbuseruploads.s3.amazonaws.com)... 54.231.196.113, 3.5.25.156, 16.182.71.185, ...
# Connecting to bbuseruploads.s3.amazonaws.com (bbuseruploads.s3.amazonaws.com)|54.231.196.113|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 49775061 (47M) [application/x-tar]
# Saving to: ‘mecab-ko-dic-2.1.1-20180720.tar.gz’
#
# mecab-ko-dic-2.1.1- 100%[===================>]  47.47M  86.6MB/s    in 0.5s
#
# 2024-05-14 05:31:29 (86.6 MB/s) - ‘mecab-ko-dic-2.1.1-20180720.tar.gz’ saved [49775061/49775061]
#
# Done
# Unpacking  mecab-ko-dic-2.1.1-20180720.tar.gz.......
# Done
# Change Directory to mecab-ko-dic-2.1.1-20180720
# Done
# installing........
# configure
# make
# make install
# bash <(curl -s https://raw.githubusercontent.com/konlpy/konlpy/v0.6.0/scripts/mecab.sh)
# https://github.com/konlpy/konlpy/issues/395#issue-1099168405 - 2022.01.11
# Done
# Install mecab-python
# Successfully Installed
# Now you can use Mecab
# from konlpy.tag import Mecab
# mecab = Mecab()
# 사용자 사전 추가 방법 : https://bit.ly/3k0ZH53
# NameError: name 'Tagger' is not defined 오류 발생 시 런타임을 재실행 해주세요
# 블로그에 해결 방법을 남겨주신 tana님 감사합니다.
# light 버전 작성 : Dogdriip님 ( https://github.com/Dogdriip )
# 문제를 해결해주신 combacsa님 감사합니다.

# %%
# pykospacing설치
# !pip install git+https://github.com/haven-jeon/PyKoSpacing.git
# Out:
# Collecting git+https://github.com/haven-jeon/PyKoSpacing.git
#   Cloning https://github.com/haven-jeon/PyKoSpacing.git to /tmp/pip-req-build-n1nngaxa
#   Running command git clone --filter=blob:none --quiet https://github.com/haven-jeon/PyKoSpacing.git /tmp/pip-req-build-n1nngaxa
#   Resolved https://github.com/haven-jeon/PyKoSpacing.git to commit 103ff614a2edf6df87d289ccaf99822b9afa9a42
#   Preparing metadata (setup.py) ... done
# Collecting tensorflow==2.15.1 (from pykospacing==0.5)
#   Downloading tensorflow-2.15.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (475.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 475.2/475.2 MB 2.0 MB/s eta 0:00:00
# Collecting h5py==3.10.0 (from pykospacing==0.5)
#   Downloading h5py-3.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 69.5 MB/s eta 0:00:00
# Collecting argparse>=1.4.0 (from pykospacing==0.5)
#   Downloading argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from h5py==3.10.0->pykospacing==0.5) (1.25.2)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.1->pykospacing==0.5) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.1->pykospacing==0.5) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.1->pykospacing==0.5) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.1->pykospacing==0.5) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.1->pykospacing==0.5) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.1->pykospacing==0.5) (18.1.1)
# Collecting ml-dtypes~=0.3.1 (from tensorflow==2.15.1->pykospacing==0.5)
#   Downloading ml_dtypes-0.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 69.3 MB/s eta 0:00:00
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.1->pykospacing==0.5) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.1->pykospacing==0.5) (24.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.1->pykospacing==0.5) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.1->pykospacing==0.5) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.1->pykospacing==0.5) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.1->pykospacing==0.5) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.1->pykospacing==0.5) (4.11.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.1->pykospacing==0.5) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.1->pykospacing==0.5) (0.37.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.1->pykospacing==0.5) (1.63.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.1->pykospacing==0.5) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.1->pykospacing==0.5) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.1->pykospacing==0.5) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow==2.15.1->pykospacing==0.5) (0.43.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.1->pykospacing==0.5) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.1->pykospacing==0.5) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.1->pykospacing==0.5) (3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.1->pykospacing==0.5) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.1->pykospacing==0.5) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.1->pykospacing==0.5) (3.0.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.1->pykospacing==0.5) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.1->pykospacing==0.5) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.1->pykospacing==0.5) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow==2.15.1->pykospacing==0.5) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.1->pykospacing==0.5) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.1->pykospacing==0.5) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.1->pykospacing==0.5) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.1->pykospacing==0.5) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow==2.15.1->pykospacing==0.5) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.1->pykospacing==0.5) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow==2.15.1->pykospacing==0.5) (3.2.2)
# Building wheels for collected packages: pykospacing
#   Building wheel for pykospacing (setup.py) ... done
#   Created wheel for pykospacing: filename=pykospacing-0.5-py3-none-any.whl size=2270666 sha256=9d1b33cb7fcf1107e8f2dc9607e86e19bfc59a446f1a068688a2f0e4dd4c639c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-jjuv1a7z/wheels/76/b3/33/dda14886ee76b8e53eb05580a14dfcf9145e9eb9d282c53f28
# Successfully built pykospacing
# Installing collected packages: argparse, ml-dtypes, h5py, tensorflow, pykospacing
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.2.0
#     Uninstalling ml-dtypes-0.2.0:
#       Successfully uninstalled ml-dtypes-0.2.0
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.9.0
#     Uninstalling h5py-3.9.0:
#       Successfully uninstalled h5py-3.9.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.15.0
#     Uninstalling tensorflow-2.15.0:
#       Successfully uninstalled tensorflow-2.15.0
# Successfully installed argparse-1.4.0 h5py-3.10.0 ml-dtypes-0.3.2 pykospacing-0.5 tensorflow-2.15.1

# %%
# konlpy, Mecab 형태소 분석기 설치 스크립트 실행
# !curl -s https://raw.githubusercontent.com/teddylee777/machine-learning/master/99-Misc/01-Colab/mecab-colab.sh | bash
# Out:
# --2024-05-14 05:14:39--  https://www.dropbox.com/s/9xls0tgtf3edgns/mecab-0.996-ko-0.9.2.tar.gz?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.8.18, 2620:100:6018:18::a27d:312
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.8.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/dl/9xls0tgtf3edgns/mecab-0.996-ko-0.9.2.tar.gz [following]
# --2024-05-14 05:14:39--  https://www.dropbox.com/s/dl/9xls0tgtf3edgns/mecab-0.996-ko-0.9.2.tar.gz
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc751c14945f63981b0f7844f766.dl.dropboxusercontent.com/cd/0/get/CS3hyBWfIxlTWh0MEw9Wr3USczsaq6WERwFAJa2uXFnecDurESJz6_UYzTMsB1t9aOZDoUg9u-v76aYdoDHE6UMOZiGrgLzbgTczl0cY113duj-RHrrikXvAlz-c-GOS-I_O83W62ahBaz3zWA6d1c7q/file?dl=1# [following]
# --2024-05-14 05:14:40--  https://uc751c14945f63981b0f7844f766.dl.dropboxusercontent.com/cd/0/get/CS3hyBWfIxlTWh0MEw9Wr3USczsaq6WERwFAJa2uXFnecDurESJz6_UYzTMsB1t9aOZDoUg9u-v76aYdoDHE6UMOZiGrgLzbgTczl0cY113duj-RHrrikXvAlz-c-GOS-I_O83W62ahBaz3zWA6d1c7q/file?dl=1
# Resolving uc751c14945f63981b0f7844f766.dl.dropboxusercontent.com (uc751c14945f63981b0f7844f766.dl.dropboxusercontent.com)... 162.125.65.15, 2620:100:6018:15::a27d:30f
# Connecting to uc751c14945f63981b0f7844f766.dl.dropboxusercontent.com (uc751c14945f63981b0f7844f766.dl.dropboxusercontent.com)|162.125.65.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1414979 (1.3M) [application/binary]
# Saving to: ‘mecab-0.996-ko-0.9.2.tar.gz?dl=1’
#
# mecab-0.996-ko-0.9. 100%[===================>]   1.35M  1.90MB/s    in 0.7s
#
# 2024-05-14 05:14:41 (1.90 MB/s) - ‘mecab-0.996-ko-0.9.2.tar.gz?dl=1’ saved [1414979/1414979]
#
# mecab-0.996-ko-0.9.2/
# mecab-0.996-ko-0.9.2/example/
# mecab-0.996-ko-0.9.2/example/example.cpp
# mecab-0.996-ko-0.9.2/example/example_lattice.cpp
# mecab-0.996-ko-0.9.2/example/example_lattice.c
# mecab-0.996-ko-0.9.2/example/example.c
# mecab-0.996-ko-0.9.2/example/thread_test.cpp
# mecab-0.996-ko-0.9.2/mecab-config.in
# mecab-0.996-ko-0.9.2/man/
# mecab-0.996-ko-0.9.2/man/Makefile.am
# mecab-0.996-ko-0.9.2/man/mecab.1
# mecab-0.996-ko-0.9.2/man/Makefile.in
# mecab-0.996-ko-0.9.2/mecab.iss.in
# mecab-0.996-ko-0.9.2/config.guess
# mecab-0.996-ko-0.9.2/README
# mecab-0.996-ko-0.9.2/COPYING
# mecab-0.996-ko-0.9.2/CHANGES.md
# mecab-0.996-ko-0.9.2/README.md
# mecab-0.996-ko-0.9.2/INSTALL
# mecab-0.996-ko-0.9.2/config.sub
# mecab-0.996-ko-0.9.2/configure.in
# mecab-0.996-ko-0.9.2/swig/
# mecab-0.996-ko-0.9.2/swig/Makefile
# mecab-0.996-ko-0.9.2/swig/version.h.in
# mecab-0.996-ko-0.9.2/swig/version.h
# mecab-0.996-ko-0.9.2/swig/MeCab.i
# mecab-0.996-ko-0.9.2/aclocal.m4
# mecab-0.996-ko-0.9.2/LGPL
# mecab-0.996-ko-0.9.2/Makefile.am
# mecab-0.996-ko-0.9.2/configure
# mecab-0.996-ko-0.9.2/tests/
# mecab-0.996-ko-0.9.2/tests/autolink/
# mecab-0.996-ko-0.9.2/tests/autolink/unk.def
# mecab-0.996-ko-0.9.2/tests/autolink/dicrc
# mecab-0.996-ko-0.9.2/tests/autolink/dic.csv
# mecab-0.996-ko-0.9.2/tests/autolink/test
# mecab-0.996-ko-0.9.2/tests/autolink/char.def
# mecab-0.996-ko-0.9.2/tests/autolink/matrix.def
# mecab-0.996-ko-0.9.2/tests/autolink/test.gld
# mecab-0.996-ko-0.9.2/tests/t9/
# mecab-0.996-ko-0.9.2/tests/t9/unk.def
# mecab-0.996-ko-0.9.2/tests/t9/ipadic.pl
# mecab-0.996-ko-0.9.2/tests/t9/dicrc
# mecab-0.996-ko-0.9.2/tests/t9/dic.csv
# mecab-0.996-ko-0.9.2/tests/t9/test
# mecab-0.996-ko-0.9.2/tests/t9/char.def
# mecab-0.996-ko-0.9.2/tests/t9/matrix.def
# mecab-0.996-ko-0.9.2/tests/t9/mkdic.pl
# mecab-0.996-ko-0.9.2/tests/t9/test.gld
# mecab-0.996-ko-0.9.2/tests/cost-train/
# mecab-0.996-ko-0.9.2/tests/cost-train/ipa.train
# mecab-0.996-ko-0.9.2/tests/cost-train/ipa.test
# mecab-0.996-ko-0.9.2/tests/cost-train/seed/
# mecab-0.996-ko-0.9.2/tests/cost-train/seed/rewrite.def
# mecab-0.996-ko-0.9.2/tests/cost-train/seed/feature.def
# mecab-0.996-ko-0.9.2/tests/cost-train/seed/unk.def
# mecab-0.996-ko-0.9.2/tests/cost-train/seed/dicrc
# mecab-0.996-ko-0.9.2/tests/cost-train/seed/dic.csv
# mecab-0.996-ko-0.9.2/tests/cost-train/seed/char.def
# mecab-0.996-ko-0.9.2/tests/cost-train/seed/matrix.def
# mecab-0.996-ko-0.9.2/tests/run-eval.sh
# mecab-0.996-ko-0.9.2/tests/run-cost-train.sh
# mecab-0.996-ko-0.9.2/tests/Makefile.am
# mecab-0.996-ko-0.9.2/tests/katakana/
# mecab-0.996-ko-0.9.2/tests/katakana/unk.def
# mecab-0.996-ko-0.9.2/tests/katakana/dicrc
# mecab-0.996-ko-0.9.2/tests/katakana/dic.csv
# mecab-0.996-ko-0.9.2/tests/katakana/test
# mecab-0.996-ko-0.9.2/tests/katakana/char.def
# mecab-0.996-ko-0.9.2/tests/katakana/matrix.def
# mecab-0.996-ko-0.9.2/tests/katakana/test.gld
# mecab-0.996-ko-0.9.2/tests/eval/
# mecab-0.996-ko-0.9.2/tests/eval/answer
# mecab-0.996-ko-0.9.2/tests/eval/system
# mecab-0.996-ko-0.9.2/tests/eval/test.gld
# mecab-0.996-ko-0.9.2/tests/shiin/
# mecab-0.996-ko-0.9.2/tests/shiin/unk.def
# mecab-0.996-ko-0.9.2/tests/shiin/dicrc
# mecab-0.996-ko-0.9.2/tests/shiin/dic.csv
# mecab-0.996-ko-0.9.2/tests/shiin/test
# mecab-0.996-ko-0.9.2/tests/shiin/char.def
# mecab-0.996-ko-0.9.2/tests/shiin/matrix.def
# mecab-0.996-ko-0.9.2/tests/shiin/mkdic.pl
# mecab-0.996-ko-0.9.2/tests/shiin/test.gld
# mecab-0.996-ko-0.9.2/tests/latin/
# mecab-0.996-ko-0.9.2/tests/latin/unk.def
# mecab-0.996-ko-0.9.2/tests/latin/dicrc
# mecab-0.996-ko-0.9.2/tests/latin/dic.csv
# mecab-0.996-ko-0.9.2/tests/latin/test
# mecab-0.996-ko-0.9.2/tests/latin/char.def
# mecab-0.996-ko-0.9.2/tests/latin/matrix.def
# mecab-0.996-ko-0.9.2/tests/latin/test.gld
# mecab-0.996-ko-0.9.2/tests/chartype/
# mecab-0.996-ko-0.9.2/tests/chartype/unk.def
# mecab-0.996-ko-0.9.2/tests/chartype/dicrc
# mecab-0.996-ko-0.9.2/tests/chartype/dic.csv
# mecab-0.996-ko-0.9.2/tests/chartype/test
# mecab-0.996-ko-0.9.2/tests/chartype/char.def
# mecab-0.996-ko-0.9.2/tests/chartype/matrix.def
# mecab-0.996-ko-0.9.2/tests/chartype/test.gld
# mecab-0.996-ko-0.9.2/tests/run-dics.sh
# mecab-0.996-ko-0.9.2/tests/ngram/
# mecab-0.996-ko-0.9.2/tests/ngram/unk.def
# mecab-0.996-ko-0.9.2/tests/ngram/dicrc
# mecab-0.996-ko-0.9.2/tests/ngram/dic.csv
# mecab-0.996-ko-0.9.2/tests/ngram/test
# mecab-0.996-ko-0.9.2/tests/ngram/char.def
# mecab-0.996-ko-0.9.2/tests/ngram/matrix.def
# mecab-0.996-ko-0.9.2/tests/ngram/test.gld
# mecab-0.996-ko-0.9.2/tests/Makefile.in
# mecab-0.996-ko-0.9.2/ltmain.sh
# mecab-0.996-ko-0.9.2/config.rpath
# mecab-0.996-ko-0.9.2/config.h.in
# mecab-0.996-ko-0.9.2/mecabrc.in
# mecab-0.996-ko-0.9.2/GPL
# mecab-0.996-ko-0.9.2/Makefile.train
# mecab-0.996-ko-0.9.2/ChangeLog
# mecab-0.996-ko-0.9.2/install-sh
# mecab-0.996-ko-0.9.2/AUTHORS
# mecab-0.996-ko-0.9.2/doc/
# mecab-0.996-ko-0.9.2/doc/bindings.html
# mecab-0.996-ko-0.9.2/doc/posid.html
# mecab-0.996-ko-0.9.2/doc/unk.html
# mecab-0.996-ko-0.9.2/doc/learn.html
# mecab-0.996-ko-0.9.2/doc/format.html
# mecab-0.996-ko-0.9.2/doc/libmecab.html
# mecab-0.996-ko-0.9.2/doc/mecab.css
# mecab-0.996-ko-0.9.2/doc/feature.html
# mecab-0.996-ko-0.9.2/doc/Makefile.am
# mecab-0.996-ko-0.9.2/doc/soft.html
# mecab-0.996-ko-0.9.2/doc/en/
# mecab-0.996-ko-0.9.2/doc/en/bindings.html
# mecab-0.996-ko-0.9.2/doc/dic-detail.html
# mecab-0.996-ko-0.9.2/doc/flow.png
# mecab-0.996-ko-0.9.2/doc/mecab.html
# mecab-0.996-ko-0.9.2/doc/index.html
# mecab-0.996-ko-0.9.2/doc/result.png
# mecab-0.996-ko-0.9.2/doc/doxygen/
# mecab-0.996-ko-0.9.2/doc/doxygen/tab_a.png
# mecab-0.996-ko-0.9.2/doc/doxygen/globals_eval.html
# mecab-0.996-ko-0.9.2/doc/doxygen/classMeCab_1_1Tagger-members.html
# mecab-0.996-ko-0.9.2/doc/doxygen/functions_vars.html
# mecab-0.996-ko-0.9.2/doc/doxygen/doxygen.css
# mecab-0.996-ko-0.9.2/doc/doxygen/tab_r.gif
# mecab-0.996-ko-0.9.2/doc/doxygen/classMeCab_1_1Lattice.html
# mecab-0.996-ko-0.9.2/doc/doxygen/functions.html
# mecab-0.996-ko-0.9.2/doc/doxygen/classMeCab_1_1Tagger.html
# mecab-0.996-ko-0.9.2/doc/doxygen/mecab_8h_source.html
# mecab-0.996-ko-0.9.2/doc/doxygen/tabs.css
# mecab-0.996-ko-0.9.2/doc/doxygen/nav_f.png
# mecab-0.996-ko-0.9.2/doc/doxygen/tab_b.png
# mecab-0.996-ko-0.9.2/doc/doxygen/globals.html
# mecab-0.996-ko-0.9.2/doc/doxygen/nav_h.png
# mecab-0.996-ko-0.9.2/doc/doxygen/tab_h.png
# mecab-0.996-ko-0.9.2/doc/doxygen/classMeCab_1_1Model.html
# mecab-0.996-ko-0.9.2/doc/doxygen/globals_func.html
# mecab-0.996-ko-0.9.2/doc/doxygen/closed.png
# mecab-0.996-ko-0.9.2/doc/doxygen/tab_l.gif
# mecab-0.996-ko-0.9.2/doc/doxygen/structmecab__path__t-members.html
# mecab-0.996-ko-0.9.2/doc/doxygen/functions_func.html
# mecab-0.996-ko-0.9.2/doc/doxygen/globals_type.html
# mecab-0.996-ko-0.9.2/doc/doxygen/classMeCab_1_1Lattice-members.html
# mecab-0.996-ko-0.9.2/doc/doxygen/structmecab__node__t.html
# mecab-0.996-ko-0.9.2/doc/doxygen/namespacemembers_func.html
# mecab-0.996-ko-0.9.2/doc/doxygen/tab_s.png
# mecab-0.996-ko-0.9.2/doc/doxygen/structmecab__dictionary__info__t-members.html
# mecab-0.996-ko-0.9.2/doc/doxygen/namespacemembers_type.html
# mecab-0.996-ko-0.9.2/doc/doxygen/classMeCab_1_1Model-members.html
# mecab-0.996-ko-0.9.2/doc/doxygen/structmecab__dictionary__info__t.html
# mecab-0.996-ko-0.9.2/doc/doxygen/namespaces.html
# mecab-0.996-ko-0.9.2/doc/doxygen/namespacemembers.html
# mecab-0.996-ko-0.9.2/doc/doxygen/namespaceMeCab.html
# mecab-0.996-ko-0.9.2/doc/doxygen/structmecab__path__t.html
# mecab-0.996-ko-0.9.2/doc/doxygen/files.html
# mecab-0.996-ko-0.9.2/doc/doxygen/structmecab__node__t-members.html
# mecab-0.996-ko-0.9.2/doc/doxygen/index.html
# mecab-0.996-ko-0.9.2/doc/doxygen/annotated.html
# mecab-0.996-ko-0.9.2/doc/doxygen/globals_defs.html
# mecab-0.996-ko-0.9.2/doc/doxygen/classes.html
# mecab-0.996-ko-0.9.2/doc/doxygen/mecab_8h-source.html
# mecab-0.996-ko-0.9.2/doc/doxygen/doxygen.png
# mecab-0.996-ko-0.9.2/doc/doxygen/tab_b.gif
# mecab-0.996-ko-0.9.2/doc/doxygen/bc_s.png
# mecab-0.996-ko-0.9.2/doc/doxygen/open.png
# mecab-0.996-ko-0.9.2/doc/doxygen/mecab_8h.html
# mecab-0.996-ko-0.9.2/doc/dic.html
# mecab-0.996-ko-0.9.2/doc/partial.html
# mecab-0.996-ko-0.9.2/doc/feature.png
# mecab-0.996-ko-0.9.2/doc/Makefile.in
# mecab-0.996-ko-0.9.2/missing
# mecab-0.996-ko-0.9.2/BSD
# mecab-0.996-ko-0.9.2/NEWS
# mecab-0.996-ko-0.9.2/mkinstalldirs
# mecab-0.996-ko-0.9.2/src/
# mecab-0.996-ko-0.9.2/src/dictionary.h
# mecab-0.996-ko-0.9.2/src/writer.h
# mecab-0.996-ko-0.9.2/src/utils.h
# mecab-0.996-ko-0.9.2/src/string_buffer.cpp
# mecab-0.996-ko-0.9.2/src/tokenizer.cpp
# mecab-0.996-ko-0.9.2/src/make.bat
# mecab-0.996-ko-0.9.2/src/mecab.h
# mecab-0.996-ko-0.9.2/src/freelist.h
# mecab-0.996-ko-0.9.2/src/string_buffer.h
# mecab-0.996-ko-0.9.2/src/learner_tagger.h
# mecab-0.996-ko-0.9.2/src/dictionary_compiler.cpp
# mecab-0.996-ko-0.9.2/src/eval.cpp
# mecab-0.996-ko-0.9.2/src/mecab-system-eval.cpp
# mecab-0.996-ko-0.9.2/src/darts.h
# mecab-0.996-ko-0.9.2/src/param.h
# mecab-0.996-ko-0.9.2/src/char_property.h
# mecab-0.996-ko-0.9.2/src/learner_node.h
# mecab-0.996-ko-0.9.2/src/mecab-dict-gen.cpp
# mecab-0.996-ko-0.9.2/src/mecab-dict-index.cpp
# mecab-0.996-ko-0.9.2/src/winmain.h
# mecab-0.996-ko-0.9.2/src/thread.h
# mecab-0.996-ko-0.9.2/src/context_id.cpp
# mecab-0.996-ko-0.9.2/src/Makefile.am
# mecab-0.996-ko-0.9.2/src/connector.h
# mecab-0.996-ko-0.9.2/src/common.h
# mecab-0.996-ko-0.9.2/src/dictionary_rewriter.cpp
# mecab-0.996-ko-0.9.2/src/Makefile.msvc.in
# mecab-0.996-ko-0.9.2/src/dictionary_rewriter.h
# mecab-0.996-ko-0.9.2/src/feature_index.h
# mecab-0.996-ko-0.9.2/src/iconv_utils.cpp
# mecab-0.996-ko-0.9.2/src/char_property.cpp
# mecab-0.996-ko-0.9.2/src/mecab-test-gen.cpp
# mecab-0.996-ko-0.9.2/src/tagger.cpp
# mecab-0.996-ko-0.9.2/src/mecab-cost-train.cpp
# mecab-0.996-ko-0.9.2/src/learner.cpp
# mecab-0.996-ko-0.9.2/src/dictionary.cpp
# mecab-0.996-ko-0.9.2/src/lbfgs.cpp
# mecab-0.996-ko-0.9.2/src/ucs.h
# mecab-0.996-ko-0.9.2/src/writer.cpp
# mecab-0.996-ko-0.9.2/src/learner_tagger.cpp
# mecab-0.996-ko-0.9.2/src/lbfgs.h
# mecab-0.996-ko-0.9.2/src/libmecab.cpp
# mecab-0.996-ko-0.9.2/src/tokenizer.h
# mecab-0.996-ko-0.9.2/src/mecab.cpp
# mecab-0.996-ko-0.9.2/src/utils.cpp
# mecab-0.996-ko-0.9.2/src/dictionary_generator.cpp
# mecab-0.996-ko-0.9.2/src/param.cpp
# mecab-0.996-ko-0.9.2/src/context_id.h
# mecab-0.996-ko-0.9.2/src/mmap.h
# mecab-0.996-ko-0.9.2/src/viterbi.h
# mecab-0.996-ko-0.9.2/src/viterbi.cpp
# mecab-0.996-ko-0.9.2/src/stream_wrapper.h
# mecab-0.996-ko-0.9.2/src/feature_index.cpp
# mecab-0.996-ko-0.9.2/src/nbest_generator.h
# mecab-0.996-ko-0.9.2/src/ucstable.h
# mecab-0.996-ko-0.9.2/src/nbest_generator.cpp
# mecab-0.996-ko-0.9.2/src/iconv_utils.h
# mecab-0.996-ko-0.9.2/src/connector.cpp
# mecab-0.996-ko-0.9.2/src/Makefile.in
# mecab-0.996-ko-0.9.2/src/scoped_ptr.h
# mecab-0.996-ko-0.9.2/Makefile.in
# checking for a BSD-compatible install... /usr/bin/install -c
# checking whether build environment is sane... yes
# checking for a thread-safe mkdir -p... /usr/bin/mkdir -p
# checking for gawk... no
# checking for mawk... mawk
# checking whether make sets $(MAKE)... yes
# checking for gcc... gcc
# checking whether the C compiler works... yes
# checking for C compiler default output file name... a.out
# checking for suffix of executables...
# checking whether we are cross compiling... no
# checking for suffix of object files... o
# checking whether we are using the GNU C compiler... yes
# checking whether gcc accepts -g... yes
# checking for gcc option to accept ISO C89... none needed
# checking for style of include used by make... GNU
# checking dependency style of gcc... none
# checking for g++... g++
# checking whether we are using the GNU C++ compiler... yes
# checking whether g++ accepts -g... yes
# checking dependency style of g++... none
# checking how to run the C preprocessor... gcc -E
# checking for grep that handles long lines and -e... /usr/bin/grep
# checking for egrep... /usr/bin/grep -E
# checking whether gcc needs -traditional... no
# checking whether make sets $(MAKE)... (cached) yes
# checking build system type... x86_64-unknown-linux-gnu
# checking host system type... x86_64-unknown-linux-gnu
# checking how to print strings... printf
# checking for a sed that does not truncate output... /usr/bin/sed
# checking for fgrep... /usr/bin/grep -F
# checking for ld used by gcc... /usr/bin/ld
# checking if the linker (/usr/bin/ld) is GNU ld... yes
# checking for BSD- or MS-compatible name lister (nm)... /usr/bin/nm -B
# checking the name lister (/usr/bin/nm -B) interface... BSD nm
# checking whether ln -s works... yes
# checking the maximum length of command line arguments... 1572864
# checking whether the shell understands some XSI constructs... yes
# checking whether the shell understands "+="... yes
# checking how to convert x86_64-unknown-linux-gnu file names to x86_64-unknown-linux-gnu format... func_convert_file_noop
# checking how to convert x86_64-unknown-linux-gnu file names to toolchain format... func_convert_file_noop
# checking for /usr/bin/ld option to reload object files... -r
# checking for objdump... objdump
# checking how to recognize dependent libraries... pass_all
# checking for dlltool... dlltool
# checking how to associate runtime and link libraries... printf %s\n
# checking for ar... ar
# checking for archiver @FILE support... @
# checking for strip... strip
# checking for ranlib... ranlib
# checking command to parse /usr/bin/nm -B output from gcc object... ok
# checking for sysroot... no
# checking for mt... no
# checking if : is a manifest tool... no
# checking for ANSI C header files... yes
# checking for sys/types.h... yes
# checking for sys/stat.h... yes
# checking for stdlib.h... yes
# checking for string.h... yes
# checking for memory.h... yes
# checking for strings.h... yes
# checking for inttypes.h... yes
# checking for stdint.h... yes
# checking for unistd.h... yes
# checking for dlfcn.h... yes
# checking for objdir... .libs
# checking if gcc supports -fno-rtti -fno-exceptions... no
# checking for gcc option to produce PIC... -fPIC -DPIC
# checking if gcc PIC flag -fPIC -DPIC works... yes
# checking if gcc static flag -static works... yes
# checking if gcc supports -c -o file.o... yes
# checking if gcc supports -c -o file.o... (cached) yes
# checking whether the gcc linker (/usr/bin/ld -m elf_x86_64) supports shared libraries... yes
# checking whether -lc should be explicitly linked in... no
# checking dynamic linker characteristics... GNU/Linux ld.so
# checking how to hardcode library paths into programs... immediate
# checking whether stripping libraries is possible... yes
# checking if libtool supports shared libraries... yes
# checking whether to build shared libraries... yes
# checking whether to build static libraries... yes
# checking how to run the C++ preprocessor... g++ -E
# checking for ld used by g++... /usr/bin/ld -m elf_x86_64
# checking if the linker (/usr/bin/ld -m elf_x86_64) is GNU ld... yes
# checking whether the g++ linker (/usr/bin/ld -m elf_x86_64) supports shared libraries... yes
# checking for g++ option to produce PIC... -fPIC -DPIC
# checking if g++ PIC flag -fPIC -DPIC works... yes
# checking if g++ static flag -static works... yes
# checking if g++ supports -c -o file.o... yes
# checking if g++ supports -c -o file.o... (cached) yes
# checking whether the g++ linker (/usr/bin/ld -m elf_x86_64) supports shared libraries... yes
# checking dynamic linker characteristics... (cached) GNU/Linux ld.so
# checking how to hardcode library paths into programs... immediate
# checking for library containing strerror... none required
# checking whether byte ordering is bigendian... no
# checking for ld used by GCC... /usr/bin/ld -m elf_x86_64
# checking if the linker (/usr/bin/ld -m elf_x86_64) is GNU ld... yes
# checking for shared library run path origin... done
# checking for iconv... yes
# checking for working iconv... yes
# checking for iconv declaration...
#          extern size_t iconv (iconv_t cd, char * *inbuf, size_t *inbytesleft, char * *outbuf, size_t *outbytesleft);
# checking for ANSI C header files... (cached) yes
# checking for an ANSI C-conforming const... yes
# checking whether byte ordering is bigendian... (cached) no
# checking for string.h... (cached) yes
# checking for stdlib.h... (cached) yes
# checking for unistd.h... (cached) yes
# checking fcntl.h usability... yes
# checking fcntl.h presence... yes
# checking for fcntl.h... yes
# checking for stdint.h... (cached) yes
# checking for sys/stat.h... (cached) yes
# checking sys/mman.h usability... yes
# checking sys/mman.h presence... yes
# checking for sys/mman.h... yes
# checking sys/times.h usability... yes
# checking sys/times.h presence... yes
# checking for sys/times.h... yes
# checking for sys/types.h... (cached) yes
# checking dirent.h usability... yes
# checking dirent.h presence... yes
# checking for dirent.h... yes
# checking ctype.h usability... yes
# checking ctype.h presence... yes
# checking for ctype.h... yes
# checking for sys/types.h... (cached) yes
# checking io.h usability... no
# checking io.h presence... no
# checking for io.h... no
# checking windows.h usability... no
# checking windows.h presence... no
# checking for windows.h... no
# checking pthread.h usability... yes
# checking pthread.h presence... yes
# checking for pthread.h... yes
# checking for off_t... yes
# checking for size_t... yes
# checking size of char... 1
# checking size of short... 2
# checking size of int... 4
# checking size of long... 8
# checking size of long long... 8
# checking size of size_t... 8
# checking for size_t... (cached) yes
# checking for unsigned long long int... yes
# checking for stdlib.h... (cached) yes
# checking for unistd.h... (cached) yes
# checking for sys/param.h... yes
# checking for getpagesize... yes
# checking for working mmap... yes
# checking for main in -lstdc++... yes
# checking for pthread_create in -lpthread... yes
# checking for pthread_join in -lpthread... yes
# checking for getenv... yes
# checking for opendir... yes
# checking whether make is GNU Make... yes
# checking if g++ supports stl <vector> (required)... yes
# checking if g++ supports stl <list> (required)... yes
# checking if g++ supports stl <map> (required)... yes
# checking if g++ supports stl <set> (required)... yes
# checking if g++ supports stl <queue> (required)... yes
# checking if g++ supports stl <functional> (required)... yes
# checking if g++ supports stl <algorithm> (required)... yes
# checking if g++ supports stl <string> (required)... yes
# checking if g++ supports stl <iostream> (required)... yes
# checking if g++ supports stl <sstream> (required)... yes
# checking if g++ supports stl <fstream> (required)... yes
# checking if g++ supports template <class T> (required)... yes
# checking if g++ supports const_cast<> (required)... yes
# checking if g++ supports static_cast<> (required)... yes
# checking if g++ supports reinterpret_cast<> (required)... yes
# checking if g++ supports namespaces (required) ... yes
# checking if g++ supports __thread (optional)... yes
# checking if g++ supports template <class T> (required)... yes
# checking if g++ supports GCC native atomic operations (optional)... yes
# checking if g++ supports OSX native atomic operations (optional)... no
# checking if g++ environment provides all required features... yes
# configure: creating ./config.status
# config.status: creating Makefile
# config.status: creating src/Makefile
# config.status: creating src/Makefile.msvc
# config.status: creating man/Makefile
# config.status: creating doc/Makefile
# config.status: creating tests/Makefile
# config.status: creating swig/version.h
# config.status: creating mecab.iss
# config.status: creating mecab-config
# config.status: creating mecabrc
# config.status: creating config.h
# config.status: config.h is unchanged
# config.status: executing depfiles commands
# config.status: executing libtool commands
# config.status: executing default commands
# make  all-recursive
# make[1]: Entering directory '/tmp/mecab-0.996-ko-0.9.2'
# Making all in src
# make[2]: Entering directory '/tmp/mecab-0.996-ko-0.9.2/src'
# make[2]: Nothing to be done for 'all'.
# make[2]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2/src'
# Making all in man
# make[2]: Entering directory '/tmp/mecab-0.996-ko-0.9.2/man'
# make[2]: Nothing to be done for 'all'.
# make[2]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2/man'
# Making all in doc
# make[2]: Entering directory '/tmp/mecab-0.996-ko-0.9.2/doc'
# make[2]: Nothing to be done for 'all'.
# make[2]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2/doc'
# Making all in tests
# make[2]: Entering directory '/tmp/mecab-0.996-ko-0.9.2/tests'
# make[2]: Nothing to be done for 'all'.
# make[2]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2/tests'
# make[2]: Entering directory '/tmp/mecab-0.996-ko-0.9.2'
# make[2]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2'
# make[1]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2'
# Making check in src
# make[1]: Entering directory '/tmp/mecab-0.996-ko-0.9.2/src'
# make[1]: Nothing to be done for 'check'.
# make[1]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2/src'
# Making check in man
# make[1]: Entering directory '/tmp/mecab-0.996-ko-0.9.2/man'
# make[1]: Nothing to be done for 'check'.
# make[1]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2/man'
# Making check in doc
# make[1]: Entering directory '/tmp/mecab-0.996-ko-0.9.2/doc'
# make[1]: Nothing to be done for 'check'.
# make[1]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2/doc'
# Making check in tests
# make[1]: Entering directory '/tmp/mecab-0.996-ko-0.9.2/tests'
# make  check-TESTS
# make[2]: Entering directory '/tmp/mecab-0.996-ko-0.9.2/tests'
# ./pos-id.def is not found. minimum setting is used
# reading ./unk.def ... 2
# emitting double-array: 100% |###########################################|
# ./model.def is not found. skipped.
# ./pos-id.def is not found. minimum setting is used
# reading ./dic.csv ... 177
# emitting double-array: 100% |###########################################|
# reading ./matrix.def ... 178x178
# emitting matrix      : 100% |###########################################|
#
# done!
# ./pos-id.def is not found. minimum setting is used
# reading ./unk.def ... 2
# emitting double-array: 100% |###########################################|
# ./model.def is not found. skipped.
# ./pos-id.def is not found. minimum setting is used
# reading ./dic.csv ... 83
# emitting double-array: 100% |###########################################|
# reading ./matrix.def ... 84x84
# emitting matrix      : 100% |###########################################|
#
# done!
# ./pos-id.def is not found. minimum setting is used
# reading ./unk.def ... 2
# emitting double-array: 100% |###########################################|
# ./model.def is not found. skipped.
# ./pos-id.def is not found. minimum setting is used
# reading ./dic.csv ... 450
# emitting double-array: 100% |###########################################|
# reading ./matrix.def ... 1x1
#
# done!
# ./pos-id.def is not found. minimum setting is used
# reading ./unk.def ... 2
# emitting double-array: 100% |###########################################|
# ./model.def is not found. skipped.
# ./pos-id.def is not found. minimum setting is used
# reading ./dic.csv ... 162
# emitting double-array: 100% |###########################################|
# reading ./matrix.def ... 3x3
# emitting matrix      : 100% |###########################################|
#
# done!
# ./pos-id.def is not found. minimum setting is used
# reading ./unk.def ... 2
# emitting double-array: 100% |###########################################|
# ./model.def is not found. skipped.
# ./pos-id.def is not found. minimum setting is used
# reading ./dic.csv ... 4
# emitting double-array: 100% |###########################################|
# reading ./matrix.def ... 1x1
#
# done!
# ./pos-id.def is not found. minimum setting is used
# reading ./unk.def ... 11
# emitting double-array: 100% |###########################################|
# ./model.def is not found. skipped.
# ./pos-id.def is not found. minimum setting is used
# reading ./dic.csv ... 1
# reading ./matrix.def ... 1x1
#
# done!
# ./pos-id.def is not found. minimum setting is used
# reading ./unk.def ... 2
# emitting double-array: 100% |###########################################|
# ./model.def is not found. skipped.
# ./pos-id.def is not found. minimum setting is used
# reading ./dic.csv ... 1
# reading ./matrix.def ... 1x1
#
# done!
# PASS: run-dics.sh
# PASS: run-eval.sh
# seed/pos-id.def is not found. minimum setting is used
# reading seed/unk.def ... 40
# emitting double-array: 100% |###########################################|
# seed/model.def is not found. skipped.
# seed/pos-id.def is not found. minimum setting is used
# reading seed/dic.csv ... 4335
# emitting double-array: 100% |###########################################|
# reading seed/matrix.def ... 1x1
#
# done!
# reading corpus ...
# Number of sentences: 34
# Number of features:  64108
# eta:                 0.00005
# freq:                1
# eval-size:           6
# unk-eval-size:       4
# threads:             1
# charset:             EUC-JP
# C(sigma^2):          1.00000
#
# iter=0 err=1.00000 F=0.35771 target=2406.28355 diff=1.00000
# iter=1 err=0.97059 F=0.65652 target=1484.25231 diff=0.38318
# iter=2 err=0.91176 F=0.79331 target=863.32765 diff=0.41834
# iter=3 err=0.85294 F=0.89213 target=596.72480 diff=0.30881
# iter=4 err=0.61765 F=0.95467 target=336.30744 diff=0.43641
# iter=5 err=0.50000 F=0.96702 target=246.53039 diff=0.26695
# iter=6 err=0.35294 F=0.95472 target=188.93963 diff=0.23361
# iter=7 err=0.20588 F=0.99106 target=168.62665 diff=0.10751
# iter=8 err=0.05882 F=0.99777 target=158.64865 diff=0.05917
# iter=9 err=0.08824 F=0.99665 target=154.14530 diff=0.02839
# iter=10 err=0.08824 F=0.99665 target=151.94257 diff=0.01429
# iter=11 err=0.02941 F=0.99888 target=147.20825 diff=0.03116
# iter=12 err=0.00000 F=1.00000 target=147.34956 diff=0.00096
# iter=13 err=0.02941 F=0.99888 target=146.32592 diff=0.00695
# iter=14 err=0.00000 F=1.00000 target=145.77299 diff=0.00378
# iter=15 err=0.02941 F=0.99888 target=145.24641 diff=0.00361
# iter=16 err=0.00000 F=1.00000 target=144.96490 diff=0.00194
# iter=17 err=0.02941 F=0.99888 target=144.90246 diff=0.00043
# iter=18 err=0.00000 F=1.00000 target=144.75959 diff=0.00099
# iter=19 err=0.00000 F=1.00000 target=144.71727 diff=0.00029
# iter=20 err=0.00000 F=1.00000 target=144.66337 diff=0.00037
# iter=21 err=0.00000 F=1.00000 target=144.61349 diff=0.00034
# iter=22 err=0.00000 F=1.00000 target=144.62987 diff=0.00011
# iter=23 err=0.00000 F=1.00000 target=144.60060 diff=0.00020
# iter=24 err=0.00000 F=1.00000 target=144.59125 diff=0.00006
# iter=25 err=0.00000 F=1.00000 target=144.58619 diff=0.00004
# iter=26 err=0.00000 F=1.00000 target=144.58219 diff=0.00003
# iter=27 err=0.00000 F=1.00000 target=144.58059 diff=0.00001
#
# Done! writing model file ...
# model-ipadic.c1.0.f1.model is not a binary model. reopen it as text mode...
# reading seed/unk.def ... 40
# reading seed/dic.csv ... 4335
# emitting model-ipadic.c1.0.f1.dic/left-id.def/ model-ipadic.c1.0.f1.dic/right-id.def
# emitting model-ipadic.c1.0.f1.dic/unk.def ... 40
# emitting model-ipadic.c1.0.f1.dic/dic.csv ... 4335
# emitting matrix      : 100% |###########################################|
# copying seed/char.def to model-ipadic.c1.0.f1.dic/char.def
# copying seed/rewrite.def to model-ipadic.c1.0.f1.dic/rewrite.def
# copying seed/dicrc to model-ipadic.c1.0.f1.dic/dicrc
# copying seed/feature.def to model-ipadic.c1.0.f1.dic/feature.def
# copying model-ipadic.c1.0.f1.model to model-ipadic.c1.0.f1.dic/model.def
#
# done!
# model-ipadic.c1.0.f1.dic/pos-id.def is not found. minimum setting is used
# reading model-ipadic.c1.0.f1.dic/unk.def ... 40
# emitting double-array: 100% |###########################################|
# model-ipadic.c1.0.f1.dic/pos-id.def is not found. minimum setting is used
# reading model-ipadic.c1.0.f1.dic/dic.csv ... 4335
# emitting double-array: 100% |###########################################|
# reading model-ipadic.c1.0.f1.dic/matrix.def ... 346x346
# emitting matrix      : 100% |###########################################|
#
# done!
#               precision          recall         F
# LEVEL 0:    12.8959(57/442) 11.8998(57/479) 12.3779
# LEVEL 1:    12.2172(54/442) 11.2735(54/479) 11.7264
# LEVEL 2:    11.7647(52/442) 10.8559(52/479) 11.2921
# LEVEL 4:    11.7647(52/442) 10.8559(52/479) 11.2921
# PASS: run-cost-train.sh
# ==================
# All 3 tests passed
# ==================
# make[2]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2/tests'
# make[1]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2/tests'
# make[1]: Entering directory '/tmp/mecab-0.996-ko-0.9.2'
# make[1]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2'
# Making install in src
# make[1]: Entering directory '/tmp/mecab-0.996-ko-0.9.2/src'
# make[2]: Entering directory '/tmp/mecab-0.996-ko-0.9.2/src'
# test -z "/usr/local/lib" || /usr/bin/mkdir -p "/usr/local/lib"
#  /bin/bash ../libtool   --mode=install /usr/bin/install -c   libmecab.la '/usr/local/lib'
# libtool: install: /usr/bin/install -c .libs/libmecab.so.2.0.0 /usr/local/lib/libmecab.so.2.0.0
# libtool: install: (cd /usr/local/lib && { ln -s -f libmecab.so.2.0.0 libmecab.so.2 || { rm -f libmecab.so.2 && ln -s libmecab.so.2.0.0 libmecab.so.2; }; })
# libtool: install: (cd /usr/local/lib && { ln -s -f libmecab.so.2.0.0 libmecab.so || { rm -f libmecab.so && ln -s libmecab.so.2.0.0 libmecab.so; }; })
# libtool: install: /usr/bin/install -c .libs/libmecab.lai /usr/local/lib/libmecab.la
# libtool: install: /usr/bin/install -c .libs/libmecab.a /usr/local/lib/libmecab.a
# libtool: install: chmod 644 /usr/local/lib/libmecab.a
# libtool: install: ranlib /usr/local/lib/libmecab.a
# libtool: finish: PATH="/opt/bin:/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin:/sbin" ldconfig -n /usr/local/lib
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# ----------------------------------------------------------------------
# Libraries have been installed in:
#    /usr/local/lib
#
# If you ever happen to want to link against installed libraries
# in a given directory, LIBDIR, you must either use libtool, and
# specify the full pathname of the library, or use the `-LLIBDIR'
# flag during linking and do at least one of the following:
#    - add LIBDIR to the `LD_LIBRARY_PATH' environment variable
#      during execution
#    - add LIBDIR to the `LD_RUN_PATH' environment variable
#      during linking
#    - use the `-Wl,-rpath -Wl,LIBDIR' linker flag
#    - have your system administrator add LIBDIR to `/etc/ld.so.conf'
#
# See any operating system documentation about shared libraries for
# more information, such as the ld(1) and ld.so(8) manual pages.
# ----------------------------------------------------------------------
# test -z "/usr/local/bin" || /usr/bin/mkdir -p "/usr/local/bin"
#   /bin/bash ../libtool   --mode=install /usr/bin/install -c mecab '/usr/local/bin'
# libtool: install: /usr/bin/install -c .libs/mecab /usr/local/bin/mecab
# test -z "/usr/local/libexec/mecab" || /usr/bin/mkdir -p "/usr/local/libexec/mecab"
#   /bin/bash ../libtool   --mode=install /usr/bin/install -c mecab-dict-index mecab-dict-gen mecab-cost-train mecab-system-eval mecab-test-gen '/usr/local/libexec/mecab'
# libtool: install: /usr/bin/install -c .libs/mecab-dict-index /usr/local/libexec/mecab/mecab-dict-index
# libtool: install: /usr/bin/install -c .libs/mecab-dict-gen /usr/local/libexec/mecab/mecab-dict-gen
# libtool: install: /usr/bin/install -c .libs/mecab-cost-train /usr/local/libexec/mecab/mecab-cost-train
# libtool: install: /usr/bin/install -c .libs/mecab-system-eval /usr/local/libexec/mecab/mecab-system-eval
# libtool: install: /usr/bin/install -c .libs/mecab-test-gen /usr/local/libexec/mecab/mecab-test-gen
# test -z "/usr/local/include" || /usr/bin/mkdir -p "/usr/local/include"
#  /usr/bin/install -c -m 644 mecab.h '/usr/local/include'
# make[2]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2/src'
# make[1]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2/src'
# Making install in man
# make[1]: Entering directory '/tmp/mecab-0.996-ko-0.9.2/man'
# make[2]: Entering directory '/tmp/mecab-0.996-ko-0.9.2/man'
# make[2]: Nothing to be done for 'install-exec-am'.
# test -z "/usr/local/share/man/man1" || /usr/bin/mkdir -p "/usr/local/share/man/man1"
#  /usr/bin/install -c -m 644 mecab.1 '/usr/local/share/man/man1'
# make[2]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2/man'
# make[1]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2/man'
# Making install in doc
# make[1]: Entering directory '/tmp/mecab-0.996-ko-0.9.2/doc'
# make[2]: Entering directory '/tmp/mecab-0.996-ko-0.9.2/doc'
# make[2]: Nothing to be done for 'install-exec-am'.
# make[2]: Nothing to be done for 'install-data-am'.
# make[2]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2/doc'
# make[1]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2/doc'
# Making install in tests
# make[1]: Entering directory '/tmp/mecab-0.996-ko-0.9.2/tests'
# make[2]: Entering directory '/tmp/mecab-0.996-ko-0.9.2/tests'
# make[2]: Nothing to be done for 'install-exec-am'.
# make[2]: Nothing to be done for 'install-data-am'.
# make[2]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2/tests'
# make[1]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2/tests'
# make[1]: Entering directory '/tmp/mecab-0.996-ko-0.9.2'
# make[2]: Entering directory '/tmp/mecab-0.996-ko-0.9.2'
# test -z "/usr/local/bin" || /usr/bin/mkdir -p "/usr/local/bin"
#  /usr/bin/install -c mecab-config '/usr/local/bin'
# test -z "/usr/local/etc" || /usr/bin/mkdir -p "/usr/local/etc"
#  /usr/bin/install -c -m 644 mecabrc '/usr/local/etc'
# make[2]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2'
# make[1]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2'
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# --2024-05-14 05:14:58--  https://www.dropbox.com/s/i8girnk5p80076c/mecab-ko-dic-2.1.1-20180720.tar.gz?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.8.18, 2620:100:6018:18::a27d:312
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.8.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/dl/i8girnk5p80076c/mecab-ko-dic-2.1.1-20180720.tar.gz [following]
# --2024-05-14 05:14:58--  https://www.dropbox.com/s/dl/i8girnk5p80076c/mecab-ko-dic-2.1.1-20180720.tar.gz
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucddcf5faf2489f8bec047591274.dl.dropboxusercontent.com/cd/0/get/CS23sVP_NJmmXg6xM30yra9psht35IXH3JP-kf14prf051-lM1-hhtDqQMOyNvXLMw62xOJUJ6Fx1PcSCToSnHj5LNXnpSqUuG3T4xHv_7t05P13BJSYj2TbtMdaiI5F5VoXW56TMOMWs8cOI6q3dO0C/file?dl=1# [following]
# --2024-05-14 05:14:59--  https://ucddcf5faf2489f8bec047591274.dl.dropboxusercontent.com/cd/0/get/CS23sVP_NJmmXg6xM30yra9psht35IXH3JP-kf14prf051-lM1-hhtDqQMOyNvXLMw62xOJUJ6Fx1PcSCToSnHj5LNXnpSqUuG3T4xHv_7t05P13BJSYj2TbtMdaiI5F5VoXW56TMOMWs8cOI6q3dO0C/file?dl=1
# Resolving ucddcf5faf2489f8bec047591274.dl.dropboxusercontent.com (ucddcf5faf2489f8bec047591274.dl.dropboxusercontent.com)... 162.125.83.15, 2620:100:6018:15::a27d:30f
# Connecting to ucddcf5faf2489f8bec047591274.dl.dropboxusercontent.com (ucddcf5faf2489f8bec047591274.dl.dropboxusercontent.com)|162.125.83.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 49775061 (47M) [application/binary]
# Saving to: ‘mecab-ko-dic-2.1.1-20180720.tar.gz?dl=1’
#
# mecab-ko-dic-2.1.1- 100%[===================>]  47.47M  15.4MB/s    in 4.0s
#
# 2024-05-14 05:15:04 (11.8 MB/s) - ‘mecab-ko-dic-2.1.1-20180720.tar.gz?dl=1’ saved [49775061/49775061]
#
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# autoconf is already the newest version (2.71-2).
# autoconf set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 52 not upgraded.
# mecab-ko-dic-2.1.1-20180720/
# mecab-ko-dic-2.1.1-20180720/configure
# mecab-ko-dic-2.1.1-20180720/COPYING
# mecab-ko-dic-2.1.1-20180720/autogen.sh
# mecab-ko-dic-2.1.1-20180720/Place-station.csv
# mecab-ko-dic-2.1.1-20180720/NNG.csv
# mecab-ko-dic-2.1.1-20180720/README
# mecab-ko-dic-2.1.1-20180720/EF.csv
# mecab-ko-dic-2.1.1-20180720/MAG.csv
# mecab-ko-dic-2.1.1-20180720/Preanalysis.csv
# mecab-ko-dic-2.1.1-20180720/NNB.csv
# mecab-ko-dic-2.1.1-20180720/Person-actor.csv
# mecab-ko-dic-2.1.1-20180720/VV.csv
# mecab-ko-dic-2.1.1-20180720/Makefile.in
# mecab-ko-dic-2.1.1-20180720/matrix.def
# mecab-ko-dic-2.1.1-20180720/EC.csv
# mecab-ko-dic-2.1.1-20180720/NNBC.csv
# mecab-ko-dic-2.1.1-20180720/clean
# mecab-ko-dic-2.1.1-20180720/ChangeLog
# mecab-ko-dic-2.1.1-20180720/J.csv
# mecab-ko-dic-2.1.1-20180720/.keep
# mecab-ko-dic-2.1.1-20180720/feature.def
# mecab-ko-dic-2.1.1-20180720/Foreign.csv
# mecab-ko-dic-2.1.1-20180720/XPN.csv
# mecab-ko-dic-2.1.1-20180720/EP.csv
# mecab-ko-dic-2.1.1-20180720/NR.csv
# mecab-ko-dic-2.1.1-20180720/left-id.def
# mecab-ko-dic-2.1.1-20180720/Place.csv
# mecab-ko-dic-2.1.1-20180720/Symbol.csv
# mecab-ko-dic-2.1.1-20180720/dicrc
# mecab-ko-dic-2.1.1-20180720/NP.csv
# mecab-ko-dic-2.1.1-20180720/ETM.csv
# mecab-ko-dic-2.1.1-20180720/IC.csv
# mecab-ko-dic-2.1.1-20180720/Place-address.csv
# mecab-ko-dic-2.1.1-20180720/Group.csv
# mecab-ko-dic-2.1.1-20180720/model.def
# mecab-ko-dic-2.1.1-20180720/XSN.csv
# mecab-ko-dic-2.1.1-20180720/INSTALL
# mecab-ko-dic-2.1.1-20180720/rewrite.def
# mecab-ko-dic-2.1.1-20180720/Inflect.csv
# mecab-ko-dic-2.1.1-20180720/configure.ac
# mecab-ko-dic-2.1.1-20180720/NNP.csv
# mecab-ko-dic-2.1.1-20180720/CoinedWord.csv
# mecab-ko-dic-2.1.1-20180720/XSV.csv
# mecab-ko-dic-2.1.1-20180720/pos-id.def
# mecab-ko-dic-2.1.1-20180720/Makefile.am
# mecab-ko-dic-2.1.1-20180720/unk.def
# mecab-ko-dic-2.1.1-20180720/missing
# mecab-ko-dic-2.1.1-20180720/VCP.csv
# mecab-ko-dic-2.1.1-20180720/install-sh
# mecab-ko-dic-2.1.1-20180720/Hanja.csv
# mecab-ko-dic-2.1.1-20180720/MAJ.csv
# mecab-ko-dic-2.1.1-20180720/XSA.csv
# mecab-ko-dic-2.1.1-20180720/Wikipedia.csv
# mecab-ko-dic-2.1.1-20180720/tools/
# mecab-ko-dic-2.1.1-20180720/tools/add-userdic.sh
# mecab-ko-dic-2.1.1-20180720/tools/mecab-bestn.sh
# mecab-ko-dic-2.1.1-20180720/tools/convert_for_using_store.sh
# mecab-ko-dic-2.1.1-20180720/user-dic/
# mecab-ko-dic-2.1.1-20180720/user-dic/nnp.csv
# mecab-ko-dic-2.1.1-20180720/user-dic/place.csv
# mecab-ko-dic-2.1.1-20180720/user-dic/person.csv
# mecab-ko-dic-2.1.1-20180720/user-dic/README.md
# mecab-ko-dic-2.1.1-20180720/NorthKorea.csv
# mecab-ko-dic-2.1.1-20180720/VX.csv
# mecab-ko-dic-2.1.1-20180720/right-id.def
# mecab-ko-dic-2.1.1-20180720/VA.csv
# mecab-ko-dic-2.1.1-20180720/char.def
# mecab-ko-dic-2.1.1-20180720/NEWS
# mecab-ko-dic-2.1.1-20180720/MM.csv
# mecab-ko-dic-2.1.1-20180720/ETN.csv
# mecab-ko-dic-2.1.1-20180720/AUTHORS
# mecab-ko-dic-2.1.1-20180720/Person.csv
# mecab-ko-dic-2.1.1-20180720/XR.csv
# mecab-ko-dic-2.1.1-20180720/VCN.csv
# Looking in current directory for macros.
# configure.ac:2: warning: AM_INIT_AUTOMAKE: two- and three-arguments forms are deprecated.
# ./lib/autoconf/general.m4:2434: AC_DIAGNOSE is expanded from...
# aclocal.m4:139: AM_INIT_AUTOMAKE is expanded from...
# configure.ac:2: the top level
# configure.ac:56: warning: AC_OUTPUT should be used without arguments.
# configure.ac:56: You should run autoupdate.
# configure.ac:2: warning: AM_INIT_AUTOMAKE: two- and three-arguments forms are deprecated.  For more info, see:
# configure.ac:2: https://www.gnu.org/software/automake/manual/automake.html#Modernize-AM_005fINIT_005fAUTOMAKE-invocation
# checking for a BSD-compatible install... /usr/bin/install -c
# checking whether build environment is sane... yes
# /tmp/mecab-ko-dic-2.1.1-20180720/missing: Unknown `--is-lightweight' option
# Try `/tmp/mecab-ko-dic-2.1.1-20180720/missing --help' for more information
# configure: WARNING: 'missing' script is too old or missing
# checking for a race-free mkdir -p... /usr/bin/mkdir -p
# checking for gawk... no
# checking for mawk... mawk
# checking whether make sets $(MAKE)... yes
# checking whether make supports nested variables... yes
# checking for mecab-config... /usr/local/bin/mecab-config
# checking that generated files are newer than configure... done
# configure: creating ./config.status
# config.status: creating Makefile
# make: Nothing to be done for 'all'.
# make[1]: Entering directory '/tmp/mecab-ko-dic-2.1.1-20180720'
# make[1]: Nothing to be done for 'install-exec-am'.
#  /usr/bin/mkdir -p '/usr/local/lib/mecab/dic/mecab-ko-dic'
#  /usr/bin/install -c -m 644 model.bin matrix.bin char.bin sys.dic unk.dic left-id.def right-id.def rewrite.def pos-id.def dicrc '/usr/local/lib/mecab/dic/mecab-ko-dic'
# make[1]: Leaving directory '/tmp/mecab-ko-dic-2.1.1-20180720'
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# fatal: destination path 'mecab-python-0.996' already exists and is not an empty directory.
# Requirement already satisfied: konlpy in /usr/local/lib/python3.10/dist-packages (0.6.0)
# Requirement already satisfied: JPype1>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from konlpy) (1.5.0)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from konlpy) (4.9.4)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.10/dist-packages (from konlpy) (1.25.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from JPype1>=0.7.0->konlpy) (24.0)

# %% [markdown]
# ## 필요한 라이브러리 import

# %%
import pandas as pd
import re
import pandas as pd
from tqdm import tqdm
from pykospacing import Spacing
from collections import Counter

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## konlpy Test

# %%
from konlpy.tag import Komoran, Okt, Hannanum, Kkma, Mecab # 한국어 형태소 분석

text = "아버지가방에들어가신다."
komoran = Komoran()
okt = Okt()
hannanum = Hannanum()
kkma = Kkma()
mecab = Mecab()

# %%
print(komoran.morphs(text))
print(okt.morphs(text))
print(hannanum.morphs(text))
print(kkma.morphs(text))
print(mecab.morphs(text))
# Out:
# ['아버지', '가방', '에', '들어가', '시', 'ㄴ다', '.']
# ['아버지', '가방', '에', '들어가신다', '.']
# ['아버지가방에들어가', '이', '시ㄴ다', '.']
# ['아버지', '가방', '에', '들어가', '시', 'ㄴ다', '.']
# ['아버지', '가', '방', '에', '들어가', '신다', '.']

# %% [markdown]
# ## 실제 데이터 작업 코드

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/파이널 프로젝트/data/서울시 고립은둔청년 실태조사(청년조사)_전처리본.csv')
df = df['【C9】 의견사항']

# %%
df = df[df != '-']
df = df.reset_index(drop=True)

# %%
df = pd.DataFrame(df)

# %%
# 한글 표현만 남기기 ( \n과 숫자 이런 문자들이 있으므로.)
def extract_word(text):
  hangeul = re.compile('[^가-힣]')
  result = hangeul.sub(' ', text)
  return result


print("Before Extraction : ",df['【C9】 의견사항'][1082])
print("After Extraction : ", extract_word(df['【C9】 의견사항'][1082]))

print("Before Extraction : ",df['【C9】 의견사항'][1085])
print("After Extraction : ", extract_word(df['【C9】 의견사항'][1085]))
df['【C9】 의견사항'] = df['【C9】 의견사항'].apply(lambda x:extract_word(x))
# Out:
# Before Extraction :  정신적인 피해를 입었을 때
# 약처방을 받게되면 다양한 부작용들이 생깁니다
# (예를들어 공황, 손떨림, 기억력저하, 멈추지 않는 눈물 등)
#  다양한 부작용을 겪다보면 사회생활이 힘들어지고
# 병원비 지출까지 해야해서
# 경제적인 부담이 엄청 커집니다.
# 경제적인 부담을 조금이라도 줄일 수 있는 정책이 나왔으면 좋겠습니다
# After Extraction :  정신적인 피해를 입었을 때 약처방을 받게되면 다양한 부작용들이 생깁니다   예를들어 공황  손떨림  기억력저하  멈추지 않는 눈물 등   다양한 부작용을 겪다보면 사회생활이 힘들어지고  병원비 지출까지 해야해서  경제적인 부담이 엄청 커집니다   경제적인 부담을 조금이라도 줄일 수 있는 정책이 나왔으면 좋겠습니다
# Before Extraction :  다양한 멘토링 프로그램
# 1:1 상담
# After Extraction :  다양한 멘토링 프로그램     상담

# %%
# # 띄어쓰기 고치기 #=> 안함. 이유는 띄어쓰기를 자기 멋대로 하여 '은 둔' , '이 유' 이런식으로 변화시킴 얘가.
# spacing = Spacing()

# def spacing_sentence(text):
#   return spacing(text)

# # print("Before Extraction : ",df['【C9】 의견사항'][1082])
# # print("After Extraction : ", spacing(df['【C9】 의견사항'][1082]))

# # print("Before Extraction : ",df['【C9】 의견사항'][1085])
# # print("After Extraction : ", spacing(df['【C9】 의견사항'][1085]))
# df['【C9】 의견사항'] = df['【C9】 의견사항'].apply(lambda x:spacing(x))

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/파이널 프로젝트/data/의견사항 분석.csv')

# %%
df['【C9】 의견사항'].tolist()
# Out:
# ['청년 구직 및 임대주택 등의 사업이 필요할 것 같습니다 ',
#  '생색 내기 는 안 했으면 좋겠습니다',
#  '자유로운',
#  '경제적으로 자립할 수 있도록 도움주세요',
#  '비대면 상담',
#  '홍보가 더 많이 되어야할거같아요',
#  '실직이나 취업 준비생들을 위한 모임',
#  '식사와 근거리 걷기 또는 플로깅 체험을 포함한 프로그램을 인근의 사람들과 소규모로 모여서 참여할 수 있도록 금액을 지원해주는 정책',
#  '경제 자립 지원',
#  '다양한 이벤트를 통한 홍보활동 증진',
#  '자살예방대책',
#  '돈을 줘라',
#  '보여주기식 지원이 아닌 실직적인 효과가 있는 장기적인 지원',
#  '경제적어려움 잇는경우 일순위',
#  '레크레이션',
#  '지속적인 지원 및 회복 치료',
#  '관심',
#  '취직을 하고 싶어요 취직 시켜 주세요',
#  '부담 안 느낄정도의 가벼운 내용으로 참여하거나 인식할 것 내용들이 많았으면 함',
#  '도와주는 사람이 많아야한다',
#  '심리적인 병증은 무엇보다 자기의지가 가장중요하다고본다  본인이 자기현실을 이겨내고자하는 의지가없다면 지원은 밑빠진 독에 물붓기인 격  제대로 의지가 있는 지원자들의 지원서를 받고서 비슷한 계열의 고민은 가진    명의 소규모 모임으로 치료를 같이 진행하는것이 좋을것같다 ',
#  '소규모 직접 모여서  취미활동을 할 수 있는 동아리',
#  '다양한 정보가 있어서 좋다',
#  '관심을 가져준다',
#  '자유로운 분위기에서 이야기를 잘 들어주고 차근차근 단계별로 정신적 안정부터 실질적인 도움까지 받을 수 있으면 좋겠다',
#  '다양한 여가활동을 할 수 있도록 경제적으로 지원해주는 것',
#  '청년들에게 인생 선배로서 다양한 조언을 해줄 수도 있고  진로 설정에 어려움을 겪는 친구들에게 코칭을 해 줄 수도 있다 ',
#  '국가 시행 정책에서 선입견으로 느끼는 무성의와 실적 위주의 진정성 없는 정책이 아니라 조금 더 고민하고 진심으로 다가가는 방법이 필요하다 금전적 지원보다도 진심으로 누군가 고립 은둔 청년들을 생각하고 이해한다고 느낄 수 있게 하는 게 더 중요하다고 본다',
#  '경제적 보조 및 현금 지급',
#  '돈줘요',
#  '여가 쿠폰 제공',
#  '지속적으로 전화나 방문을 통해 대화를 해 으면 한다',
#  '무작정 사람들과 대면할 횟수를 늘리고 바깥활동을 유도하는 방법은 거부감이 듭니다 ',
#  '취업',
#  '경제적지원 및 휴식',
#  '일회성이 아닌 지속적인 지원이 필요하다고 본다',
#  '진정성잇는 심리상담과 프로그램    실용성이 없어보이는데       저도 딱히 방안을 내 놓지는 못하겠습니다 ',
#  '현실에서 좌절을 겪고 희망이 없다고 생각하는 경우가 많기 때문에  희망을 줄 수 있는 계기를 주는 것이 필요하다고 생각합니다  말뿐인 조언보다는 스스로를 달라지게 할 수 있는 자기개발  기술교육  연수교육 등의 기회를 주었으면 합니다  그리고  제가 이전에 좌절을 겪었을 때  봉사활동을 하면서 현실을 받아들이는 방법을 달리한 경험이 있습니다  고립적인 생활을 하는 사람의 입장에서 자신이 무가치하고 무의미한 존재처럼 느껴지지만  가벼운 방법으로라도  내가 남을 도울 수 있는 존재 이고 작게 나마  세상을 더 좋아지게 하는데에 역할을 하는 존재 라고 생각할 수 있는 시간을 주는 것이 좋다고 생각합니다  이에 봉사활동이나 주기적인 헌혈 등에 대한 참여를 유도하는 것도 괜찮지 않을까요 ',
#  '지금 서베이에 참여하고 더 많은 헤이폴 포인트를 쌓아보세요 ',
#  '월세 지원 정책 지원이 있었으면 한다',
#  '정신과 비용 지급',
#  '줌 수업  고립청년은 밖에 나갈 생각을 안함 ',
#  '취업연계형 사업으로 변경  돈이 있어야 뭘하지 ',
#  '지속적인 지원 및 사후관리가 중요하다',
#  '콘서트나 연극 관람 기회주기',
#  '찾아가는 서비스',
#  '장기전으로 생각하는 제도',
#  '상담',
#  '홍보를해서 널리알려줘랑',
#  '전문상담',
#  '취업지원',
#  '수해에 돌아가신 반지하 가족들처럼 그런 사고가 더이상 생기지 않도록 신경을 썼으면 좋겠다 ',
#  '금전적인 지원금을 많이 지원해주었으면 좋을것 같다 ',
#  '우선 나올수 있는 기회를 만들어줘야함',
#  '최대한 국민 세금이 안드는쪽으로 운영하면 좋겠다 ',
#  '은둔 자유',
#  '친구가 맺어지는 과정이 투명하면 좋겠다',
#  '경제',
#  '공원 산책 등 야외 활동에 참여할 만한 프로그램이 있으면 좋겠다',
#  '취업연계',
#  '세금 감면',
#  '은둔 청년들도 방 안에서 게임을 하거나 유튜브를 하거나 어떤 행동을 할 테니   그들의 그런 활동으로 돈을 벌 수 있다는 점을 알려주면 좋을 듯   유튜브로 돈을 벌 수 있는 방법과 편집 프로그램  툴 사용법 등을 교육하면 어떨지  ',
#  '프리허그 운동',
#  '결심하자마자 바로 도와줄 수 있는 채널',
#  '맞춤형 상담 및 지원',
#  '친구를 만들어주는 사업을 한다',
#  '현실적인 지원을 해야 한다',
#  '   로 관리할 수 있는 복지사가 있었으면 좋겠다',
#  '힘든 사람이 직접 이런 정책들을 찾고 지원하는게 참 쉽지가 않은듯 합니다  찾아가는 서비스로 이러한 도움이 필요한 사람들을 잘 찾을수 있는   선별할수 있는 시스템이 먼저 잘 갖춰졌으면 합니다 ',
#  '정부에서 적극 지원했으면 한다',
#  '안정된 일자리 정규직  보장  노동자에 대한 처우 개선  청년에 대한 경제적 지원',
#  '부담되지 않고 신원이 확실히 보장되어야 한다',
#  '포인트제도',
#  '지속적인 경제적 지원',
#  '이쪽으로 경험이 없어서',
#  '청년경제적 지원을 더 늘리면 좋겠다',
#  '청소년들의 경제상황에 맞춰서 특수 목적성의 학교를 설립',
#  '일회 상담성 도움보다 현실적인 도움이 필요하다',
#  '자유롭게 익명으로 상담을 할 수 있는 시스템',
#  '홀로 거주하는 청년들을 전수 조사하면 좋을 것 같다 ',
#  '고립된 청년을 도움 줄 방안이 있을 까 찾는 다고 해도 은든과 고립의 일상인데 밖으로 나올라고 할까요  정책적으로 정형적인 탁상행정으로 수원  모녀 사건 처럼   관심이 갈까 하는 생각이 드는데   ',
#  '노동 강도 및 근로 시간이 수월하고 짧은 공공 일자리를 제공하여 경제 활동에 참여할 수 있도록 유도하기',
#  '비대면',
#  '정책이 있다는 것 자체가 알려지지 않았음',
#  ' 시 뉴스에서 은둔청년에 대해 다룬적이 있었는데 남일 같지가 않았다   만명 넘게 증상을 가지고 있고 해결책을 가지고 지원한다고 했는데 가장 중요한건 돈이나 사람보다 미래를 만들어줘야한다고 생각한다',
#  '경제적 지원',
#  '고립되지 않게 지속적인 관심과 격려가 필요해요',
#  '정책 마련 후  적극적인 홍보 필요',
#  '소통',
#  '보다 경제적으로 확실한 지원이 필요',
#  '경제적 지원',
#  '액티비티 프로그램 마련',
#  '단순한 일회성이 아니라 적극적으로 고립  은둔 청년을 불러들어야하며 참여 나이와 성별  사람 수에 제한을 두어서는 절대 안된다  적극적인 경제적지원  취업연계 지원 필요하며  일회성이 아닌 장기적으로 관리해야함',
#  '  세까지 가능하게 해주었으면',
#  '사회적으로 참여할수 있는 활동 단체 및 프로그램을 계발하여 주말에도 참여가 가능한 모임 개선',
#  '다양한 일자리 알선  취업기회 제공',
#  '어떠어떠한 정책이 효과가 높고 결과가 좋다는건 있을 수 없는 영역이라고 생각하기에 섬세하게 방법을 변경하며 접근하되 당장 결과가 나오지 않더라도 꾸준히 계속적으로 시행해 나가야만 미진하더라도 결과물이 보일 수 있는 영역이라고 생각됨',
#  '독서활동',
#  '사회에 정착할수있게끔 일자리를 만들어줘야한다',
#  '일자리및 취업에 필요한 자금지원',
#  '다양한 지원 필요',
#  '고립 운든 청년지원사업',
#  '상담 정책 활발한 홍보',
#  '솔직하게 적자면 이미 중증 우울증은 정말 구제 방법이 없다고 생각합니다  그런 경우는 통상 유년시절의 상처로 비롯된 경우가 많고 어릴적부터 이어진 가족내의 상처로 기인하는 경우도 많습니다  이런 경우 그 사람을 총제적으로 드러내야 하기때문에 상담으로 치유되긴 어렵다고 봅니다 ',
#  '신체활동',
#  '자존감을 높여주는 프로그램이 많았으면 한다',
#  '예전에 저같은 경우 괴롭힘을 당해서    년동안 방에만 있었습니다  밖으로 나가면 다른 사람들이 나를 두고 욕하는 것 같고 내 과거를 아는것 같고 밖이 너무 무서웠습니다  그런데    년동안 부모님 일 도와드리고 제가 좋아하는 책을 읽으니 세상이 생각보다 살 만하다는 것을 어느 순간 깨달았습니다  제 개인적 견해로는 세상이 어떤지 견문을 좀 넓히고 이런일도 있고 저런일도 있구나 하면서 여러세상을 직접이든 간접이든 겪음으로 해서 과거는 정말 조그만한 세상이였고 세계는 넓구나 하니 마음이 편안해 지더라구요  세상을 여러 관점에서 바라볼 수 있는 힘을 길러주는 정책이 있었으면 합니다 ',
#  '취업  배움 활동에 대한 지원',
#  '직업을 적극 장려한다 ',
#  '돈걱정없이  지원받고싶다',
#  ' 대  매칭',
#  '임시거처를 할수있는 시설확충',
#  '지원금을 많이 주면 좋겠자',
#  '세심한 관심',
#  '봉사활동',
#  '경제적 지원',
#  '긍정적인효과를 내세운 온라인 홍보',
#  '  와의 사전대화연습',
#  '목욕지원',
#  '자주 개인 휴대폰 전화로 사회적인 정책에 관한 메세지를 보내주시면 고맙습겠습니다    ',
#  '자유로운 상담치료와 심리치료병행',
#  '창업  취업  자기개발 활동을 위한 경제적 지원 및 멘토상담 지원',
#  '픽업 서비스가 잇어서 해당 구내에 셔틀 버스식으로 시설에 데려다줘서 단체 교육을 해줬으면 좋겠다',
#  '온라인이나 동영상 홍보를 통한 전달작업',
#  '금전적으로 지원해주면서 심리상담',
#  '가족 중에 이런 사람이 있어서 취업 지원 제발',
#  '상담',
#  '가장 먼저 규칙적인 생활을 할수 있도록 가벼운 규칙적인 커뮤니티형 운동 프로그램 마련  억지로 하는 것이 아니라 자연스럽고 편안하지만 자유로운 분위기에 참여할 수 있는 프로그램으로 마련했으면 좋겠다  이 커뮤니티를 통해 형성된 네트워크로 마음의 안정과 다양한 정보 교류가 자연스럽게 될수 있도록 했으면 좋겠다 ',
#  '고립된 원인이 무엇이냐에 따라 처방은 달라져야 합니다  원인 진단에 집중하면 좋겠네요',
#  '경제적지원',
#  '전문상담사와 상담',
#  '봉사활동',
#  '활동자금과 동기부여가 필요하다',
#  '딱히 잘 모르겠다 대부분 외부와 단절을 처음에 시작으로 익숙해져가서 대부분 방법을 잃어버리는거 같다 나조차도 이런데 밥법을 안다면 탈출 했을듯',
#  '운동프로그램',
#  '사각지대가 없도록 적극적으로 대상을 찾고 시민단체에 맡기지 말고 시청 차원에서 전문가들로 팀을 꾸려 케어해야 한다',
#  '공원에서 같이 운동 할 수 잇는 것을 하면 좋을 것 같습니다 ',
#  '다양한 활동',
#  '바리스타 자격증 이나 컴활이나 워드 자격증 딸 수 있으면 좋겠습니다',
#  '취업하는데 필요한 자격증 강의제공 자격증 시험료 지원',
#  '많은 홍보와 실제적인 참여율로 생활을 하는데 도움이 되는 시스템이면 좋겠어요',
#  '수요조사부터 한 후에 프로그램 기획',
#  '다양한 활동을 할 수 있는 기회를 줬으면 좋겠다  뭘 하고 싶은지 뭘 잘하는지는 해봐야 하는데 적극성이 떨어지다보니 그것을 찾을 기회도 의욕도 주는것 같다 ',
#  '집에서 밖으로 나갈 수 있게끔 계기를 마련해 준다',
#  '고립',
#  '참여활성화',
#  '돈을 다시 환원해서 선순환을 이끈다',
#  '고립  은둔 청년들은 지원사업이 있다는 것 조차 알지 못할 것 같다  이런 사업이 있다는 것을 잘 알리는 것이 우선 되어야 할 것이다  지원에 제한은 없되  은둔 고립 청년이 아닌 자에게 지원이 돌아가지 않도록 정책을 잘 정비하였으면 한다   가장 중요한 것은 은둔 고립 청년들이 집 밖을 나올 수 있게끔 하는 것이 가장 중요하다고 생각하다  돈을 지원하되  돈을 받기 위해서는 꼭 밖을 나와야 한다던가  밝은 날 외출한 기록을 제출해야 한다던가 ',
#  '돈을 넉넉하게 지원해주는게 좋을꺼 같다',
#  '본인은 한때   대 초반 집의 경제적 문제와 가족간 불화로 은둔을경험했으나  돈이 없어 결국은 일을하게 되면서 어쩔수없이 고쳐졌다  아무도 손내밀어 주지 않았고 혼자 극복했고  남은 우울감은 평생 가져가야할 숙제 라고 생각된다  이전 세대와 다르게 요즘 청년들에게 공적서비스가 지나치게 정서적 부분까지 지원해주는것은 젊은 세대를 더 나태하고 나약하게 만든다고 생각한다  고립 은둔청년은 세금으로 지원할것이 아니라 그냥 죽게 놔두거나 어차피 본인도 죽는게 더 행복  지가 죽기는싫고 돈없으면 뭐라도 한다  세금 낭비하지말고 관심 그만주었으면 좋겠다 ',
#  '사소한 일이라도 밖에 나올 수 있게 만들어야한다  같은 시간 같은장소에 나가 생산적인 일을 하면서 규칙적인 생활을 하는 것 만으로도 은둔  고립된 사람을 밖을 나올 수 있게 한다',
#  '정작 필요한 사람들은 이런 제도가 있다는 것 자체를 모를것이기 때문에 사각지대에 있는 사람들을 잘 찾아야 효과가 있을 것 같습니다 ',
#  '최대한 많은 지원',
#  '친구를 만들 수 있는 프로그램',
#  '대화를 자주해야한다',
#  '심리치료',
#  '카카오톡 채널  이메일 상담',
#  '상담',
#  '가능하면 장기적인 지원이 좋을 것 같습니다   회성 지원은 그닥 효과가 있지 않아요  그리고 활동적인 액티비티가 함께 되면 좋을 것 같습니다 ',
#  '홍보',
#  '같은 처지의 사람을 모아 합숙 및 캠핑 쉬운 서바이벌 훈련을 시켜 독립심 및 사회성 자존감을 높인다  같은 처지의 사람리 정기적으로 모여 다과를 즐기며 서로의 고충을 듣고 해결을 위한 도움을 준다',
#  '더 많은 이들에게 도움이 됐으면 한다',
#  '일단 집 밖으로 나오도록 유도하는 것이 중요하고 비슷한 문제를 겪는 사람들이 많다는 사실을 인지할 수 있도록 하면 좋을 것 같습니다 ',
#  '다양한 상담 프로그램이 있으면 좋을 것 같다',
#  '관련 커뮤니티를 익명으로 운영하면서 오프라인과 온라인에서 부담없이 대화하고 지원받을수가 있는 채계를 만들고 경제적으로 심리적으로 같이 지원하는것',
#  '비슷한 나이대  직업군  학력  취미 등 공감대를 이룰 수 있는 사람들과의 만남과 프로그램이 있었으면 좋겠다',
#  '그들에서 섣불리 다가가는것 보다는 천천히 다가가는 것이 좋을 거 같다',
#  '상담',
#  '진짜 음지에 있는 사람들을 찾아서 도와주세요 ',
#  '다양한 방안을 찾고 있습니다  여러분이 생각하실 때 필요한 정책이 있다면 자유롭게 써 주세요   없다면 다음페이지로 이동 ',
#  '전문가와의 심리 상담  정신과전문의 상담  형식적인 상담이 아니라 사명감이 있는 분들이 상담을 해주셔야 효과가 있음  정신질환 치료를 자의로 중단한 주변 청년에게 치료를 권해본 적이 있는데 절대로 병원 안 다님  그 청년의 부모도 그 사람이 정신과 치료 받는 것을 반대함 ',
#  '한 방안을 찾고 있습니다  여러분이 생각하실 때 필요한 정책이 있다면 자유롭게 써 주세요   없다면 다음페이지로 이동 ',
#  '실질적인 대안이 되는 정책을 펴시길 바란다  보여주기식 말고',
#  '금전적인 지원',
#  '경제적인 지원',
#  '현실 고민',
#  '상담',
#  '조금더 쉽게다가갈수있는 카톡이나 이런 메신져를 통한 상담도 좋을꺼 같습니다',
#  '지속적인 상담 등 필요하다고 여기는 것 제공',
#  '노출을 싫어하는 심리상 비대면 상담과 지속적인 접촉 및 관심이 필요  개월 이상 ',
#  '생활비 지원 ',
#  '다양한 서비스',
#  '확실한 복지 정책',
#  '실제로 취준 기간일때 아무 의욕도 생기지 않는 경험을 해봤다  뭐라도 해야하는걸 알지만 어디를 나가고  친구를 만나는 것 조차 돈이기 때문에 더 나가지 않게 되었다  외출을 감당할 수 있을 정도의 경제적 지원이 뒷받침되고 그 이후에 정서적 지원  일자리 지원이 되는게 좋을 것 같다 ',
#  '좋아하는 것을 할 수 있는 개인룸이 있는 공용공간 지원',
#  '취업할 수 있도록 지원',
#  '찾아가는 서비스',
#  '사회성 길러주는 교육',
#  '고립된 삶을 사는 사람은 외출이 없기 때문에 찾기는 쉽지 않다 혹 미취업 경제활동을 하지못하는 사람들먼저 찾아봐야할것 같다',
#  '다양한 활동프로그램',
#  '실질적으로 필요한 대상자를 선별하는게 가장 중요하다고 생각한다 ',
#  '나이제한 없애기   주거지원 사람이 살 수 있는곳  제발 반지하 다 없애기  생계비가 너무 낮음  생계비 올리기 ',
#  '경제적 정신적으로 고립된 청년 지원',
#  '각자에 맞는 맞춤형 지원이 필요',
#  '    전문가와의 상담이 가장 필요하고 실용적일듯',
#  '나가기',
#  '심리상담',
#  '왜 고립과 은둔이 되었는지 원인을 파악하여 도움을 주어야 한다',
#  '몰두할 수 있는 취미가지기',
#  '희망프로그램 발굴지원',
#  '일자리 많이 만들어 주세요',
#  '상담과 치료를 받을 동안 살 수 있는 생활비 지원이 필요하다',
#  '다른 방안을 강구하는 것보다 직접 지원  금전  프로그램 ',
#  '경제적 지원보다는 취미나 일자리를 제공',
#  '경제적으로 지원해 주는 것이 있으면 좋겠다',
#  '지속적인관심',
#  '경제지원',
#  '현금서비스 지원',
#  '현금지원정책이 필요합니다',
#  '취직 연계 외에도 인적 교류가 있을 수 있는 프로그램이 있었으면 좋겠다',
#  '적극적인 대내외 홍보활동이 필요하다',
#  '강압적이지 않은 분위기',
#  '현금 지원을 많이 해야한다',
#  '실질적인 취미활동을 위한 지원 및 경제적 지원이 필요하다',
#  '금전적인 지원',
#  '현금을 준다',
#  '활동할수있는 오프라인지원',
#  '돈을 조금 주더라도 일자리 지원',
#  '체계적인 프로그램과 서비스 제공',
#  '일자리지원 상담 취미활동 및 비슷한 사람들끼리 대면기회 제공',
#  '직장 등의 이유로 서울에 올라와 거주하고 있는  인가구 상담  여러 취미 프로그램 등을 만들어 줬으면 좋겠다',
#  '일자리나 사람들과의 소통이 가능한 모임 만들기',
#  '스스로 지원하려는 사람은 없을거에요  보통 무기력하거나 아무것도 하기 싫고 사람도 만나기 싫으니까  ',
#  '현금을 두둑히',
#  '주택방안',
#  '대화를 많이 들어줬으면 좋겠다',
#  '다양한 방식으로 홍볼  했으면 좋겠습니다   주로 인터넷에서 활동을 많이하니  커뮤니티에서 홍보하기  이용 후기로 홍보하기  효과 알려주기  하면 뭐가좋은지 등등 정말 필요한 사람들에게 필요한 지원을 한다고 인식되면좋겠습니다  ',
#  '다양한 센터 운영',
#  '홍보가 많이 되었으면 좋 어요',
#  '나와서 취미나 운동 모임에 참여하면 현물이나 현금 등 바우처 제공',
#  '고립 은둔 청년이 적극적으로 지원할수 있는 길을 만들면 좋겠다',
#  '오프라인으로 대화를 통한 모임 및 간단한 게임  같이 부담없이 같이 활동하면서 대화 나눌 수 있는 뭔가가 있었으면 합니다',
#  '랜덤채팅 등 익명성이 보장된 사이트에 광고 배너를 넣어 고립된 사람들에게 노출할 것 ',
#  '원데이클래스 체험활동 알바 및 인턴생활 연계',
#  '지금도 충분',
#  '구청이나 주민센터에서 할 수 있는 취미활동이 있었으면 좋겠습니다 ',
#  '나에게 맞는 적성과 그에 부합하는 양질의 일시적이지 않은 일자리와 주거공간이 제공되면 좋겠다 ',
#  '나이대를 묶어서 멘토 멘티 제도를 만든다  여행 코너를 기획한다',
#  '조건이 부족해도 다양한 지원잇으면 좋겠다',
#  '다양한 취미활동',
#  '버스 타고다가 현수막에  인 청년 가구를 대상으로 소모임 연계 및 지원 프로그램을 알려준다고 하는데 그런 활동이 많이 알려졌으면 좋겠습니다 ',
#  '나와 싸게 밥을 먹을 수 있는 곳이 있었으면 좋겠다 ',
#  '지속적 대화',
#  '밖에 나와서 원데이 클래스 강좌 구독',
#  '청년들에게 희망을 주어야 한다',
#  '관련된 홍보 필요    광고  포털사이트 광고  지하철  버스 등에서 광고  서울시민 중 대상 연령층에게 문자나 우편으로 지원방안 안내',
#  '무료 상담',
#  '많은 홍보활동을 통해 신청자 모집후 모임 갖기',
#  '감사합니다  잘 찾아봐 주세요  요새 청년들이 많이 힘든 것 같아요  ',
#  '개인문제 사회적문제가 구분이 가 안건가여',
#  '상담 생활지원 문화생활지원',
#  '고립 은둔이면 밖에 나오는게 아니라 집에만 있을텐데    직접 방문을 해서 사업 내용이랑 알려주고 밖으로 데리고 와야 한다',
#  '경제적 사회적으로 고립되지 않도록 최선을 다해 돕는다',
#  '온라인 홍보  심리상담 취미생활 사람들과 모이는  프로그램 이후 수고료',
#  '힘들고 지칠때 위로를 해주고 누군가 내 이야기를 들어줄수 있으며 편안하게',
#  '운동을 함께할 기회제공',
#  '실질적인 도움이 필요하다 너무 형식적인 느낌',
#  '은둔형 외톨이 지원',
#  ' 대  전담 마크가 좋을거같아요',
#  '일자리알선과 정신상담',
#  '경제적 자립 지원',
#  '최대한 많은 혜택을 지원하며 한번이라도 참여 가능한 프로그램을 만든다',
#  '온라인흥보강화',
#  '정말로 사람들이 좋아할 만한 취미활동을 지원한다 ',
#  '고립이나 은둔같은 워딩말고 다른 용어 사용',
#  '현금성 지원은 하지 않는게 좋을 것 같다  좋은 일자리 연계하여 기업에 혜택을 주는 쪽이 좋을 것 같다 ',
#  '직장인은 지원 안해줘서 슬퍼요',
#  '알바자리 소개  은둔하지말고  일 시키기',
#  '밀착 홍보가 필요할 것 같다',
#  '취미생활 장려',
#  '물질적인 지원',
#  '함께하는 것',
#  '고립된 청년끼리 만나서 성관계',
#  '온라인 상담센터',
#  '이미 마음의 상처를 갖고 살아가는 사람이기 때문에 접근 시 주의 필요',
#  '경제적인 지원이 필요하다',
#  '저의 경험으로 미루어 볼 때  무기력함이나 우울함은 규칙적이지 않은 생활의 반복  사람들을 만나지 않고 고립된 생활로 인해 더 심해진다고 생각합니다  따라서 규칙적인 생활을 할 수 있는 지원 제도   예를 들어 아침  시에 일어나 인증을 하면 포인트를    원 준다든 지 하는 식으로 요즘 트렌드가 짠테크기 때문에 서울시에 배분된 재정을 프로그램을 지원한 사람들에게 포인트로 하루에 차근차근 지원해준다는 식으로 성취감을 높이는 것    규칙적인 생활을 강제하고  이런 활동을 익명의 주변 사람들과 함께 할 수 있는 프로그램이나 제도를 만들어  다른 사람을 만나기까지는 힘들어도  나 말고도 이런 상황에 있는 다른 사람들이 많구나 하는 경험을 하게 해주어 어느 정도 생활에 필요한 사회성을 충당할 수 있는 제도를 마련한다면 좋겠습니다  예를 들어 미라클모닝 챌린지  산책 챌린지 등등  개인적인 경험으로 고립되거나 은둔된 생활에서는 시작하는 거 자체가 엄청난 소모이고 용기라고 생각합니다  따라서 차근차근 작은 성취감을 달성할 수 있는 지원제도가 마련 되기를 진심으로 희망합니다 ',
#  '대화할수 있고 공감해주는 사람이 옆에 필요할거 같음',
#  '정신과 상담비용 지원방법이 있었으면 좋겠네요  병원을 가야한다는 사실은 알지만  병원비나 약값으로 주저하게 되는 경우도 있는걸 봐서요 ',
#  '희망을 주셨으면 하네요  앞으로 살 길에 대한',
#  '일시적인 것이 아닌 지속적인 관리 프로그램',
#  '경력단절 은둔여성도 도와주세요 프로그램 연계지원해주세요',
#  '상담 경제적 커리어적',
#  '물고기를 잡아주기보다는 물고기를 잡는 법을 알려주는 프로그램이 필요하다 ',
#  '구직에 이로운 법이나 제도를 제정할 필요가 있다 ',
#  '취업 및 이직 안정적 직장생활 안정적인 주거생활 보장',
#  '실질적으로 도움이 되는 경제적 지원과 사회생활을 할수있는 적극적인 취업제도와 도움이 되는 심리상담이 있었으면 좋겠다',
#  '전문적인 상담이 필요하고 친구와 같은 멘토링 프로그램이 필요할 것 같다',
#  '상담의 문턱을 낮추고 사람을 만나서 에너지를 얻을 수 있는 활동을 많이 만든다',
#  '국가에서 경제적으로 어려운 사람을 지원해야 한다',
#  '상담치료',
#  '지속적인 지원',
#  '온라인으로 상담받기',
#  '다양하게 지원해주세요',
#  '오프라인 모임 주선',
#  '실질적인 지원이 필요하다',
#  '은둔된 사람을 찾을 수 있겠니  주소는 다른 지역에 두고 서울에 은둔하고 있는 사람은 어떻게 지원하나요',
#  '연령  소득 등 제한이 심해서 지원이 더 필요한 사람이 지원 받지 못하는 경우가 많음',
#  '편안한 분위기',
#  '취업 도움',
#  '심리적으로 지원을 해줘서 사회성을 길러주는 프로젝트를 만든다',
#  '돈 많이 주는 지원',
#  '심리상담',
#  '홍보가 다양한 루트로 잘 이루어졌으면 좋겠습니다',
#  '경제적 지원과 진정한 멘토',
#  '비슷한 처지의 사람들과 함께 할 수 있는 취미활동  만들기 같은 사소한 것이라도 ',
#  '방 밖을 나올만한 작은 미션 주그',
#  '당사자가 원하는 실질적인 일자리로 향한 도움 제공 실질적인 목표 세우는 방법 실질적인 공부 방법',
#  '일자리 지원',
#  '많은도움되길바랍니다',
#  '사회생활을 하고 있지만 회사외에 아무활동을 못하는 사람들도 해당되면 좋겠다 ',
#  '우선 정신적으로 지지가 되었으면 좋겠고  실질적 문제를 해결할 수 있게 압박감없이 도움을 받았으면 좋겠다',
#  '경저제적 지원',
#  '실제로 서울시에 거주하는 청년이 얼마나 있는지 제대로 조사했으면 좋겠어요  주민등록상의 주소랑 실거주지가 다른 사람들이 워낙 많고  성범죄 등 범죄 트라우마로 은둔을 선택하게 된 사람들에 대한 심리 치료가 필요하다고 생각합니다  그리고 범죄 피해자에 대한 사회적 비난도 없어져야하고 가해자에 대한 제대로 된 사법 절차도 필요하고요 ',
#  '직접 만나서 식사하기',
#  '고립 은둔이라는 표현이 아니더라도 사람은 누구나 우울감이 들때가 있기 마련이잖아요  직장인들이나 사람들이 우울감이 들때 상담을 받거나 토로할 수 있는 온라인 창구같은 것이 있으면 좋겠습니다   부담스럽게 찾아가거나 누구를 만나지 않더라도 카톡이나 다른 것들로 소통을 하고 정리해볼 수 있는 창구가 있으면 좋을것 같아요 ',
#  '청년들에게 골고루 기회를 줬으면 좋겠어요 갑자기 자의가 아니라 타의로 일을 그만두게 되었을때 경제적 지원도 그렇구요',
#  '청년지원',
#  '주거공간',
#  '어른의 시각으로 도와주려고 해봤자 큰 도움은 안될거같다',
#  '지원 대상인지조차 모르고 지나치는 경우가 대부분일 것 같습니다  적극적으로 홍보되면 좋겠습니다 ',
#  '취미생활을 가질수있도록 지원',
#  '금전적인 지원이 필요합니다 ',
#  '지금으로도 만족',
#  '외출시 지원비 지급',
#  '처음부터 대면보다는 비대면으로 차근차근마음을 열고 그 다음에 대면이나 다른 치료를 진행하면 좋을것 같다 또 치료가 끝나고난후에도 정기적으로 모임이나 상담이 있으면좋겠다',
#  '흥미있는 활동 지원',
#  '캠페인활동이 잦았으면 좋겠다',
#  '갑자기 일자리를 잃게된 사람들을 위한 경제적인 지원',
#  '그런 사람을 발굴하는 것 자체가 어려울듯 은둔형 외톨이는 스스로 은둔형 청년이라 말하지 않음 이웃 등의 추천을 받아서 해보는건 어떨까요 우리집  층에도 딱 그런분 사시는데    ',
#  '고립 청년은 현재 복지 부서의 인력으로 모두를 커버하는 것은 현실적으로 어려우므로 통계를 위한    등을 개발하여 이용하면 좋을 것 같다 ',
#  '경제적지원',
#  '고용정책  실업자 지원',
#  '홍보와 간편한 신청  사생활 보호',
#  '   로 친밀감을 높인다',
#  '지원금때문에 상담해주는 병원이 아닌 진짜 마음을 다독여줄수있는 곳섭외',
#  '자유',
#  '고립된 많은 사람들이 알 수 있게 적극적인 홍보와 참여를 유도 하여야 한다',
#  '개인정보 및 상담체계가 좀 체계적이고 외부노출을 꺼리는 청년들을 위해    로 진행되는 프로그램이 많아야 할 것 같다',
#  '우선 고립 은둔을 피하려면 심리치료도 중요하지만 직장을 다니는게 중요하다고 생각합니다  다양한 일자리 지원과 그 일자리에 취직이 가능하게끔 취직 훈련 및 면접과 관련 공부 지원을 해주고  취직이 결정되면 청년들이 새로운 직장 환경에 적응 할 수 있도록 지원해주고 새로운 직장에서 다닐  개월 정도 동안은 온라인 같은 걸로 심리 상담같은 지원이 필요하다고 봅니다',
#  '병원을 꼭 찾아가서 방문하는거보단 카카오톡 상담센터처럼  운영하는것도 좋을거같아요',
#  '풍부한지원경험',
#  '요즘 오는 택배마다 물품에 손상있고   배송문제도 있고 해서 좀 걱정했는데  상품하자없고 배송도 문제없이 안전하게 잘 왔습니다  감사합니다   다음에 재구매 의사 있습니다     번창하세요',
#  '경제적 지원',
#  '나이제한을 좀더넓게 청녀나이가너무어려서 지원을못받아요 청년도힘들지만 나이가많다고 다잘사는간아니니까요',
#  '활동 지원이 필요합니다',
#  '부담없이 자연스럽게 어울리면서 실질적 도움도 되는 시스템',
#  '직장인 심리검사',
#  '다양한 문화생활 혜택이 있으면 좋겠어요 ',
#  '많은 홍보와 간소화된 절차',
#  '가정방문',
#  '경제적 도움이 필요로 하는데 알맞은 해결책은 아닌거 같다',
#  '요즘 젊은 이들이 선호하거나 관심있어할 만한 다양한 프로그램이 있었으면 좋겠다  콘서트나 공연 등 문화생활을 즐길 수 있는 요소들로',
#  '여러가지 문화활동',
#  '항상 연락할곳',
#  '경제적 지원',
#  '자금 지원',
#  '경제적으로 자립할수 있는 직업교육이 필요',
#  '심리적인 문제가 클 것이므로  이에대한 지원이 제일 중요할것같다',
#  '고립 은둔 하는 사람들은 맨처음엔 자기 의지로 들어가지만  나오고 싶을때는 이미 한 발 떼기 무서워져서 못 나가는 사람들도 꽤 있어요 전 그 한 걸음을 옮기게 도와줘야 한다고 생각해요',
#  '뭔지 모르겠지만 고립된 청년의 마음을 안다 ',
#  '대책안 마련',
#  ' 대 로 밀접상담',
#  '일자리 연계사업',
#  '심리상담',
#  '정신적인 문제 치료 확대 해야 함',
#  '우을증 및 가족의 죽음에 대한 심리치료',
#  '상담이필요할꺼같아요   일대일',
#  '스스로 자학 하는 습관이 덜어질수 있도록 원인을 물어보고 여러가지 직업을 알려주는 것',
#  '외로움 극복 상담',
#  '가장 문제가되는게 돈이에요  단기적으로 살아갈 돈은 있어야하고  취업 등 일자리 연계정책이 필요합니다  또한 심리상담 뿐 아니라 강연등을통해서 부정적 감정을 털고 일어날수있도록 도와주세요  돈적인 부분에 조금이나마 희망이보이고  앞으로  취업하고 잘살아나갈수있다는 용기가 생기도록 전반적인 케어가 필요합니다  그리고 정말 심할때는 이런정책에대해 알아보지도못하고 더욱 곪아가요  다양한곳에 홍보도 필요하고   고립은둔청년이 용기내서올수있도록 좀 쉬운 소통채널과 편안한분위기 조성도 필요합니다 ',
#  '서울시에서 하는 마음 건강 프로그램을 찾아보고 있었는데 신청이 격월이다 보니 정작 마음이 힘들 때 신청을 하지 못했어요  격월이 아니라  상시로 신청을 할 수 있었으면 좋겠습니다  각 구에서 신청 할 수 있는 바우처 또한 온라인 신청이 아니라 대면신청이다 보니 저같은 직장인은 반차를 쓰고 일부러 주민센터까지 가야하는 불편함이 있습니다  인터넷 시대에 인터넷으로 간편하게 신청할 수 있었음 좋겠습니다 ',
#  '은둔에서 벗어날 필요가 없다고 생각하는 대상자를 위한 참여 유도 방안',
#  '가족관계가 어떤지 상담을 해봐야 될거 같다',
#  '사회로 나올 수 있도록 도움 정책 필요',
#  '청년들을위한 일자리 창출',
#  '커뮤니티활성화',
#  '비슷한 나이 대의 사람들이 함께 취미생활 및 활동을 할 수 있도록 지원하면 좋을 것 같음',
#  '심리상태 체크',
#  '청년에 대한 경제적 지원',
#  '강요하지 말고 서서히 다가가서 기회제공',
#  '꼭 필요한 사람들에게 좋은 혜택이 돌아갔으면 합니다 ',
#  '해당 청년을 포함 함께 지내는 가족과 전문 상담사를 통해 상담을 우선적으로 한다',
#  '나랑 비슷한 상황에 있는 사람들과 그 가족들과의 만남이 필요하고 사회복지사 선생님 같은 사람들이 도와주길 원합니다',
#  '처음부터 너무 깊이 들어가는것보다 인사나 안부를 자주 보내는 간단한 내용으로 신청자에한해 카톡이나 문자 보내기   상징적인 별명이나 신청자가 원하는 이름으로 보내기',
#  '지금 정책을 몰라서 필요한 정책을 잘 모르겠음',
#  '밖에서의 활동추',
#  '심리적 안정감을 저렴하게 지원받을 수 있어야합니다  개인병원은 너무 비싸요',
#  '중증이 아닌 경증을 앓는 청년들도 참여하고 우울증에 대한 인식을 넓힐 수 있는 정책 마렴',
#  '인스타그램',
#  '사회에 적응할 수 있는 방법',
#  '고립이나 은둔 청년의 경우 가족의 보살핌이 중요하다고 생각됩니다  가족들을 교육해 주거나 대응 방법을 알려 주는 정책이 있으면 좋을 것 같아요 ',
#  '적극적인 홍보활동이 필요할 것같다 ',
#  '실업수당의 중복수령을 필터링한다',
#  '청년이 왜 그렇게 되었는지에 대한 원인을 찾아내려는 정부의 노력 및 그들의 현재 상황을 최대한 이해하고 다양한 해결방안을 모색할 수 있는 의지를 심어줄 수 있어야 한다',
#  '사회가 변화감에 따라 외톨이들이 많아지고있어서 사회적 문제라고 생각한다',
#  '적절한 시기에 미리발견하는것이 중요할것같다  장기적으로 관리해서 사회생활 적응할수있도록 도와야한다',
#  '지원금이 나오는 취업관련 프로젝트가 있으면 좋겠다',
#  '취업',
#  '고립 은둔 청년 이름 자체가 신청하기 어려울 것 같다',
#  '경제나 살리고  금리나 좀 잡자  ',
#  '편하게 다가갈 수 있었으면 좋겠고 진짜 도우려면 까다롭지 않아야 할거같다',
#  '다양한 일자리 많아 졌으면 좋겠어요',
#  '처음에는  대 로 그리고 점차적으로 비슷한 성향의 사람들을 모아 점차 사회에 나갈 수 있는 기틀을 마련하는 것이 중요하며 어떤 것이든 일이 되었든 운동이 되었든 뭔가를 하게 하는 것이 중요한 것 같습니다',
#  '다양한 문화생활을 지원',
#  '취미생활 지원',
#  '정책은 모르겠지만 가끔 친구처럼 잘지내지  라고 문자로 해줄수 있는   그런게 필요 할꺼같네요',
#  '꾸준한관심이필요하다',
#  '자살예방상담이나 자립지원 프로그램 추진',
#  '게임을 통한 건전한 일상생활을 하도록 프로그램 연계가 필요함',
#  '현실적으로 쉽지 않고 효과 미미할거라 본다',
#  '지원 프로그램의 홍보가 부족한 것 같다 ',
#  '홍보',
#  '외부활동에 참여할 수 있는 기회를 제공하고 금전적으로 도움을주어 자립을 도와야함',
#  '경제적 지원이나 심리치료 등의 지원을 하려고 해도 지원 대상을 찾아내기가 어렵거나 지원 대상이지만 마음의 문을 닫은 사람들도 있다고 생각합니다 본인이 신청하지 않더라도 주변의 도움 요청으로도 받아들여질 수 있는 환경이면 좋겠습니다',
#  '돈이 있으면 밖으로 나가게 됩니다  경제적 지원이 가장 중요하고  그 경제적 지원을 받기 위해서 강제적으로라도 상담을 받게 했으면 좋겠습니다  억지로 간 상담에서 엄청난 위로를 받았던 경험이 있어서요 ',
#  '재정',
#  '더 많은 홍보가 필요해요',
#  '나갈수잇는 이유 재밌는것들 많이 생겼으면',
#  '공유서비스운영',
#  '은둔 청년은 이런지원 방안이 있는지도 모릅니다 은둔 청년을 밖으로 나와 일하고 사회경험을 할수 있도록 도와주고 싶은데 저도 방법을 아직 생각하지 못했습니다 나라에서 적극적인 지원과 마련책이 나와주길 희망합니다',
#  '봉사활동',
#  '생계와 본인이 문제가 아님 가정사로 고립되어있는 청년들도 참여하게 해줬으면 좋겠음',
#  '아무에게도 손을 벌리거나 도움을 요청할 수 없는 고립된 저소득 가정이나 문제가 있는 문제가정에게 경제적 도움을',
#  '원하는방식으로 비대면대면하기',
#  '정부에서 적극적으로 관심을 가지며  청년들이 일정의 사회생활을 할 수 있도록 교육의 기회를 마련하고 재정적인 지원을 한다',
#  '적극적으로 참여 할수있도록  많은프로그램있어서   ',
#  '직접적인 대면 지원',
#  '상담지원 지지',
#  '재정',
#  '재정',
#  '심리적상담',
#  '경제',
#  '경제',
#  '취미  활동반을 아주 다양하게 만들어서  너무 육체적인 활동이 아닌 정적인 활동  고립은둔청년들이 등록 할 수 있는 허들을 낮춰주세요',
#  '경제',
#  '다양한 사람들을 도와주는 정책',
#  '다양한 지원정책',
#  '지속적인 심리상담',
#  '모임',
#  '다양한 분야 지원',
#  '히키코모리나 은둔청년들이 잘 볼 수 있도록 마케팅하는 것이 좋을 것 같아요',
#  '이분들은 외로움이 대부분이고 질병이 있으니 절대적인 치료가 필요할 것으로 여겨진다 우선 소통을 적극적으로 연결할 수 있는 콘텐츠 내가 참여해서 리더가 될 수 있는 것 로 연결 소통을 지속적으로 형편에 상관없이 성실하게 끈질기게 연결점을 이어주는 장치 매우 필요하리라 여겨진다',
#  '고립된 은둔 청년들을 위해 커뮤니티 형성을 하여 여러 문화 활동들을 도와준다',
#  '근본적으로 상담 등을 해주시는 분들이 과연 고립  은둔 청년을 이해할 수 있을지 의문입니다 ',
#  '돈 지원이 필요하다',
#  '일회적 이벤트가 아닌    개월 이상 지속적이었으면 좋을것 같고 단순한 그 사람의 상태에만 초점을 맞추면 반짝 괜찮아졌다가 다시 안좋아질 확률이 높으므로 주변 환경과 가족 개선이 반드시 같이 이루어졌으면 한다',
#  '단기적인 지원이 아닌 장기적인 지원이 필요',
#  '사회로 나올 수 있는 기회를 많이 주세요',
#  '다양한 일자리',
#  '경제적 지원 말고 실질적인 도움을 줘야한다 ',
#  '비슷한 또래의 커뮤니티 활동을 통해 나만의 문제가 아님을 인식햇으면 좋겟다',
#  '충분한 상담과 관심',
#  '비슷한 상황에 있는 분들끼리 소통할 수 있는 모임을 만들어도 괜찮을것같네요',
#  '산책등이라도 가볍게 밖으로 나오게 하는 모든 정책',
#  '경제적 지원을 기본적으로 심리적인 치료가 매우 중요하다고 보여짐  지금 같은 코로나  로 인한 상황에서는 지금까지 겪지 못한 시기이기 때문에',
#  '요즘 청년들은 개인적인 성향과  취향이 확고해  그전이랑 다른건 같음    은둔과 고립이 더욱 심각한 수준인거 같기도 하다  각 지역 단체에   비슷한 성향 취향 토대로   기본적인 지원을 해준다면 마음 이 맞는 사람들끼리 소통이 되어서 더 많이 활동하지않을까싶기도함',
#  '상세한 대화상담',
#  '몰랐는데 이런프로그램은 중요하다고 생각합니다  주변에 고립은둔 으로 힘든 청년을 많이 봤습니다  저도 한때 그런경험이 있고 ',
#  '취미생활',
#  '새로운 취미를 가질수있는 온라인 교육서비스가 있으면 좋을거같아요',
#  '참여하고싶습니다  지원할수있는 방안을 알려주세요 부탁합니다',
#  '자립 의지가 있는 성실한      대를 도와주는게 더 효율적이라고 생각한다 ',
#  '홍보물을 보고 싶어요',
#  '상담페이지개설',
#  '외부로 이끌어내는 방법',
#  '홍보자체가 잘 안되어 있는것 같다 잘 모르는 사람들이 많아서 참여하기 힘든것 같다',
#  '   상담외에도 혼자 방문해서 다양한 엑티비티에 참여할수 있는 공간이 있었음 좋을거같다',
#  '지원정책에사각지대가없었음한다 ',
#  '캠페인',
#  '심리적인 도움',
#  '일자리지원을 위한 교육지원',
#  '고립 은둔 청년 입장에선 공무원이든 뭐든 번듯한 벌이와 가족이 있는 사람들이 찾아와서 관계를 맺자고 하는 일 자체가 불쾌하지 않을까요  심리상담 치료 재활 다 좋은데 그 전에 새로운 사람 만나는 거 자체가 피곤하고 불쾌합니다  과하게 노력하지 않았으면 좋겠고 코로나 때처럼 최소한의 생활이 가능한 지원금이나 꼬박꼬박 주면 좋겠습니다 ',
#  '고립  은둔 청년의 실질적인 이유가 뭔지를 알아야함 질문을 바꿔 보아야 함  우울한가요  말고   우울한 감정은 어디서 나오나요  어떻게 하면 더 나을까요  ',
#  '고립 은둔 청년들은 대부분 주눅이 들어있고 자신감이 결여된 경우가 대부분입니다  자신과 비슷한 사람들과 만나서 소통 능력을 기르고  사람들의 따뜻한 조언과 응원이 필요합니다  접근이 쉽고 무겁지 않은 소모임 형태로 모임 지원 등의 정책이 있으면 좋을 것 같습니다 ',
#  '심리적으로 힘들때 찾아갈수 있는 익명성을 띈 상담',
#  '상담지원',
#  '동네 청년과 연결시켜주기',
#  '조건을 완화하고 소득관계없이 누구나 신청이 되었으면좋겠다',
#  '대면보다는 비대면으로 서서히 시작해야할 것 같다 ',
#  '일회성이고 형식적인 지원보다는 실효성 있는 지원이 필요합니다 ',
#  '온라인교육 비대면프로그램',
#  '취업알선',
#  '비슷한 상황을 겪는 친구들끼리 함께 할 수 있는 운동 축구 농구 야구  등을 지원하고 열어야합니다 ',
#  '재정적 지원이 절실함',
#  '어느순간부터 집밥에 잘안나가게 되었는데 그냥 무슨계기가 있었던건 아니였습니다  일단 그래서 집에서 나가는것부터 하는게 좋을것 같아요  저는 누군가와 어색한 대화를 한다거나 이런걸 원하는게 아니니까 그냥 걷기운동이나  뛰기운동을 하는 산책시스템같은게 있으면 좋을것 같아요  그리고 일단 나오게하려면 동기부여가 필요한데 참석을 잘하는 사람에게는 상금을 준다거나 하면 좋을것 같아요',
#  '대출 빚에서 구제',
#  '금전적인 지원',
#  '생활비지원  자전거사용',
#  '우울해지면 일단 나가기가 싫습니다  도움되는 인터넷 강연이 도움이 될 것 같네요 ',
#  '상담과 관심',
#  '경제',
#  '인터넷을 이용한 다양한 캠페인',
#  '경기도에서는 정신과 및 상담 지원비 제공이 되던데 서울시도 상담과 실비가 되지 않아 치료비 지원이 되지 않는 장애나 질환 관련되어 제공 부탁드립니다 ',
#  '경제',
#  '경제적지원필요',
#  '취업지원',
#  '보여주기식의 일시적인 지원보다는 꾸준히 보살펴주는게 필요하다 생각 합니다 ',
#  '인력이 급하고 부족한 곳을 중심으로 먼저 취업할 사람의 국비 지원과 교육을 확충하고  이를 통해 기업과 연계하여 취업을 알선하고 보조금을 지급한다 ',
#  '복지혜택',
#  '좀더 자연스럽고 많은 대상에 수혜가될수있는정책',
#  '경제',
#  '온라인 친구가 되어준다 ',
#  '활발한 사회활동',
#  '경제력이 되어야 살 만하다고 그나마 느낀다',
#  '경제적 지원',
#  '거주 지원 단기간이라도 ',
#  '직접적인 일자리 연계 및 경제적 도움',
#  '돈 지원 및 일 체험 기회',
#  '전화  메신저 등으로 자주 안부를 물어주세요',
#  '정책홍보가 우선이다',
#  '집 밖에 나오려는것부터 어려움을 많이 느끼기 때문에 보다 쉽게 소통할 수 있고 부담이 없는 온라인채팅으로 시작해 점점 활동범위를 넓혀 최종적으로는 집에서 나올 수 있도록 돕는것이 좋다 생각합니다 ',
#  '온라인 커뮤니티 운영',
#  '우울감과 패배감에 빠지면 집안에서 나가는 것 뿐만 아니라 침대에서 일어나는 것 자체가 힘들어집니다  그로인해 근육손실도 일어나 육체적으로도 안좋아집니다  매 순간마다 일어나자 뭐든 해보자 하지만 하루살이 처럼 금방 져버리고 후회와 좌절감에 빠집니다  악순환이 반복되면서 길어지게되면 자포자기가 되버립니다  일본의 선례처럼 자발적 의지보단 주변의 도움  조금은 강제성이 있다면 조금이라도 일찍 사회복귀가 빠를지도 모르겠다 생각됩니다 ',
#  '많은 사람이 참여할 수 있도록',
#  '생활에 필요한 용품 사주기',
#  '고립된 청년들을 위한 단계적인 지원이 필요한것 같습니다 ',
#  '사람이 바뀌지 않는 한 프로그램은 아무 의미가 없습니다 자기 의지가 제일 중요합니다',
#  '스스로 고립 운둔된 사람들은 사람과의 관계를 가장 어려워하고 타인의 시선과 생각때문에 더더욱 숨으려 함  지원의 문제가 아니라 지원 상담자의 태도가 중요  상담자가 완전한 타인이고 낯선이인 이상 완전히 마음의 문을 열기는 힘들 것',
#  '걷기 챌린지  일단 나와서 걸으면 리프레시 되는 기분과 함께 움직임으로 얻게 되는 의욕이 있음',
#  '상담',
#  '온라인 및 휴대폰과 연계',
#  '상담 지원 강화  약물 복용시에는 일상생활이 어려운 경우가 많으므로 생활비 지원',
#  '병원에 가는걸 부담스러워 하지 않는 안내 등',
#  '주기별 방문하여 보살핌',
#  '직접 찾아가면 좋겠어요',
#  '병원비 지원 같은 실질적 도움을 줄 수 있는 방안도 있으면 좋을 것 같습니다',
#  '적극적인 보살핌과 지원금 지원',
#  '정신적 치료와 함께 경제활동까지 연계해서 지원해주는 프로그램',
#  '병원가기 지원',
#  '온라인으로 하다가 연락이 안된다면 찾아가보는 것도 방법인 것 같습니다',
#  '화상 연락 서비스',
#  '여러 매체를통한 홍보',
#  '상담  생활 지원',
#  '심리적으로 안정을 찾을수 있게 상담치료',
#  '다시 사회생활에 적응할 수 있도록     상담 필요',
#  '적극적인홍보',
#  '관심있는 취미 및 여러 분야의 공통점을 가진 사람들끼리 모아 흥미를 일으킬 수 있는 프로그램 개발 및 참여유발',
#  '고립 은둔 청년을 가려내는 기준부터 설명해줬으면 좋겠다',
#  '정서적안정과 공감대 비밀우지',
#  '상담을 통한 근본적인 문제 찾기',
#  '매일 안부 연락나누기',
#  '고립된 청년들이 대상이므로 자주 사용하는 채널을 통한 홍보  쉽게 지원하고 이용할 수 있도록 이용 대상자 확대 등',
#  '취미 운동프로그램으로 단합력을 가지면 좋을듯',
#  '주택청약 공급과 매매가 하락',
#  '서울시에서는 고립 은둔 청년을 지원할 수 있는 다양한 방안을 찾고 있습니다  여러분이 생각하실 때 필요한 정책이 있다면 자유롭게 써 주세요   없다면 다음페이지로 이동 ',
#  '상담사는 유능한 사람으로 뽑아야 하고 고립 은둔 청년에게 접근할 때 조심스러운 방식으로 해야 한다 ',
#  '자주 통화해주기',
#  '매일 아침이나 저녁에 운동하는 모임에 참석하기',
#  '경제살리기',
#  '사업을 하고 있는데 수입이 제대로 벌여들이지 않는 청년이 부수적인 수입을 위해 투잡을 필요로 할때 이를 지원해주는 제도가 필요함',
#  '약물  상담 치료보다 몸을 움직여서 활력을 불어넣을 수 있는 둘레길 걸으며 쓰레기 줍기  한강변 걸으며 쓰레기 줍기 등의 활동을 하면 좋을 것 같다  주변 자연도 보고  뭔가 좋은 일을 한다는 뿌듯함도 함께 얻을 수 있을 듯 ',
#  '경제적 지원과 코로나 백신 부작용 지원 온라인 서비스',
#  '취업및 생계유지가 잘  으면 좋겠다',
#  '청년들이 왜 고립되고 은둔생활을 할 수 밖에 없는지 그 원인을 파악하여 진정으로 필요한 부분을 채워졌으면 합니다  사람 각 개인에 맞춤형 해결책 제시',
#  '일단 홍보가 덜 된 것 같다  홍보를 해서 참여자를 늘리고 고립된 대부분의 청년은 정신적인 고립에서 이어진 것이라고 생각한다  무조건적인 경제적 지원이 아닌 대인기피증 등의 질병을 서서히 치료해 가며 사회생활 및 경제활동을 하도록 일자리를 고안해서 지원하는 것도 좋아보인다 ',
#  '단기적인 사업이 아닌 진심으로 도움이 필요한 청년들을 장기적으로 지원하기 위한 노력이 필요하다 ',
#  '바우처',
#  '고립운둔 청년들이 다시 사회로 나갈 수 있도록 여러방면으로 지원',
#  '적절하고 직접적인 도움',
#  '취업연계프로그램',
#  '상담',
#  '생활비지원',
#  '문화센터지원',
#  '다양한 프로그램이 있어서 선택가능하게',
#  '적극적인 심리상담이 필요하다 본인뿐만 아니라 가족에게도 해결책을  적극적으로 알려줘야할듯',
#  '프로그램 개발',
#  '사회생활에 적응 할수 있도록 경제적 지원을 해줬으면 좋겠다 취업지원 프로그램이 체계적으로 이뤄졌으면 좋겠다',
#  '경제적 지원은 반드시 필요한 것 같다',
#  '청년의 나이라고 하면   대를 생각할수 있는데 나이가 많은 사람도  참여할수 있는 기회가 있음한다',
#  '경제적지원  경제적인 어려움으로 외출을 꺼리게 되고 활동이나 공부 등을 시도하기 어려움',
#  '은둔 청년들끼리 네트워크 형성을 하여 같이 헤쳐나갈 수 있는 시스템을 만든다',
#  '장기간의 금전적 지원',
#  '대면 비대면이 적절히 섞이면 좋을 것 같다',
#  '매일 규칙적으로 활동할 수 있는 일자리 혹은 비용지원  무난한 단시간 일자리  어렵지않은 일과 편안한분위기 사람들 시니어분들 바리스타하느누카페처럼    운동이나 취미 비용지원    고립 은둔한 사람끼리 모여서 이런모임을 주최한다면 더 꺼려지고 무거울거같아서 자유로이 취미로 자신을 독려할 수 있는 비용지원이 나을거같고 그리고 상담   퀄리티있는 전문가 상담이 절실합니다 정말    ',
#  '취업을 연계해주고 지원해주면 좋겠다',
#  '심리상담',
#  '함께 취미활동 및 운동  봉사하기',
#  '돈줘야함',
#  '은둔청년에게 일자리 취업이나 다양한 활동이 가능하게 연계가 되면 좋을것같다',
#  '직접적인 복지가 실행될 수 있게 해주세요',
#  '본인이 사회에 나올 의지가 없거나 있어도 공포가 클것같아서 자발적인 참여는 적을것같아요   가족이 먼저 이런 프로그램이 있다는걸 알게되어야 은둔 청년에게 전달될것같아요',
#  '청년들 잘 부탁합니다',
#  '밖으로 나갈 수 있도록 만드는 그런 기본적인 ',
#  '성격 개조',
#  '정서적 안정 및 취미활동 지원',
#  '사람들을 만나 천천히 마음의 문을 열수있는 기회가 필요하다고 생각',
#  '취업 연계',
#  '이런 시설들의 위치적 접근성이 좋으면 좋을 것 같다',
#  '고민을 나눌수 있는 공간에 문자로 상담을 할 수 있으면 좋겠다',
#  '이런 식의 조삼모사  소 잃고 외양간 고치는 프로그램은 그만두시길 바랍니다  모든 것이 그렇듯이 경제적 사회적으로 시스템이 안정되고  기성세대의 희생을 청년들에게 권고하는 세태를 해결한다면 자연스럽게 적어질 것이라고 생각합니다 ',
#  '부동산 지원',
#  '익명성과 보안이 보장되어야 한다 ',
#  '취업장려금 지원',
#  '자살을 예방하기에 좋아보인다',
#  '심각한 고립으로 진행되기 전  경제 사정이 좋지않은 청년들을 위해 저렴하게 문화 생활을 할수있도록 문화비가 지원됐으면 합니다  혹은 청년들 주거지 근처에 무료로 이용할수있는 공원같은 시설이 더욱 많아졌으면 합니다',
#  '가볍게 채팅으로 운영하는 곳을 더 많이 찾을 듯하가',
#  '취업자리',
#  '여러 매체로 관련 내용을 홍보',
#  '사각지대에서 발견하지 못하는 문제나 고립 은둔 청년을 적극적으로 찾아내고 지원하려는 노력 경주',
#  '밖으로 나가는것과같은 가장 기본적인 것에서부터 시작',
#  '심리상담',
#  '지속가능한프로그램',
#  '적극적 홍보',
#  '찾아가는 서비스 함께하는 운동',
#  '저도 환경이 어려운데 같이 필요한 프로그램 지원서비스가 있으면 좋겠습니다',
#  '경제적 지원 및 심리 상담',
#  '효과적으로 많은 사람들한테 알려야 할 사업인것 같다 그래야 가족이든 지인이든 소개해줄수 있으면 좋겠다',
#  '적극적인 홍보',
#  '여러만남을 주선해줘으면',
#  '지속적인 관심과 홍보',
#  '전혀 몰랐던 정책이라  좀더 많은 홍보가 필요할 것 같다',
#  '이런 제도가 있는지 모르는 사람이 대부분일듯 합니다  홍보가 되면 좋겠습니다 ',
#  '더 적극적인 정부지원이 있었으면 한다',
#  '자각지표',
#  '작은 성취감을 쌓을 수 있는 정책 필요 적당히  개월 꾸준히 하면 바로 아웃풋 나오는 정책들로 자존감 높여줘야함 이를테면 현 취업  개월 과정 수업은 가장 큰 문제점으로 아침  시부터  시까지 직장인 수준     개월 과정 형성     은둔청년들도 나름 열심히 해보려고 들었다가 또 패배감 느끼는 부분',
#  '같은 처지에 있는 사람들과 대화하기',
#  '친구  기타 동성 지인  명 혹은 가족과 함께하는 활동 지원이 필요하지만 낯선 사람을 만나기 싫어하는 청년이 주변에 있음 으로 교통비 등이 지원됨',
#  '장기적으로큰그림을그리고 연계해서 꾸준히가야한다',
#  '부자들 때문에 자괴감이 든다 제발 취업좀 시켜 주세요',
#  '함께할 수 있는 프로그램',
#  '쉬운 접근성',
#  '의욕을 충전할수있는 활동',
#  '홍보',
#  '경제적지원',
#  '홍보가필요함',
#  '홍보도 부족하지만 다양한 채널로 유입할 수 있게 했으면 좋겠네요',
#  '본인들이 하고자하는것을 발견해서  개월간의 경제적 지원을 해줬으면 좋겠다',
#  '헬스장 연계나 운동모임 결성',
#  '생활반경 이내에서 이루어지는 지원사업',
#  '자주 연락해주세요',
#  '고립되거나 은둔하고 있는 청년들이 먼저 도움을 요청할 수 있는 방법이 있으면 좋겠다',
#  '관리하는 책임자들의 능력과 도덕성 고려가 필요',
#  '보상적인 모임',
#  '온라인을 통해 비슷한 처지에 있는 이들을 연계하는 방안',
#  '청년들이 고립되고 은둔형이 되는 이유 중 하나는 살아갈 희망이 없다고 느낄때라고 생각합니다  특히 서울에서 살아가기란 쉽지 않다는것입니다  대인관계  일  주거  의료비  결혼  자녀유무 등 희망을 잃지 않도록 실질적인 도움을 주셨으면 좋겠습니다 ',
#  '일자리 창출',
#  '비용적인 지원이 필요',
#  '관심을 갖고 정기적인 활동 필요',
#  '돈을 지원해준다',
#  '요리 클래스 같은거 추천드립니다',
#  '인터넷 셧다운 중독치료',
#  '학교를 다니고 있는 사람은 아무런 지원을 받을 수 없는지  대학생의 나이   이하 면서 학교 재학 상태가 아닌 사람은 받을 수 있는지 궁금한데 없다면 이에 관해 마련하는 것도 좋을 수 있지 않을까 생각합니다 ',
#  '많은 지원 이벤트를 해주세요',
#  '알기쉽게  나이에 제한을 두지 말아야하며  경제적인 지원과 취업지원도 병행해야한다',
#  '금액지원',
#  '문화 프로그램을 통한 인간관계 형성',
#  '진압 진로 같이 탐색하고 찾아봐주기',
#  '    온라인등 홍보강화 하면좋겠습니다 ',
#  '사각지대에서 소외받는 사람듯을 위한 정책',
#  '내일배움카드같은 시스템이 더욱 다양하고   활발해 음죠캣따  ',
#  '지원자격이 완화된 다양한 방안이 필요하다고 생각한다',
#  '정신 및 심리상담은  대  및 가족과 단체로 하고  경제적인 지원은 개인적으로 했으면 좋겠습니다  지원금을 가져가는 가족과의 분리를 위해 ',
#  '보여주기식 지원이 아닌 진짜 필요한 사람들에게 어떻게 하면 지원해줄 수 있을지 고민해보기를 바람 공무원들 일이 항상 그럼',
#  '탁상행정좀 그만했으면   ',
#  '취미프로그램 개설',
#  '서울시의 홍보를 통해 적극적으로 고립 은둔 청년들을 도와주었으면 한다',
#  '일상적으로 경제활동을 할 수 있게 만들어주는것',
#  '좋은 방안이지만 고립 은둔이라는 단어처럼 실제 그렇게 생활하는 사람은 주변에서 누구도 알아주지 않기 때문에  혹은 자발적으로 자신이 이겨내야겠다는 의지가 생기지 않는이상  이 정책이 실질적으로 해당자를 파악하여 시행할 수 있을지 의문입니다 ',
#  '심리치료 놀이활동',
#  '상담센터',
#  '온라인상담',
#  '대학에 갈 수 있도록 학비 지원',
#  '그들에게 부담이 되지 않게끔 했으면 좋겠다 ',
#  '지속적인 정신적 도움',
#  '찾아가서 상담 서비스',
#  '편안한 분위기',
#  '자립지원금',
#  '   로 찾으면 많을듯',
#  '다양한사람들과의 활동',
#  '    개인 지도',
#  '개인이 스스로 그 고립을 헤치고 나와야 하기 때문에 굳이 필요한 정책이 없습니다 ',
#  '많은 홍보를 해서 꼭 도움이 필요한 사람이 도움을 얻어갔으면 좋겠따',
#  '홍보',
#  '적성검사를 통해 일자리를 만들어준다 ',
#  '목적 없이 살아가는 은둔형 청년들을 위한 실질적인 취업 또는 경제적 지원',
#  '어려운 분들에게 실질적으로 도움이 되면 좋겠네요',
#  '홍보',
#  '비대면 상담',
#  '중장기적인 지원이 필요함',
#  '다양한 홍보',
#  '실제 자유롭게  경제활동을 할 수있도록 해야한다',
#  '히키코모리들이 주로 애니 이런거를 좋아 하니깐 일본 유명 애니 페스티벌을 개최해서 비슷한 친구들끼리 모일수 있도록 만들어 준다',
#  '취업을 시켜주세요',
#  '최대한 사회와 유대감을 느낄 수 있게 만들어야합니다',
#  '고립청년에게 지원할 수 있는 방안도 중요하지만 복지계열 전공자가 아니면 모르는 상황이 더 중요하다고 생각합니다 ',
#  '전문적인 좋은 검증된 선생님들이 이런 사업에 참여해야 합니다 ',
#  '경제적 지원이 무엇보다 가장 좋은 해결책 같다',
#  '비슷한 또래친구들은 어떤고민을 하는지 알 수 있도록 모임을 만들면 좋을 것 같습니다 ',
#  '자주 방문하기',
#  '다양한 정책들이 생겨났으면 좋겠습니다  감사합니다 ',
#  '지속적 관리',
#  '다양한 일자리 제공',
#  '이런 정책이 있다는걸 홍보 등으로 알려주세요',
#  '비밀유지',
#  '체험',
#  '젊은 우리 청년들은 취업이 하고 싶어요 취직좀 시켜 주세요',
#  '실업청년들이 많다 취직의 길을 많이 열어주면 좋겠다',
#  '누구도 버림받지 않는 사회부터 만들기',
#  '사회성에 대한 교육이 있었음 좋겠다 대화스킬  상대방에대한 이해 ',
#  '쉽게 참여할 수 있게 해줬으면 좋겠다',
#  '금전지원정책',
#  '비슷한 분들끼리 취미 생활처럼 즐겁게 일할 수 있는 것들이 마련되어서 경제적 도움도 되면서 다른 분들과 소통할 수 있었으면 좋겠다 ',
#  '지속적인 상담 지원이 이루어졌으면 좋겠습니다 ',
#  '보편적 복지로 도움을',
#  '심리상담 지원 및 그룹 활동',
#  '찾아가는 서비스',
#  '부끄럽고 어려운 일이 아니라는 적극적인 홍보가 필요하다 ',
#  '자연스러운 지원',
#  '온라인에서 쉽고 빠르게 신청하되 본인이 신청하게끔 금액을 높혀준다',
#  '인터넷',
#  '경제 지원',
#  '금전적 지원 정책',
#  '격려금 지원혜택',
#  '비슷한 처지 사람들끼리 모이기',
#  '사회로 끌어내주어야하며 하는것은 하루이틀로 되는것이 아니니 긴 시간 지원가능한 정책이어야한다',
#  '잘 해줬으면',
#  '청년들이 꼭 취업을 할게 아니라  자신의 장점과 특기를 잘 발굴할수 있는 프로그램과  그 장점을 살려 창업을 할 수 있도록 창업지원도 많이 늘려주세요   아니면 무이자대출이나 저금리 대출도 좋아요   그리고 청년두배통장 같은 것도 현재 직장을 안다니고 있어도 사대보험이 없어도  프리랜서도 적은 소득으로도 자산을 형성할수 있는 기회도 늘려주세요 ',
#  '은둔 청년을 잘 찾아내는 것이 중요',
#  '가볍고 거부감없게    로 치료를 시작해보는게 좋을거같다',
#  '적극적 홍보',
#  '일자리를 더 창출해내야한다 ',
#  '사회로 나갈수 잇는 디딤돌',
#  '근본적인 원인 해결이 필요하다 단편적으로 형식적인 지원은 무의미하다',
#  '가출청소년보호',
#  '지원을 하더라도 조심스럽게 접근해야 할것 같다',
#  '친구의 신고',
#  '일저리 제공',
#  '홍보  처음 들어보네요',
#  '밖으로 나오면 어쨌든 돈을 써야 한다  그래야 뭔가 작은 경험이라도 시도해볼 수 있다 따라서 경제적 지원도 중요하고  무조건적으로 말을 들어줄 사람도 필요하다  그렇지만 깊은 관계는 어려워하는 것이 청년의 특징인 것 같다',
#  '내 가족이다 생각해주세요',
#  '수시로 전화를 통해 모니터링을 실시한다',
#  '소수가 아닌 다수에게 지원해줬으면 좋겠다 ',
#  '본인부담이 있다면 하기 힘들것 같으니 무료면은 좋겠고  만약 힘들다면 전화상담도 좋을것 같다',
#  '음식이나 제품 등 물질적인 지원',
#  '취업난에 직장을 얻을 때까지 경제적 지원이 필요',
#  '경제적 지원 및 심리치료',
#  '실질적인 대책 마련',
#  '은둔형 외톨이는 그렇게 쉽게 밖으로 나오려고 하지 않는다  자동이 아니다  수동적으로 움직이는 사람들이라 적극적으로 밖으로 끌어내는 게 필요하다 ',
#  '실질적 도움',
#  '전문가 양성',
#  '고립이 되면 아된요',
#  '고립된 청년들을 찾기 위해 주변 종교시설 같은 곳에 연계해서 하면 좋을거 같다',
#  '단기간의 재정적지원과 추후 좋은 취업자리를 알선',
#  '자신감 얻을 수 있는 활동과 사람과 자연스럽게 어울릴 수 있는 프로그램이 필요',
#  '돈을 지원해주는 것이 아닌 실질적 도움이 됐으면',
#  '정의부터 명확히 그들의 선호도 확인 필요 고립이나 은둔한다고 문제가 있다는 것인지 ',
#  '단발성이 아닌 지속적인 모니터링이 필요합니다 ',
#  '이런 정책들을 다양하게 많이 만들어주고 접근하기 쉽도록 많이 홍보해주세요',
#  '정신건강 바우처를 잘 제공하면 좋겠다',
#  '임대주택 지원',
#  '사회적 친구가 필요함',
#  '삶의 의지와 희망을 되찾기 위한 경제적 지원 및 장기 상담 프로그램 지원이 필요하다',
#  '경제적지원',
#  '브라우저에서 가장 즐겨 하시는 활동은 무엇입니까 ',
#  '꾸준한 관심',
#  '인터넷에서 다양한 교육 프로그램을 만든다',
#  '서울시의 정장 대여 및 취업연계 프로그램 너무 좋습니다     고립하고 은둔하는 이유는 무기력증에 빠져서인데   무기력증을 탈출할 수 있는 심리치료나 주변에 친구를 만들수 있는   기회가 생기면 좋을 것 같아요',
#  '적절한 심리 진단 및 치료 후 파트타임 공공 일자리 등을 주선해주고 차후에 노동 상담도 병행해서 계속 진행해주면 좋을 것이라 생각됩니다',
#  '고립 은둔을 탈피하려면 다양한 활동을 할 수 있는 기회가 있어야 합니다   요즘 청년들은 취미 같은게 딱히 없는 경우가 많아 더 그런 경우가 많을 것 같습니다   직업과 교육 보다는 취미 여가를 즐기는 방안을 모색해야 할 것 같습니다 ',
#  '실제 도움이 필요하지만 복지 사각지대에 있는 청년들이 해당 프로그램 자체를 모르고 있을 수 있으니 찾아가는 복지 서비스를 실행한다는 마음가짐으로 적극적인 홍보와 지원에 열을 올려야 한다 ',
#  '일단 그 분들을 밖에 나오게 하세요  그리고 일단 즐겁게 노는 것이 중요할 것 같습니다 ',
#  '지원은 더이상 그만  ',
#  '일본처럼 운둔하는 청년들이 숙소에서 생활하며일을하고사회 생활을 하게 했으면 한다 ',
#  '맨토 및 대화하기',
#  '또래 연령들과의 모임도 좋을듯',
#  '오락활동지원',
#  '인터넷 검색창에 찾는것보다 저절로 보여지면 충분히 알수있고 주위에 전할수 있다',
#  '한달동안 몇번 이상 출석을 하면 생활비를 지원해주는 정책이 있었으면한다',
#  '가정방문',
#  '내가 가지고 있는 재능을 나눠주고 싶다',
#  '찾아가는 서비스',
#  '장기 실업자에게 일괄문자 부탁합니다',
#  '같이 취미 활동',
#  '심리 상담 및 솔루션 제공',
#  '메신저     등 많은 사람들이 알수있으면 좋겠다',
#  '정책도 중요하지만 좀 더 다양한 방법의 홍보가 필요해 보인다 ',
#  '확실하게홍보',
#  '다양한 복지정책',
#  '정기적인 소모임',
#  '경제',
#  '가족이 신청할 수 있도록 도움',
#  '힘든사람들 많이 도와주세요',
#  '관심',
#  '미디어 매체 등을 통해 정책홍보 필요',
#  '어려운 청년 발굴 및 경제적 지원',
#  '심리 치료 위주가 필요한듯',
#  '홍보',
#  '서울시는 탁상행정만 하는 곳으로 시장이 친일에 가까움',
#  '찾아가는서비스',
#  '응원하는 영상 같은걸 많이 만들어 휴대폰  티비에 많이 노출 하는 것이 도움될 것 같아요  그 외에는 자신의 의지   ',
#  '혼자서 나서서 누가 지원하는 사람은 없을것이다 이러한걸 알고 누가 지원해보라고 말을 하거나 추천으로 해주는것도 나쁘지않을꺼 같다',
#  '직접 집으로 찾아가도 좋을것같아요',
#  '숙식제공',
#  '단편드라마나 영상매체 등으로 조금 늦게 취업되어도 괜찮다는 메시지가 담긴 미디어가 많았으면 좋겠습니다  취업이 힘들어 극단적 선택을 하는 청년이 증가하고 있다고 하는데  무심코 본 영상에 위로가 되어 속 시원히 울고 조금이라도 더 살아보는 계기가 될 수 있는 매체가 있었으면 좋겠습니다 ',
#  '숨어있는 청년이 생각보다 많으니 잘 찾아서 지원할 필요가 있다',
#  '모임을 만들어준다',
#  '자기개발 지원 극복하는 방법 더 깊은 고립에 빠지지 않는 방법',
#  '비대면 화상 상담',
#  '코로나 지원금처럼 월 고정적으로 소액이라도 지원되었으면 좋겠다 ',
#  '연애중개사업을 실시한다',
#  '밖으로 이끌어낼 방법을 생각해야 한다',
#  '세금낭비',
#  '은둔했던 경험상 애초에 자발적으로 도움을 요청할 수 있는 상태는 이미 혼자서 거희 다 극복한 단계  여기서 다시 사회로 나갈 수 있도록 마음을 다독여주는 것이 필요하다고 생각합니다  경제적 지원이나 교육도 좋지만  무엇보다 진심으로 얘기할 수 있도록 심리상담에 더 많은 비중을 두고 정책을 마련해주세요 ',
#  '경제적 지원',
#  '체계적인 시스템 지원',
#  '인터넷 커뮤니티 사이트에 배너 광고를 해보는 게 좋을 것 같습니다  랜덤채팅 등 시간을 죽이기 위해서 사람들이 오래 사용하는 곳',
#  '정신병원 치료 및 약물이 보험적용과 혜택을 받으수있았으면 좋겠습니다',
#  '경제',
#  '세상과 소통되지 못한 채로 자책하는 청년 및 청소년들이 많습니다  신청하는 절차보다는 먼저 찾아갈 수 있는 서비스가 개발되면 좋겠습니다  특히 학교에 있는 청소년 중 위험한 학생들이 꽤 많은데 교사로서 도움을 줄 수 있는 부분은 굉장히 한정적이어서 안타깝습니다 ',
#  '청년 봉사 모임 정신치료지원금 지급',
#  '요리수업',
#  '예산을지윈',
#  ' 인 가정이 누릴 수 있는 인프라와 제도를 제공해준다',
#  '다양한 지원자금 정책 부탁드려요',
#  '개인이 직접 신청하지 않는 경우도 있을 것으로 생각되어 주변인이 대신 신청하여 대상자를 확인하고 지원하는 방안도 필요할 것 같다 ',
#  '카카오톡 등을 통한 정책홍보',
#  '언제든   시간 대화할 수 있는 상담 서비스',
#  '전체적으로 많은 지원을 해야 한다고 생각합니다 ',
#  '친목이 중요할듯',
#  '다양한 교루와 대화',
#  '취업을 장려하는 원데이클래스',
#  '지원금',
#  ' 회성이 아닌 지속적인 케어가 가능한 활동을 진행하면 좋을 듯 함',
#  '고립이 될 정도의 사람은 이렇게 귀찮은 절차로 신청하지 않을것 같습니다 ',
#  '설문조사를 통한 지원',
#  '  세 이상 무직 자를 찾아서 상담필요한지 물어보는게 좋은듯 ',
#  '비슷한 경험자들과 함께',
#  '청년 교류',
#  '정신적으로 힘드신분들에게 도움이 많이 되셨으면 좋겠습니다',
#  '심리적 고위험군 대상 발굴 치료',
#  '메신저 같은 걸로도 진행하면 좋을거같아요 ',
#  '정기적 관심가지기 위한 녹즙배달',
#  '심리적 지원',
#  '정서적 교류',
#  '비대면으로 상담',
#  '편하게 오갈 수 있는 오프라인 장소가 있으면 좋을 것 같다  굳이 뭔가를 하지않아도 편하게 앉아만 있을 수 있는 조용한 장소',
#  '스포츠 활동에 대한 지원이 있으면 좋을 것 같다 ',
#  '꾸준히 하고 싶을 만한 흥미 취미를 만들어주세요 신청조건이 어렵지 않고 접근성이 좋고 은둔 고립이라는 단어로 내가 이 활동에 참여하면 정서적 불안한 사람을 인증하는건가 싶은 생각이 들지 않도록 홍보해주세요',
#  '잘 보살펴주시면 좋겠습니다',
#  '고립된 청년들은 밖으로 나올 기회가 필요합니다 두려움을 극복하고 세상밖으로 나갈 수 있게 해 줘야 합니다 ',
#  '고립 은둔 청년들이 외부적으로 쉽게 참여할 수 있는 공간을 허락해 오프라인을 나올 수 있도록 하는게  순위라고 생각',
#  '같은 내용의 심리상담이 반복되지 않았으면 좋겠습니다   경험상 주기적인 상담에 같은 내용만 반복적으로 듣다보면 치료에 대한 회의감이 들더라구요  ',
#  '성격에따른 지원방법',
#  '신원을 잘 보장해줘야함',
#  '사회에 적응 할 수 있는 전문적인 프로그램이 있었으면 합니다',
#  '정기적인 심리상담과 무기력함 타파를 위한 활동지원',
#  '취업 알선이 좋을것같다',
#  '소통을좀 더 했으면 좋겠습니다',
#  '자조모임 만들기  본인의 우울함을 주변 사람들에게 지속적으로 말하다 보면 주변사람도 지치게 되고  우울증을 겪는 당사자는 본인의 우울함에 지친 주변인을 보며 더욱 마음을 닫고 혼자 고통스러워하게 되고 더 고립됩니다    괴로움을 말로 표현해 풀 수 있도록 지원해주는 자조모임 지원 필요',
#  '청년 상담 알림이',
#  '돌봄 서비스',
#  '찾아가는방문서비스',
#  '사람들과 만날수있는 활동',
#  '매주 긍정적인 레터 제공',
#  '종교활동을 할 수 있게 해준다',
#  '취미 및 직업 연계   여행 프로그램   챌린지 등등',
#  '전반적인지원',
#  '심리적이나 경제적인 지원',
#  '일단 그런 사람을 찾기가 힘들 것 같다  왜냐하면   대들은 더군다나 그런 사람들은 아예 사회와의 단절을 통해 고립되었기 때문에 찾기도 힘들 것 같다',
#  '각종 상담레터 제공',
#  '상영중인 영화 초대',
#  '돌봄지원',
#  '전체적으로 관심이 있어야 함',
#  '교육복지',
#  '많은 지원이 필요하다',
#  '고립 은둔의 이유가 취업이라면 우선 경제적 지원과 심리적인 상담이 제일 필요',
#  '여러 홍보',
#  '경제',
#  '대부분 청년이 고립되는 이유로 취업문제라 생각합니다  그러기에 질 좋은 일자리를 만드는게 가장 근본적인 해결책이라고 생각합니다 ',
#  '취업일자리지원 취업 역량 강화 지원 정신적 치료 지원',
#  '커뮤니티에 글을 쓴다',
#  '서울이 아닌 자연환경이 좋은 도시로 일정기간 혼자 생활할수 있는 연계 생활 시스템이 있어서 원할 경우 경제적 부담없이 다른 도시에서 살아보기가 필요하다 ',
#  '경제적 지원',
#  '응원합니다',
#  '좋은 지원프로그램으로 지원',
#  '고립 및 은둔 청년들이 제일 많이 활동을 보이고  자칫 잘못된 길로 빠질 수 있는 유일한 공간이 인터넷이라고 생각합니다  다양한 분야의 홈페이지 및 포털 사이트에서 지원 프로그램의 존재를 알리고  해당 프로그램에 관심을 가졌을 때 자연스럽게 합류할 수 있는 시스템을 구축하는 것이 좋다고 생각합니다 ',
#  '용돈 지원',
#  '그런 청년들을 이해할수있는건 또래친구들밖에 없다고 생각은 드는데 전문적인 인력이나 전문가로 대체하기 어렵다면 청년지원자를 받는것도 좋아보인다고 생각합니다',
#  '무엇인가를 할 의지나 마음의 준비가 안됐기때문에 그들끼리 서로 모아서 소통과 여러 프로그램을 하는게 좋다고 생각함',
#  '보통 밖에 잘 나가지 않는 이유 중 큰 하나는 밖으로 나가서 뭘 하려면 돈이 들어가기 때문이다 경제적 여유가 없는 지금 상황에서는 자연적으로 밖에 나가지 않게 되고 자발적 은둔이 되는 것이다 누군가를 만나는 것도 돈이 든다 이 경제적 상황이 해소되지 않는한 일명 은둔 청년은 쉽게 줄어들지 않을것이다',
#  '경제적인 지원도 좋지만 그 사람이 스스로 참여할수있도록 사회와 가까워지는 훈련이 필요하다고 생각함',
#  '정보에 대한 알림이 중요하지만 그렇다고 강요하거나 강제하는것은 어려운 일이니 자연스럽게 참여할 수 있는 프로그램의 개발이 중요하다고 생각함 프로그램 제목에 직접적으로 은둔 등의 단어가 부적절해보임 ',
#  '사람들이 모여 이야기 하며 교류할수있는 자리',
#  '청년에대한취업알선',
#  '취업 지원 프로그램 운영',
#  '경제적지원',
#  '봉사를 통해 도와요 ',
#  '동아리 활동으로 청소년들의 자주의식을 함양하게 해야한다 ',
#  '지원금을 줘야판다',
#  '이런정책이 더 발전됐으면 좋겠습니다',
#  '시간 잘 지키고 차별없고 평범한 그런 일자리를 얻고싶다  매번 워크넷이나 취업청년지원센터같은 경우 아는사람은 알고 모르는 사람은 모르다가 끝나는 경우도 다반사다  맨날 노인 일자리만 창출하다가 끝나버린 문정권이 되질 말았으면 좋겠다  문자같은 지원도 아낌없이 해주었으면 좋겠다 ',
#  '담당 공무원의 도덕  인격적인 수준이 적절해야함이 중   ',
#  '보통 고립되거나 은둔하고 있는청년들은 마음에 상처가 있기마련이라 조심스럽게 접근해야합니다 개개인에 최대한 맞춰서요 마음이 안좋을수도있고 경제적인 부분때문일수도있겠죠 경제적인부분은 경제적 지원만 충분하다면 벗어날 확률이크고 마음적인부분은 지속적인 관찰과 지원이 필요합니다 기대로부터 오는 상실감이 크니까요 첫문을 열기도 여려울수있습니다 이런말이있죠 책임질거 아니면 건들지 말라고 그런마음으로 지원해줘야해요 단순히 지원만한다고 다인게 아니라는겁니다 경제적지원은 나눠서 최대한 의무적으로 밖에 나가서 무언가를 할수있게끔 시스템되어야하고 지원대상을 제외한 다른사람에게는 비밀보장이 되어야합니다 정신적 지원도 마찬가지구요 치료나 사회생활을 할수있게 만들어줘야해요 물고기를 주는게 아니라 물고기를 낚고 손질하고 직접 만들어서 상차리고 어떻게 먹는지 상은 어떻게 치우는지 다 알려줘야합니다 말그대로 어떻게 해야 이세상 살아가는지 사람들과 어울릴수있는지 꼭 이 설문들에서 좋은 부분들 모으셔서 모두에게 도움되는 정책 만드셨으면 좋겠습니다',
#  '취미프로그램 찾기 재정적지원',
#  '경제적 지원과 심리치료또는 심리상담을 전문적으로 받을 수 있는 기회가 있었으면 좋겠어요',
#  '학교와 같은 형식으로 등교하며  교육및 재활을 하고 교류를 같는다',
#  '응원합니다',
#  '금전적 지원',
#  '경제 지원',
#  ' 대  상담 심리사 정책이 생겼으면 좋겠습니다 ',
#  '방문서비스',
#  '고립 청년을 위한 전화상담',
#  '경제적 지원이 극빈층에만 집중돼서 극빈층 위 계층은 경제적 지원은 덜 받으나 온 몸으로 시련을 겪고 있음  서울시 청년 지원 사업 대상자 수를 늘리고 취업 연계나 취미 활동을 지원하고  특정 단계를 달성하면 지원금을 지급하는 식으로 목표 지향형 지원금 제도를 구축해야한다고 봄 공기관의 성과에는 목표 달성율을 반영시키지 않되  대상자의 취직 여부나 만족도 조사등을 통해 공기관의 성과에 반영하는 등 결과지향형이 아닌 과정지향형 성과 달성율 기준을 도입해야 한다고 봄 결국 중요한 건 팩트가 아니라  지원받는 청년의 마음이 편해졌는가 여전히 불편한가 하는 주관적 만족도임  ',
#  '청년들의 문화생활비 지원',
#  '상담',
#  '거주지 찾아가보기',
#  '서울에 한국인구 절반이 모여있는것 자체가 큰문제임',
#  '지원금',
#  '스스로 나오지않고 고립하고 은둔한 사람을 어떻게 찾아낼것인지 그거부터 해결필요',
#  '공부기회제공',
#  '다양한 취미활동을 만들 수 있는 프로그램',
#  '금전적 지원',
#  '영화관 초대',
#  '향후 취업이나 학업의 금전적 지원까지 같이 들어갔으면 좋겠습니다',
#  '왜 은둔생활을 하는지 알아보고 그 원인을 해결해 줄수 있으면 해결까지 해준다',
#  '생활비지원',
#  '고립 은둔 청년을 위한 맞춤형 일자리나 자립 지원',
#  '경제적 지원을 해줘서 다같이 놀고 편안한 분위기에서 뭔가 재미있게 할 수 있으면 좋을것같음',
#  '경제적인지원을 해주시면 좋을거같아요',
#  '경제적 지원도 지원이지만 취업지원 및 기회가 가장 중요하지 않을까 문제는 양질의 직업이 있을리도 없고 되지도 않는다는 거겠지만',
#  '거주외국인에 대한 지원폭 확대',
#  '방문 상담 및 친밀감 조성',
#  '체크하다보니 제가 고립청년처럼 느껴졌는데 저는 아니고   저 말고 분명 구석탱이에 박혀있는 청년들이 많을텐데 걔네는 이정도로는 절대 밖으로 안나옵니다   그들은 불특정한 누군가를 만나는 걸 싫어해요',
#  '금융지원 ',
#  '나는 자발적 은둔청년이지만 이런 자발적 은둔청년에게도 지원금을 줬으면 좋겠다',
#  '은둔 고립이 생기는 본질적 이유는 경제적 불안함에 미래를 걱정하는 심리적 압박이 강하여 일도 사회생활도 하고싶어하지 않은거라 생각합니다 ',
#  '소통을 더 하기를 바랍니다',
#  '우울증과 고립감을 겪고 있는 심리적 불안정자들을 대상으로 한 심리 치료 프로젝트와 자격증 개발 연계 프로젝트',
#  '금전적 지원',
#  '홍보를해서알라자',
#  '보호 시설과 교육',
#  '사교 모임도 참석하게 해주면 좋을것같다',
#  '사람들끼리 만나서 얘기할수있는거',
#  '심리상감하면좋울둣',
#  '   ',
#  '친구를 만들어주는 프로그램을 만들면 좋을 것 같습니다 ',
#  '고립 은둔 청년은 스스로 사회에 나오고자 하는 의지가 부족하기에 신고를 받고 적극적으로 접촉하는 과정이 필요할 듯 하다 ',
#  '상담에 대한 장벽 없애기',
#  '심리치료에 대한 지원을 할것',
#  '확실한 지원책',
#  '경력 필요 없이 배울 수 있는 일자리 같은 게 있으면 좋겠다',
#  '계속 집에있는 사람들을 위해서 일정한 시간 주마다 반복적으로 신체적 활동에 관한 교육프로그램이 만들어져야 할거 같다 ',
#  '신청해야만 받을 수 있는 환경이 문제입니다  신청할만큼 알아보고 지원하는 사람들이라면  적어도 본인의 상황을 개선시킬 힘이 있는 사람이라 생각합니다  고립  은둔으로 극악의 상황에 놓여 아무것도 할 수 없이 나약해진 사람들은 서울시에서 그 어떤 프로그램을 진행해도 알리가 없고 신청하기도 힘들 것이다  서울시에서 먼저 다가가고 먼저 찾아내어 도움을 줄 필요가 있습니다',
#  '가장 중요한건 경제적인 문제로 인한 은둔 청년이 많이 생기고 있다고 생각합니다  돈이죠 결국 자본주의 시대에 도태되었다는 걸 반증하는 사회현상이라고 생각합니다   그런데 돈을 그냥 주면 안되고 일을 하던 움직이게 해서 어느정도의 경험을 통한   업무습득을 통한  그런 제도가 필요하다고 생각합니다   무작정 경제적으로 지원을 해주는게 아니라  몸이 불편하지 않는이상 뭐라도 경험을 통한 경제적 이익이 생기는 정책이 있었으면 좋겠습니다 ',
#  '심리상담을위한',
#  '흥미있는 주제를 제공해주고 점점 이야기를 나눌 수준까지 흥미를 이끌어내면 오프라인에서도 함께 토론할것 같습니다 아니면 함께 영상이나 책을 시청하거나 읽는 시간',
#  '이것저것 참여하고 서류신청도 복잡해서 하고싶지않다',
#  '지금 이거 안하고 있는걸로 아는데 했으면 좋겠다',
#  '보여주기식의 지원방안은 안됩니다  갈수록 혼자 고립되는 청년들이 늘어날 것입니다  취업  연애  대외활동 등 장벽이 갈수록 높아지고 있어 모든것을 포기하고 집에만 있는 소위 말해 은둔형 외톨이가 급증할 것입니다  이에 대한 실질적인 해결책이 시급합니다 ',
#  '가정폭력 피해자가 많을 수 있어요  가족과 함께 하는 치료가 꼭 필요할 거 같아요 ',
#  '자립하기 위한 금전적인 지원  사회로 나오기 위한 다양한 프로그램',
#  '광고를 많이 하는게 좋을것같다',
#  '화술 인간관계 정립에 대한 강의 제공 요청',
#  '정신적인 문제가 큰거같아 정신상담이 필요하다 ',
#  '외부로 많이 나올수있게 도와준다',
#  '정서적 불안을 해소할 수 있는 활동들을 하게 하는 것이 도움이 되는 것 같습니다',
#  '청년들이 인생에 전성기때 고립을 선택하는것이 얼마나 안타까운 일인가    사회의 양극화는 점점 더 심해지고   부모의 가난이 되물림 되어서 기회조차 못잡는 청년들이 안타깝습니다  고립청년들에게 좋은 환경과 좋은 사람들과 함께 일할 수 있는 기회에 다방면으로 주어졌으면 좋겠습니다  본인이 무엇을 좋아하는지 모르고 생계때문에 하고 싶은 것이 있어도 하지못하는 청년들이 많습니다 심지어 본인이 뭘 좋아하는지 찾지못해서 방황하는 청년들도 있습니다  청년들이 대한민국을 이끌어 갈 미래세대 중요한 인재입니다  고립청년들에게 다양한 프로그램과 지원을 통해 청년들이 사회에 일원으로 활동 할 수 있도록 적극적인 관심과 지원과 격려 부탁드립니다  저희도 고립생활에서 벗어 나 대한민국의 건실한 청년으로 살아가고 싶습니다  저희에게 기회를 주십시요 ',
#  '부트캠프',
#  '은둔청년 신청해서 하고 있는데 기간이 정해져있어서 아무런 문제가 해결되지도 않았는데 기간이 끝나가면 더이상 은둔청년프로그램에 있지 못하게 되는게 아쉽다 같은 고민을 갖고 있는 사람들과 소통 생활 기간이 정해져있지 않고 자유롭게 다닐 수 있으면 좋겟어요',
#  '다양한 활동 프로그램',
#  '경제적 지원  개인 그룹 상담 확대  적극적인 홍보  다양한 종류의 프로그램을 로테이션이나 기수제로 모집',
#  ' 인구성원의 경제적지원이 필요합니다',
#  '센터 증설',
#  '교통비 지원이 됐으면 좋겠습니다 리커버리 센터에 계신 코치님께선 매일 방문했으면 좋겠다고 하셨지만  매일 가기엔 교통비가 많이 드네요 은둔 청년은 돈이 없다구요   ',
#  '제 상황에서 돈을 받을 수 있는 정책은 취업관련된 건이고 다 해봤지만 혼자서 의욕을 가지고 할 수 없었어요    차 상담때도 어떤 걸 원하냐고 직접 물어봤는데 답하기 힘들었어요  뭐부터 해야할지 감이 안 와요  스스로 의지가 필요한데 은둔청년 지원해도 잘 모르겠습니다   이런 활동도 지인이 추천한거라    돈이 가장 급하긴한데 어떤 준비도 안하는 입장에서 그냥 받기엔 자괴감 들거 같아요  관련 서적  북 이나 영상자료 공유해주시면 저희 입장에서 접근하기 좋지 않나 싶습니다  집 안에서 가능한 활동부터 지원해주세요   정책은 감사하나 지원사업 가이드라인이 어느정도 잡혔으면 좋겠습니다 ',
#  '고립  은둔 청년들은 미래에 대한 불확실함 그리고 인생의 목적 또는 꿈이 상실되어 있다고 생각이 듭니다  그리하여 인생을 살아가는데에 있어서 길을 잃었을 거라고 생각이 듭니다  그 청년들이 밖으로 나와 인생을 나아갈 수 있도록 용기 그리고 길을 찾아주고 혼자 걸어 갈 수 있을 만큼의 도움을 주어야 한다고 생각합니다  가장 중요한 것은 청년들의 진로 상담과 일을 할 수 있는 기회를 주어서 사회에서 활동을 할 수 있도록 해줘야 한다고 생각합니다 ',
#  '생활비지원',
#  '학원비 지원 프로그램  취창업을 위해 필요한 역량을 기르기 위해 최대  개월가량 학원비를 지원해주는 정책  내일배움으로는 계층별 분야별 지원금액비율이 달라서 청년들 위주로 어떤 것이든 취업 연계해서 학습종료후 바로 취업하여 일을 한다는 전제로 학원비 전액 지원해주는 정책이 있었으면 좋겠다는 생각이 듭니다    신체건장증진 정책   지정 운동시설을  개월  개월 가량 등록 지원해주는 프로그램  신체 활력이 생기면 자신감이 생기는데  운동시설의 경우 비용이 높은 편이라서 진입장벽이 좀 높은 것 같아서 서울시 공공시설 혹은 지정 시설에서    개월가량 신체건강을 챙길 수 있도록 지원해주는 프로그램이 있으면 좋을 것 같습니다 ',
#  '식비 및 여가활동 지원을 해줬으면 한다  그리고 각 구의 청년오랑센터에서 정기적으로 진행하는 청년 교류 모임이 많았으면 한다  예를 들어 취미용 원데이클래스나 글쓰기  독서 모임  영화 동아리 등의 모임이 있었으면 한다 ',
#  '정신과 진료비 지원',
#  '활동에 따른 보상 지급',
#  '지금은 기관이 강북에 하나 있는걸로 아는데  강남쪽에도 하나 있었으면 좋겠네요',
#  '대면 활동 프로그램 자주 실행 필요',
#  '함께 운동하기  심리검사 여러 프로그램이 있는데 홍보가 잘 안 되고 있는 것 같습니다   그리고 청년정보통이 아니라 따로 홈페이지를 만들어서 센터 위치와 정보 제고를 제공하고 상담신청 등을 받는게 좋을 것 같아요 ',
#  '좀 더 대상을 확대해서 힘든 사람들을 더 많이 지원해줬으면 좋겠습니다 ',
#  '너무 좋고 이 시대에 너무 필요한 것이라고 생각하기 때문에        이 더 늘어났으면 좋겠습니다',
#  '개인적으로는 재정상황이 고립에 미치는 영향도 제법 있는것 같습니다  일자리 소개나 지원금 등이 프로그램과 같이 제공된다면 프로그램에 직접적으로 참여하기 쉬워질듯 합니다 ',
#  '다양한 복지정책',
#  '지원금',
#  '소량이라도 경제적 지원있 있었으면 좋겠습니다 ',
#  '심리적인 요인이니 스스로 극복 해야 한다',
#  '실질적인 도움과 해결책을 제시해 주어야 합니다 ',
#  '경제적 지원보다 좋은 것은 없다고 생각합니다',
#  '친밀감형성',
#  '국책사업으로 고립 은둔 청년들이 사람과 잘 부딪히지 않으면서 사회나 세상에 조금이라도 도움이 되며 집밖에서의 활동과 노동으로 돈을 벌 수 있으면 꾸준히 할것 같다 ',
#  '청년 희망지원금',
#  '거주지와 가까웠으면 좋겠다 ',
#  '또래상담가 자원봉사',
#  '고립청년의 기준을 고립청년으로 낮춰야한다  중증이 되기 전에 직장에 다녀도 인간적인 관계가 부족해 사회적 고립상태인 사람들을 도왔으면 하는 바람이 있습니다 ',
#  '응원합니다',
#  '금전적 지원',
#  '사회생활을 위해 인턴형식으로  년  년 정도 원하는 직종에서 일을 배우는 프로그램도 있었으면 좋겠습니다  직업관련 활동 고립은둔 청년의 가족들과 전화 상담',
#  '사업명에 고립 은둔청년이라고 적으면  그 사업에 참여하는 사람들은 고립 은둔청년이라는 낙인을 가지게 됩니다  심리적으로 힘든 청년들이 낙인효과로 움츠러들지 않도록 단어 하나하나에도 신경을 써주세요 ',
#  '저소득 미취업 청년들 연락및 생활 지원',
#  '사회적활동을 많이 할수있는 환경을 만들어주세요 ',
#  '월세지원',
#  '부담 없이 익명 상담',
#  '고립이나 은둔같은 단어가 부정적 이미지를 연상시킬 수 있다고 생각해요    그리고   청년지원센터 등의 공간이 좀 더 많아졌으면 좋겠습니다 ',
#  '경제적지원',
#  ...]

# %%
# 형태소 분리
from konlpy.tag import Mecab # 한국어 형태소 분석

mecab = Mecab()
words = " ".join(df['【C9】 의견사항'].tolist())
words = mecab.morphs(words)
words
# Out:
# ['청년',
#  '구직',
#  '및',
#  '임대',
#  '주택',
#  '등',
#  '의',
#  '사업',
#  '이',
#  '필요',
#  '할',
#  '것',
#  '같',
#  '습니다',
#  '생색',
#  '내기',
#  '는',
#  '안',
#  '했',
#  '으면',
#  '좋',
#  '겠',
#  '습니다',
#  '자유',
#  '로운',
#  '경제',
#  '적',
#  '으로',
#  '자립',
#  '할',
#  '수',
#  '있',
#  '도록',
#  '도움',
#  '주세요',
#  '비대면',
#  '상담',
#  '홍보',
#  '가',
#  '더',
#  '많이',
#  '되',
#  '어야',
#  '할',
#  '거',
#  '같',
#  '아요',
#  '실직',
#  '이나',
#  '취업',
#  '준비',
#  '생',
#  '들',
#  '을',
#  '위한',
#  '모임',
#  '식사',
#  '와',
#  '근거리',
#  '걷',
#  '기',
#  '또는',
#  '플',
#  '로',
#  '깅',
#  '체험',
#  '을',
#  '포함',
#  '한',
#  '프로그램',
#  '을',
#  '인근',
#  '의',
#  '사람',
#  '들',
#  '과',
#  '소',
#  '규모',
#  '로',
#  '모여서',
#  '참여',
#  '할',
#  '수',
#  '있',
#  '도록',
#  '금액',
#  '을',
#  '지원',
#  '해',
#  '주',
#  '는',
#  '정책',
#  '경제',
#  '자립',
#  '지원',
#  '다양',
#  '한',
#  '이벤트',
#  '를',
#  '통한',
#  '홍보',
#  '활동',
#  '증진',
#  '자살',
#  '예방',
#  '대책',
#  '돈',
#  '을',
#  '줘라',
#  '보여',
#  '주',
#  '기',
#  '식',
#  '지원',
#  '이',
#  '아닌',
#  '실직',
#  '적',
#  '인',
#  '효과',
#  '가',
#  '있',
#  '는',
#  '장기',
#  '적',
#  '인',
#  '지원',
#  '경제',
#  '적',
#  '어려움',
#  '잇',
#  '는',
#  '경우',
#  '일',
#  '순위',
#  '레',
#  '크레이',
#  '션',
#  '지속',
#  '적',
#  '인',
#  '지원',
#  '및',
#  '회복',
#  '치료',
#  '관심',
#  '취직',
#  '을',
#  '하',
#  '고',
#  '싶',
#  '어요',
#  '취직',
#  '시켜',
#  '주',
#  '세요',
#  '부담',
#  '안',
#  '느낄',
#  '정도',
#  '의',
#  '가벼운',
#  '내용',
#  '으로',
#  '참여',
#  '하',
#  '거나',
#  '인식',
#  '할',
#  '것',
#  '내용',
#  '들',
#  '이',
#  '많',
#  '았',
#  '으면',
#  '함',
#  '도와',
#  '주',
#  '는',
#  '사람',
#  '이',
#  '많',
#  '아야',
#  '한다',
#  '심리',
#  '적',
#  '인',
#  '병증',
#  '은',
#  '무엇',
#  '보다',
#  '자기',
#  '의',
#  '지',
#  '가',
#  '가장',
#  '중요',
#  '하',
#  '다고',
#  '본다',
#  '본인',
#  '이',
#  '자기',
#  '현실',
#  '을',
#  '이겨',
#  '내',
#  '고자',
#  '하',
#  '는',
#  '의지',
#  '가',
#  '없',
#  '다면',
#  '지원',
#  '은',
#  '밑',
#  '빠진',
#  '독',
#  '에',
#  '물붓',
#  '기인',
#  '격',
#  '제대로',
#  '의지',
#  '가',
#  '있',
#  '는',
#  '지원자',
#  '들',
#  '의',
#  '지원서',
#  '를',
#  '받',
#  '고서',
#  '비슷',
#  '한',
#  '계열',
#  '의',
#  '고민',
#  '은',
#  '가진',
#  '명',
#  '의',
#  '소',
#  '규모',
#  '모임',
#  '으로',
#  '치료',
#  '를',
#  '같이',
#  '진행',
#  '하',
#  '는',
#  '것',
#  '이',
#  '좋',
#  '을',
#  '것',
#  '같',
#  '다',
#  '소',
#  '규모',
#  '직접',
#  '모여서',
#  '취미',
#  '활동',
#  '을',
#  '할',
#  '수',
#  '있',
#  '는',
#  '동아리',
#  '다양',
#  '한',
#  '정보',
#  '가',
#  '있',
#  '어서',
#  '좋',
#  '다',
#  '관심',
#  '을',
#  '가져',
#  '준다',
#  '자유',
#  '로운',
#  '분위기',
#  '에서',
#  '이야기',
#  '를',
#  '잘',
#  '들',
#  '어',
#  '주',
#  '고',
#  '차근차근',
#  '단계',
#  '별',
#  '로',
#  '정신',
#  '적',
#  '안정',
#  '부터',
#  '실질',
#  '적',
#  '인',
#  '도움',
#  '까지',
#  '받',
#  '을',
#  '수',
#  '있',
#  '으면',
#  '좋',
#  '겠',
#  '다',
#  '다양',
#  '한',
#  '여가',
#  '활동',
#  '을',
#  '할',
#  '수',
#  '있',
#  '도록',
#  '경제',
#  '적',
#  '으로',
#  '지원',
#  '해',
#  '주',
#  '는',
#  '것',
#  '청년',
#  '들',
#  '에게',
#  '인생',
#  '선배',
#  '로서',
#  '다양',
#  '한',
#  '조언',
#  '을',
#  '해',
#  '줄',
#  '수',
#  '도',
#  '있',
#  '고',
#  '진로',
#  '설정',
#  '에',
#  '어려움',
#  '을',
#  '겪',
#  '는',
#  '친구',
#  '들',
#  '에게',
#  '코칭',
#  '을',
#  '해',
#  '줄',
#  '수',
#  '도',
#  '있',
#  '다',
#  '국가',
#  '시행',
#  '정책',
#  '에서',
#  '선입견',
#  '으로',
#  '느끼',
#  '는',
#  '무성의',
#  '와',
#  '실적',
#  '위주',
#  '의',
#  '진정',
#  '성',
#  '없',
#  '는',
#  '정책',
#  '이',
#  '아니',
#  '라',
#  '조금',
#  '더',
#  '고민',
#  '하',
#  '고',
#  '진심',
#  '으로',
#  '다가가',
#  '는',
#  '방법',
#  '이',
#  '필요',
#  '하',
#  '다',
#  '금전',
#  '적',
#  '지원',
#  '보다',
#  '도',
#  '진심',
#  '으로',
#  '누군가',
#  '고립',
#  '은',
#  '둔',
#  '청년',
#  '들',
#  '을',
#  '생각',
#  '하',
#  '고',
#  '이해',
#  '한다고',
#  '느낄',
#  '수',
#  '있',
#  '게',
#  '하',
#  '는',
#  '게',
#  '더',
#  '중요',
#  '하',
#  '다고',
#  '본다',
#  '경제',
#  '적',
#  '보조',
#  '및',
#  '현금',
#  '지급',
#  '돈',
#  '줘요',
#  '여가',
#  '쿠폰',
#  '제공',
#  '지속',
#  '적',
#  '으로',
#  '전화',
#  '나',
#  '방문',
#  '을',
#  '통해',
#  '대화',
#  '를',
#  '해',
#  '으면',
#  '한다',
#  '무작정',
#  '사람',
#  '들',
#  '과',
#  '대면',
#  '할',
#  '횟수',
#  '를',
#  '늘리',
#  '고',
#  '바깥',
#  '활동',
#  '을',
#  '유도',
#  '하',
#  '는',
#  '방법',
#  '은',
#  '거부',
#  '감',
#  '이',
#  '듭니다',
#  '취업',
#  '경제',
#  '적',
#  '지원',
#  '및',
#  '휴식',
#  '일회성',
#  '이',
#  '아닌',
#  '지속',
#  '적',
#  '인',
#  '지원',
#  '이',
#  '필요',
#  '하',
#  '다고',
#  '본다',
#  '진정',
#  '성',
#  '잇',
#  '는',
#  '심리',
#  '상담',
#  '과',
#  '프로그램',
#  '실용',
#  '성',
#  '이',
#  '없',
#  '어',
#  '보이',
#  '는데',
#  '저',
#  '도',
#  '딱히',
#  '방안',
#  '을',
#  '내',
#  '놓',
#  '지',
#  '는',
#  '못하',
#  '겠',
#  '습니다',
#  '현실',
#  '에서',
#  '좌절',
#  '을',
#  '겪',
#  '고',
#  '희망',
#  '이',
#  '없',
#  '다고',
#  '생각',
#  '하',
#  '는',
#  '경우',
#  '가',
#  '많',
#  '기',
#  '때문',
#  '에',
#  '희망',
#  '을',
#  '줄',
#  '수',
#  '있',
#  '는',
#  '계기',
#  '를',
#  '주',
#  '는',
#  '것',
#  '이',
#  '필요',
#  '하',
#  '다고',
#  '생각',
#  '합니다',
#  '말',
#  '뿐',
#  '인',
#  '조언',
#  '보다',
#  '는',
#  '스스로',
#  '를',
#  '달라지',
#  '게',
#  '할',
#  '수',
#  '있',
#  '는',
#  '자기',
#  '개발',
#  '기술',
#  '교육',
#  '연수',
#  '교육',
#  '등',
#  '의',
#  '기회',
#  '를',
#  '주',
#  '었',
#  '으면',
#  '합니다',
#  '그리고',
#  '제',
#  '가',
#  '이전',
#  '에',
#  '좌절',
#  '을',
#  '겪',
#  '었',
#  '을',
#  '때',
#  '봉사',
#  '활동',
#  '을',
#  '하',
#  '면서',
#  '현실',
#  '을',
#  '받아들이',
#  '는',
#  '방법',
#  '을',
#  '달리',
#  '한',
#  '경험',
#  '이',
#  '있',
#  '습니다',
#  '고립',
#  '적',
#  '인',
#  '생활',
#  '을',
#  '하',
#  '는',
#  '사람',
#  '의',
#  '입장',
#  '에서',
#  '자신',
#  '이',
#  '무',
#  '가치',
#  '하',
#  '고',
#  '무',
#  '의미',
#  '한',
#  '존재',
#  '처럼',
#  '느껴',
#  '지',
#  '지만',
#  '가벼운',
#  '방법',
#  '으로',
#  '라도',
#  '내',
#  '가',
#  '남',
#  '을',
#  '도울',
#  '수',
#  '있',
#  '는',
#  '존재',
#  '이',
#  '고',
#  '작',
#  '게',
#  '나마',
#  '세상',
#  '을',
#  '더',
#  '좋',
#  '아',
#  '지',
#  '게',
#  '하',
#  '는',
#  '데',
#  '에',
#  '역할',
#  '을',
#  '하',
#  '는',
#  '존재',
#  '라고',
#  '생각',
#  '할',
#  '수',
#  '있',
#  '는',
#  '시간',
#  '을',
#  '주',
#  '는',
#  '것',
#  '이',
#  '좋',
#  '다고',
#  '생각',
#  '합니다',
#  '이',
#  '에',
#  '봉사',
#  '활동',
#  '이나',
#  '주기',
#  '적',
#  '인',
#  '헌혈',
#  '등',
#  '에',
#  '대한',
#  '참여',
#  '를',
#  '유도',
#  '하',
#  '는',
#  '것',
#  '도',
#  '괜찮',
#  '지',
#  '않',
#  '을까요',
#  '지금',
#  '서베이',
#  '에',
#  '참여',
#  '하',
#  '고',
#  '더',
#  '많',
#  '은',
#  '헤이',
#  '폴',
#  '포인트',
#  '를',
#  '쌓',
#  '아',
#  '보',
#  '세요',
#  '월세',
#  '지원',
#  '정책',
#  '지원',
#  '이',
#  '있',
#  '었',
#  '으면',
#  '한다',
#  '정신',
#  '과',
#  '비용',
#  '지급',
#  '줌',
#  '수업',
#  '고립',
#  '청년',
#  '은',
#  '밖',
#  '에',
#  '나갈',
#  '생각',
#  '을',
#  '안',
#  '함',
#  '취업',
#  '연계',
#  '형',
#  '사업',
#  '으로',
#  '변경',
#  '돈',
#  '이',
#  '있',
#  '어야',
#  '뭘',
#  '하',
#  '지',
#  '지속',
#  '적',
#  '인',
#  '지원',
#  '및',
#  '사후',
#  '관리',
#  '가',
#  '중요',
#  '하',
#  '다',
#  '콘서트',
#  '나',
#  '연극',
#  '관람',
#  '기회',
#  '주기',
#  '찾아가',
#  '는',
#  '서비스',
#  '장기전',
#  '으로',
#  '생각',
#  '하',
#  '는',
#  '제도',
#  '상담',
#  '홍보',
#  '를',
#  '해서',
#  '널리',
#  '알려',
#  '줘',
#  '랑',
#  '전문',
#  '상담',
#  '취업',
#  '지원',
#  '수해',
#  '에',
#  '돌아가',
#  '신',
#  '반지하',
#  '가족',
#  '들',
#  '처럼',
#  '그런',
#  '사고',
#  '가',
#  '더',
#  '이상',
#  '생기',
#  '지',
#  '않',
#  '도록',
#  '신경',
#  '을',
#  '썼',
#  '으면',
#  '좋',
#  '겠',
#  '다',
#  '금전',
#  '적',
#  '인',
#  '지원금',
#  '을',
#  '많이',
#  '지원',
#  '해',
#  '주',
#  '었',
#  '으면',
#  '좋',
#  '을',
#  '것',
#  '같',
#  '다',
#  '우선',
#  '나올',
#  '수',
#  '있',
#  '는',
#  '기회',
#  '를',
#  '만들',
#  '어',
#  '줘야',
#  '함',
#  '최대한',
#  '국민',
#  '세금',
#  '이',
#  '안',
#  '드',
#  '는',
#  '쪽',
#  '으로',
#  '운영',
#  '하',
#  '면',
#  '좋',
#  '겠',
#  '다',
#  '은',
#  '둔',
#  '자유',
#  '친구',
#  '가',
#  '맺',
#  '어',
#  '지',
#  '는',
#  '과정',
#  '이',
#  '투명',
#  '하',
#  '면',
#  '좋',
#  '겠',
#  '다',
#  '경제',
#  '공원',
#  '산책',
#  '등',
#  '야외',
#  '활동',
#  '에',
#  '참여',
#  '할',
#  '만',
#  '한',
#  '프로그램',
#  '이',
#  '있',
#  '으면',
#  '좋',
#  '겠',
#  '다',
#  '취업',
#  '연계',
#  '세금',
#  '감면',
#  '은',
#  '둔',
#  '청년',
#  '들',
#  '도',
#  '방',
#  '안',
#  '에서',
#  '게임',
#  '을',
#  '하',
#  '거나',
#  '유튜브',
#  '를',
#  '하',
#  '거나',
#  '어떤',
#  '행동',
#  '을',
#  '할',
#  '테',
#  '니',
#  '그',
#  '들',
#  '의',
#  '그런',
#  '활동',
#  '으로',
#  '돈',
#  '을',
#  '벌',
#  '수',
#  '있',
#  '다는',
#  '점',
#  '을',
#  '알려',
#  '주',
#  '면',
#  '좋',
#  '을',
#  '듯',
#  '유튜브',
#  '로',
#  '돈',
#  '을',
#  '벌',
#  '수',
#  '있',
#  '는',
#  '방법',
#  '과',
#  '편집',
#  '프로그램',
#  '툴',
#  '사용법',
#  '등',
#  '을',
#  '교육',
#  '하',
#  '면',
#  '어떨지',
#  '프리허그',
#  '운동',
#  '결심',
#  '하',
#  '자마자',
#  '바로',
#  '도와',
#  '줄',
#  '수',
#  '있',
#  '는',
#  '채널',
#  '맞춤',
#  '형',
#  '상담',
#  '및',
#  '지원',
#  '친구',
#  '를',
#  '만들',
#  '어',
#  '주',
#  '는',
#  '사업',
#  ...]

# %%
file_name = './test.txt'

with open(file_name, 'w+') as file:
    file.write('\n'.join(words))

# %%
# 한 글자 용어 제거
remove_one_word = [x for x in words if len(x) > 1 or x == "돈"]
len(remove_one_word)
# Out:
# 9367

# %%
from collections import Counter
frequent = Counter(remove_one_word).most_common()
frequent
# Out:
# [('지원', 390),
#  ('으로', 214),
#  ('청년', 170),
#  ('필요', 149),
#  ('으면', 142),
#  ('상담', 141),
#  ('사람', 140),
#  ('경제', 137),
#  ('습니다', 133),
#  ('고립', 116),
#  ('활동', 102),
#  ('프로그램', 100),
#  ('합니다', 87),
#  ('생각', 83),
#  ('에서', 77),
#  ('정책', 75),
#  ('홍보', 68),
#  ('취업', 68),
#  ('한다', 67),
#  ('도움', 64),
#  ('다양', 64),
#  ('심리', 61),
#  ('도록', 59),
#  ('사회', 52),
#  ('생활', 49),
#  ('참여', 46),
#  ('다고', 46),
#  ('일자리', 46),
#  ('이나', 45),
#  ('취미', 44),
#  ('만들', 44),
#  ('많이', 42),
#  ('에게', 42),
#  ('돈', 39),
#  ('세요', 37),
#  ('중요', 36),
#  ('적극', 36),
#  ('은둔', 35),
#  ('치료', 33),
#  ('모임', 31),
#  ('아니', 31),
#  ('기회', 31),
#  ('지만', 31),
#  ('연계', 31),
#  ('해야', 31),
#  ('제공', 30),
#  ('이런', 29),
#  ('문제', 29),
#  ('아요', 28),
#  ('지속', 28),
#  ('대한', 28),
#  ('가족', 27),
#  ('신청', 27),
#  ('정신', 26),
#  ('해서', 26),
#  ('어야', 25),
#  ('경우', 25),
#  ('보다', 25),
#  ('는데', 25),
#  ('서비스', 25),
#  ('아닌', 24),
#  ('관심', 24),
#  ('어서', 24),
#  ('실질', 24),
#  ('위한', 23),
#  ('교육', 23),
#  ('라고', 23),
#  ('지원금', 23),
#  ('운동', 23),
#  ('온라인', 23),
#  ('사업', 22),
#  ('가장', 22),
#  ('비슷', 22),
#  ('방법', 22),
#  ('때문', 22),
#  ('다는', 22),
#  ('함께', 22),
#  ('친구', 21),
#  ('경험', 21),
#  ('마음', 21),
#  ('금전', 20),
#  ('센터', 20),
#  ('방안', 19),
#  ('그런', 19),
#  ('여러', 19),
#  ('어요', 18),
#  ('거나', 18),
#  ('직접', 18),
#  ('대화', 18),
#  ('찾아가', 18),
#  ('나가', 18),
#  ('개인', 18),
#  ('는지', 18),
#  ('만나', 18),
#  ('도와', 17),
#  ('본인', 17),
#  ('같이', 17),
#  ('마련', 17),
#  ('소통', 17),
#  ('나오', 17),
#  ('다면', 16),
#  ('면서', 16),
#  ('처럼', 16),
#  ('라도', 16),
#  ('제도', 16),
#  ('모르', 16),
#  ('힘들', 16),
#  ('부터', 15),
#  ('까지', 15),
#  ('통해', 15),
#  ('스스로', 15),
#  ('그리고', 15),
#  ('나올', 15),
#  ('상황', 15),
#  ('다른', 15),
#  ('끼리', 15),
#  ('입니다', 15),
#  ('통한', 14),
#  ('나갈', 14),
#  ('가능', 14),
#  ('서울시', 14),
#  ('자유', 13),
#  ('부담', 13),
#  ('정도', 13),
#  ('희망', 13),
#  ('자신', 13),
#  ('줘야', 13),
#  ('복지', 13),
#  ('시스템', 13),
#  ('먼저', 13),
#  ('가지', 13),
#  ('접근', 13),
#  ('대상', 13),
#  ('주변', 13),
#  ('장기', 12),
#  ('의지', 12),
#  ('안정', 12),
#  ('조금', 12),
#  ('한다고', 12),
#  ('방문', 12),
#  ('시간', 12),
#  ('지금', 12),
#  ('전문', 12),
#  ('운영', 12),
#  ('나이', 12),
#  ('커뮤니티', 12),
#  ('개월', 12),
#  ('직장', 12),
#  ('사회생활', 12),
#  ('자립', 11),
#  ('효과', 11),
#  ('자기', 11),
#  ('진행', 11),
#  ('준다', 11),
#  ('세상', 11),
#  ('이상', 11),
#  ('생기', 11),
#  ('자체', 11),
#  ('없이', 11),
#  ('시설', 11),
#  ('자주', 11),
#  ('자연', 11),
#  ('스럽', 11),
#  ('형성', 11),
#  ('네요', 11),
#  ('우울', 11),
#  ('부분', 11),
#  ('아서', 11),
#  ('병원', 11),
#  ('인터넷', 11),
#  ('위해', 11),
#  ('환경', 11),
#  ('비용', 10),
#  ('알려', 10),
#  ('너무', 10),
#  ('직업', 10),
#  ('심리치료', 10),
#  ('대부분', 10),
#  ('해결', 10),
#  ('이유', 10),
#  ('문화', 10),
#  ('취직', 9),
#  ('아야', 9),
#  ('현금', 9),
#  ('개발', 9),
#  ('봉사', 9),
#  ('정부', 9),
#  ('알선', 9),
#  ('더라도', 9),
#  ('규칙', 9),
#  ('일단', 9),
#  ('관련', 9),
#  ('생활비', 9),
#  ('공간', 9),
#  ('재정', 9),
#  ('됩니다', 9),
#  ('어려움', 8),
#  ('현실', 8),
#  ('분위기', 8),
#  ('지급', 8),
#  ('전화', 8),
#  ('못하', 8),
#  ('우선', 8),
#  ('어떤', 8),
#  ('해결책', 8),
#  ('미래', 8),
#  ('상처', 8),
#  ('편안', 8),
#  ('원인', 8),
#  ('시작', 8),
#  ('혼자', 8),
#  ('극복', 8),
#  ('정서', 8),
#  ('다가', 8),
#  ('관계', 8),
#  ('자발', 8),
#  ('비대면', 7),
#  ('내용', 7),
#  ('무엇', 7),
#  ('고민', 7),
#  ('유도', 7),
#  ('관리', 7),
#  ('최대한', 7),
#  ('힘든', 7),
#  ('보장', 7),
#  ('익명', 7),
#  ('비대', 7),
#  ('해요', 7),
#  ('게끔', 7),
#  ('정말', 7),
#  ('교류', 7),
#  ('외부', 7),
#  ('전문가', 7),
#  ('아무', 7),
#  ('처지', 7),
#  ('정기', 7),
#  ('오프라인', 7),
#  ('주거', 7),
#  ('서울', 7),
#  ('뭔가', 7),
#  ('부족', 7),
#  ('혜택', 7),
#  ('어도', 7),
#  ('어려운', 7),
#  ('어떻게', 7),
#  ('졌으면', 7),
#  ('연락', 7),
#  ('더욱', 7),
#  ('리커버리', 7),
#  ('보여', 6),
#  ('시켜', 6),
#  ('정보', 6),
#  ('진심', 6),
#  ('주기', 6),
#  ('해도', 6),
#  ('꾸준히', 6),
#  ('어렵', 6),
#  ('해당', 6),
#  ('처음', 6),
#  ('조차', 6),
#  ('사각지대', 6),
#  ('위해서', 6),
#  ('요즘', 6),
#  ('장소', 6),
#  ('다음', 6),
#  ('형식', 6),
#  ('기간', 6),
#  ('대상자', 6),
#  ('발굴', 6),
#  ('이용', 6),
#  ('사이트', 6),
#  ('광고', 6),
#  ('클래스', 6),
#  ('만든다', 6),
#  ('문자', 6),
#  ('살아가', 6),
#  ('용기', 6),
#  ('지역', 6),
#  ('라는', 6),
#  ('누구', 6),
#  ('흥미', 6),
#  ('현재', 6),
#  ('나와', 6),
#  ('또래', 6),
#  ('부탁', 6),
#  ('혹은', 6),
#  ('준비', 5),
#  ('체험', 5),
#  ('자살', 5),
#  ('느낄', 5),
#  ('인식', 5),
#  ('본다', 5),
#  ('제대로', 5),
#  ('이야기', 5),
#  ('인생', 5),
#  ('느끼', 5),
#  ('다가가', 5),
#  ('누군가', 5),
#  ('이해', 5),
#  ('늘리', 5),
#  ('일회성', 5),
#  ('계기', 5),
#  ('입장', 5),
#  ('존재', 5),
#  ('세금', 5),
#  ('과정', 5),
#  ('산책', 5),
#  ('채널', 5),
#  ('맞춤', 5),
#  ('개선', 5),
#  ('청소년', 5),
#  ('학교', 5),
#  ('거주', 5),
#  ('조사', 5),
#  ('확실', 5),
#  ('제한', 5),
#  ('단체', 5),
#  ('이미', 5),
#  ('신체', 5),
#  ('동안', 5),
#  ('으니', 5),
#  ('어느', 5),
#  ('자격증', 5),
#  ('다시', 5),
#  ('그냥', 5),
#  ('공감대', 5),
#  ('파악', 5),
#  ('체계', 5),
#  ('려는', 5),
#  ('채팅', 5),
#  ('밖에', 5),
#  ('감사', 5),
#  ('반복', 5),
#  ('한다는', 5),
#  ('소득', 5),
#  ('공부', 5),
#  ('려면', 5),
#  ('적응', 5),
#  ('마다', 5),
#  ('들어가', 5),
#  ('확대', 5),
#  ('상태', 5),
#  ('찾아내', 5),
#  ('요청', 5),
#  ('기본', 5),
#  ('응원', 5),
#  ('매체', 5),
#  ('매일', 5),
#  ('단어', 5),
#  ('영상', 5),
#  ('주택', 4),
#  ('로운', 4),
#  ('또는', 4),
#  ('가벼운', 4),
#  ('차근차근', 4),
#  ('단계', 4),
#  ('여가', 4),
#  ('조언', 4),
#  ('진정', 4),
#  ('대면', 4),
#  ('듭니다', 4),
#  ('괜찮', 4),
#  ('포인트', 4),
#  ('목적', 4),
#  ('일상', 4),
#  ('인데', 4),
#  ('자금', 4),
#  ('우울증', 4),
#  ('부모', 4),
#  ('걱정', 4),
#  ('관한', 4),
#  ('보내', 4),
#  ('병행', 4),
#  ('창업', 4),
#  ('멘토', 4),
#  ('줘서', 4),
#  ('담사', 4),
#  ('케어', 4),
#  ('실제', 4),
#  ('봐야', 4),
#  ('활성', 4),
#  ('외출', 4),
#  ('결국', 4),
#  ('세대', 4),
#  ('훈련', 4),
#  ('인지', 4),
#  ('부담없이', 4),
#  ('진짜', 4),
#  ('페이지', 4),
#  ('노출', 4),
#  ('바우처', 4),
#  ('데이', 4),
#  ('강화', 4),
#  ('사용', 4),
#  ('자리', 4),
#  ('일어나', 4),
#  ('성취감', 4),
#  ('챌린지', 4),
#  ('달성', 4),
#  ('물고기', 4),
#  ('프로젝트', 4),
#  ('선택', 4),
#  ('절차', 4),
#  ('그렇', 4),
#  ('려고', 4),
#  ('외톨이', 4),
#  ('추천', 4),
#  ('보호', 4),
#  ('다니', 4),
#  ('새로운', 4),
#  ('걸로', 4),
#  ('검사', 4),
#  ('제일', 4),
#  ('건강', 4),
#  ('못했', 4),
#  ('시대', 4),
#  ('창출', 4),
#  ('노력', 4),
#  ('적절', 4),
#  ('편하', 4),
#  ('가정', 4),
#  ('분야', 4),
#  ('연결', 4),
#  ('근본', 4),
#  ('가볍', 4),
#  ('코로나', 4),
#  ('수준', 4),
#  ('을까', 4),
#  ('이끌', 4),
#  ('점점', 4),
#  ('더더욱', 4),
#  ('위치', 4),
#  ('교통비', 4),
#  ('하나', 4),
#  ('해준다', 4),
#  ('굳이', 4),
#  ('불안', 4),
#  ('그러', 4),
#  ('기관', 4),
#  ('코치', 4),
#  ('푸른', 4),
#  ('고래', 4),
#  ('주세요', 3),
#  ('규모', 3),
#  ('모여서', 3),
#  ('금액', 3),
#  ('예방', 3),
#  ('대책', 3),
#  ('고자', 3),
#  ('동아리', 3),
#  ('로서', 3),
#  ('진로', 3),
#  ('시행', 3),
#  ('위주', 3),
#  ('보이', 3),
#  ('딱히', 3),
#  ('을까요', 3),
#  ('수업', 3),
#  ('공원', 3),
#  ('게임', 3),
#  ('바로', 3),
#  ('탁상행정', 3),
#  ('노동', 3),
#  ('절대', 3),
#  ('결과', 3),
#  ('계속', 3),
#  ('활발', 3),
#  ('중증', 3),
#  ('자존', 3),
#  ('순간', 3),
#  ('구나', 3),
#  ('길러', 3),
#  ('배움', 3),
#  ('장려', 3),
#  ('휴대폰', 3),
#  ('버스', 3),
#  ('제발', 3),
#  ('동기', 3),
#  ('부여', 3),
#  ('단절', 3),
#  ('알리', 3),
#  ('그만', 3),
#  ('카카오톡', 3),
#  ('모아', 3),
#  ('쉬운', 3),
#  ('모여', 3),
#  ('즐기', 3),
#  ('서로', 3),
#  ('사실', 3),
#  ('만남', 3),
#  ('여러분', 3),
#  ('이동', 3),
#  ('카톡', 3),
#  ('여기', 3),
#  ('어디', 3),
#  ('없애', 3),
#  ('보통', 3),
#  ('방식', 3),
#  ('등등', 3),
#  ('나와서', 3),
#  ('나눌', 3),
#  ('충분', 3),
#  ('주민', 3),
#  ('일시', 3),
#  ('조건', 3),
#  ('소모임', 3),
#  ('연령', 3),
#  ('무료', 3),
#  ('신청자', 3),
#  ('는다', 3),
#  ('위로', 3),
#  ('으며', 3),
#  ('직장인', 3),
#  ('소개', 3),
#  ('시키', 3),
#  ('따라서', 3),
#  ('아침', 3),
#  ('강제', 3),
#  ('한다면', 3),
#  ('경력', 3),
#  ('멘토링', 3),
#  ('주선', 3),
#  ('이루', 3),
#  ('목표', 3),
#  ('바랍니다', 3),
#  ('등록', 3),
#  ('창구', 3),
#  ('구요', 3),
#  ('만족', 3),
#  ('끝나', 3),
#  ('캠페인', 3),
#  ('인력', 3),
#  ('친밀감', 3),
#  ('보단', 3),
#  ('니까요', 3),
#  ('므로', 3),
#  ('단기', 3),
#  ('또한', 3),
#  ('감정', 3),
#  ('알아보', 3),
#  ('불편', 3),
#  ('강요', 3),
#  ('서서히', 3),
#  ('보살핌', 3),
#  ('실업', 3),
#  ('그렇게', 3),
#  ('시기', 3),
#  ('발견', 3),
#  ('점차', 3),
#  ('성향', 3),
#  ('꾸준', 3),
#  ('생겼으면', 3),
#  ('공유', 3),
#  ('은데', 3),
#  ('생계', 3),
#  ('원하', 3),
#  ('일정', 3),
#  ('마케팅', 3),
#  ('을지', 3),
#  ('반드시', 3),
#  ('모든', 3),
#  ('못한', 3),
#  ('몰랐', 3),
#  ('개설', 3),
#  ('공무원', 3),
#  ('재활', 3),
#  ('절실', 3),
#  ('참석', 3),
#  ('대출', 3),
#  ('드립니다', 3),
#  ('메신저', 3),
#  ('일본', 3),
#  ('운둔', 3),
#  ('약물', 3),
#  ('기준', 3),
#  ('비밀', 3),
#  ('조심', 3),
#  ('스러운', 3),
#  ('부작용', 3),
#  ('무조건', 3),
#  ('보인다', 3),
#  ('실행', 3),
#  ('접근성', 3),
#  ('지인', 3),
#  ('인간', 3),
#  ('끌어내', 3),
#  ('늘려', 3),
#  ('확인', 3),
#  ('얘기', 3),
#  ('만날', 3),
#  ('홈페이지', 3),
#  ('겁니다', 3),
#  ('지향', 3),
#  ('성과', 3),
#  ('저희', 3),
#  ('학원', 3),
#  ('가량', 3),
#  ('하나하나', 3),
#  ('사무실', 3),
#  ('구직', 2),
#  ('임대', 2),
#  ('실직', 2),
#  ('식사', 2),
#  ('포함', 2),
#  ('이벤트', 2),
#  ('증진', 2),
#  ('순위', 2),
#  ('회복', 2),
#  ('이겨', 2),
#  ('기인', 2),
#  ('지원자', 2),
#  ('계열', 2),
#  ('가진', 2),
#  ('국가', 2),
#  ('쿠폰', 2),
#  ('무작정', 2),
#  ('거부', 2),
#  ('실용', 2),
#  ('좌절', 2),
#  ('이전', 2),
#  ('달리', 2),
#  ('가치', 2),
#  ('월세', 2),
#  ('변경', 2),
#  ('콘서트', 2),
#  ('돌아가', 2),
#  ('신경', 2),
#  ('유튜브', 2),
#  ('어떨지', 2),
#  ('이러', 2),
#  ('선별', 2),
#  ('신원', 2),
#  ('맞춰서', 2),
#  ('홀로', 2),
#  ('공공', 2),
#  ('대해', 2),
#  ('격려', 2),
#  ('액티비티', 2),
#  ('단순', 2),
#  ('된다', 2),
#  ('어떠', 2),
#  ('영역', 2),
#  ('독서', 2),
#  ('구제', 2),
#  ('이어진', 2),
#  ('봅니다', 2),
#  ('높여', 2),
#  ('괴롭힘', 2),
#  ('과거', 2),
#  ('그런데', 2),
#  ('어떤지', 2),
#  ('더라구요', 2),
#  ('확충', 2),
#  ('긍정', 2),
#  ('전달', 2),
#  ('억지로', 2),
#  ('네트워크', 2),
#  ('따라', 2),
#  ('처방', 2),
#  ('진단', 2),
#  ('집중', 2),
#  ('익숙', 2),
#  ('버리', 2),
#  ('탈출', 2),
#  ('시민', 2),
#  ('시청', 2),
#  ('강의', 2),
#  ('기획', 2),
#  ('은지', 2),
#  ('였으면', 2),
#  ('나와야', 2),
#  ('한때', 2),
#  ('내밀', 2),
#  ('가져가', 2),
#  ('지나치', 2),
#  ('나약', 2),
#  ('낭비', 2),
#  ('사소', 2),
#  ('정작', 2),
#  ('회성', 2),
#  ('높인다', 2),
#  ('천천히', 2),
#  ('질환', 2),
#  ('자의', 2),
#  ('다가갈', 2),
#  ('접촉', 2),
#  ('실제로', 2),
#  ('이후', 2),
#  ('생계비', 2),
#  ('각자', 2),
#  ('가구', 2),
#  ('에요', 2),
#  ('무기력', 2),
#  ('아무것', 2),
#  ('주로', 2),
#  ('간단', 2),
#  ('랜덤', 2),
#  ('인턴', 2),
#  ('구청', 2),
#  ('적성', 2),
#  ('양질', 2),
#  ('여행', 2),
#  ('포털', 2),
#  ('안내', 2),
#  ('모집', 2),
#  ('찾아봐', 2),
#  ('건가', 2),
#  ('텐데', 2),
#  ('모이', 2),
#  ('들어줄', 2),
#  ('이라도', 2),
#  ('기업', 2),
#  ('둔하', 2),
#  ('물질', 2),
#  ('인해', 2),
#  ('인증', 2),
#  ('하루', 2),
#  ('높이', 2),
#  ('엄청난', 2),
#  ('공감', 2),
#  ('주소', 2),
#  ('나요', 2),
#  ('당사자', 2),
#  ('지지', 2),
#  ('압박감', 2),
#  ('얼마나', 2),
#  ('범죄', 2),
#  ('피해자', 2),
#  ('비난', 2),
#  ('져야', 2),
#  ('표현', 2),
#  ('감이', 2),
#  ('갑자기', 2),
#  ('그만두', 2),
#  ('가질', 2),
#  ('어려울', 2),
#  ('우리', 2),
#  ('모두', 2),
#  ('실업자', 2),
#  ('간편', 2),
#  ('여야', 2),
#  ('꺼리', 2),
#  ('면접', 2),
#  ('다닐', 2),
#  ('배송', 2),
#  ('즐길', 2),
#  ('항상', 2),
#  ('무서워', 2),
#  ('뭔지', 2),
#  ('할꺼', 2),
#  ('외로움', 2),
#  ('살아갈', 2),
#  ('강연', 2),
#  ('부정', 2),
#  ('전반', 2),
#  ('조성', 2),
#  ('찾아보', 2),
#  ('격월', 2),
#  ('벗어날', 2),
#  ('체크', 2),
#  ('지내', 2),
#  ('선생', 2),
#  ('이름', 2),
#  ('저렴', 2),
#  ('대응', 2),
#  ('모색', 2),
#  ('도와야', 2),
#  ('살리', 2),
#  ('아님', 2),
#  ('저소득', 2),
#  ('육체', 2),
#  ('히키코모리', 2),
#  ('질병', 2),
#  ('여겨진다', 2),
#  ('성실', 2),
#  ('매우', 2),
#  ('리라', 2),
#  ('도와준다', 2),
#  ('의문', 2),
#  ('확률', 2),
#  ('으므로', 2),
#  ('인한', 2),
#  ('취향', 2),
#  ('심각', 2),
#  ('티비', 2),
#  ('불쾌', 2),
#  ('능력', 2),
#  ('기르', 2),
#  ('찾아갈', 2),
#  ('동네', 2),
#  ('완화', 2),
#  ('그래서', 2),
#  ('한데', 2),
#  ('보살펴', 2),
#  ('급하', 2),
#  ('그나마', 2),
#  ('단기간', 2),
#  ('패배감', 2),
#  ('빠지', 2),
#  ('집니다', 2),
#  ('강제성', 2),
#  ('어려워하', 2),
#  ('타인', 2),
#  ('낯선', 2),
#  ('리프', 2),
#  ('스러워', 2),
#  ('된다면', 2),
#  ('화상', 2),
#  ('유능', 2),
#  ('수입', 2),
#  ('활력', 2),
#  ('걸으며', 2),
#  ('쓰레기', 2),
#  ('유지', 2),
#  ('제시', 2),
#  ('대인', 2),
#  ('방면', 2),
#  ('알려줘야', 2),
#  ('시도', 2),
#  ('카페', 2),
#  ('둔한', 2),
#  ('독려', 2),
#  ('만드', 2),
#  ('성격', 2),
#  ('그래야', 2),
#  ('자괴감', 2),
#  ('든다', 2),
#  ('헬스', 2),
#  ('도덕', 2),
#  ('보상', 2),
#  ('특히', 2),
#  ('요리', 2),
#  ('아무런', 2),
#  ('내일', 2),
#  ('바람', 2),
#  ('즐겁', 2),
#  ('그룹', 2),
#  ('부끄럽', 2),
#  ('장점', 2),
#  ('아니면', 2),
#  ('보험', 2),
#  ('프리랜서', 2),
#  ('단편', 2),
#  ('신고', 2),
#  ('모니터링', 2),
#  ('실시', 2),
#  ('움직이', 2),
#  ('종교', 2),
#  ('어울릴', 2),
#  ('무기력증', 2),
#  ('탈피', 2),
#  ('미디어', 2),
#  ('누가', 2),
#  ('나쁘', 2),
#  ('연애', 2),
#  ('학생', 2),
#  ('안타깝', 2),
#  ('주변인', 2),
#  ('전체', 2),
#  ('이렇게', 2),
#  ('설문', 2),
#  ('따른', 2),
#  ('자조', 2),
#  ('고통', 2),
#  ('알림', 2),
#  ('돌봄', 2),
#  ('레터', 2),
#  ('영화', 2),
#  ('초대', 2),
#  ('라면', 2),
#  ('역량', 2),
#  ('도시', 2),
#  ('원할', 2),
#  ('구축', 2),
#  ('인가', 2),
#  ('해소', 2),
#  ('보임', 2),
#  ('와요', 2),
#  ('버린', 2),
#  ('관찰', 2),
#  ('모으', 2),
#  ('셔서', 2),
#  ('극빈층', 2),
#  ('계층', 2),
#  ('특정', 2),
#  ('반영', 2),
#  ('거주지', 2),
#  ('장벽', 2),
#  ('만큼', 2),
#  ('시킬', 2),
#  ('업무', 2),
#  ('갈수록', 2),
#  ('방황', 2),
#  ('일원', 2),
#  ('정해져', 2),
#  ('서적', 2),
#  ('지정', 2),
#  ('식비', 2),
#  ('영향', 2),
#  ('요인', 2),
#  ('으면서', 2),
#  ('낙인', 2),
#  ('모습', 2),
#  ('신다면', 2),
#  ('초년생', 2),
#  ('집단', 2),
#  ('터놓', 2),
#  ('교감', 2),
#  ('방향', 2),
#  ('무리', 2),
#  ('플랫', 2),
#  ('필수', 2),
#  ('생색', 1),
#  ('내기', 1),
#  ('근거리', 1),
#  ('인근', 1),
#  ('줘라', 1),
#  ('크레이', 1),
#  ('병증', 1),
#  ('빠진', 1),
#  ('물붓', 1),
#  ('지원서', 1),
#  ('고서', 1),
#  ('가져', 1),
#  ('선배', 1),
#  ('설정', 1),
#  ('코칭', 1),
#  ('선입견', 1),
#  ('무성의', 1),
#  ('실적', 1),
#  ('보조', 1),
#  ('줘요', 1),
#  ('횟수', 1),
#  ('바깥', 1),
#  ('휴식', 1),
#  ('달라지', 1),
#  ('기술', 1),
#  ('연수', 1),
#  ('받아들이', 1),
#  ('의미', 1),
#  ('느껴', 1),
#  ('도울', 1),
#  ('나마', 1),
#  ('역할', 1),
#  ('헌혈', 1),
#  ('서베이', 1),
#  ('헤이', 1),
#  ('사후', 1),
#  ('연극', 1),
#  ('관람', 1),
#  ('장기전', 1),
#  ('널리', 1),
#  ('수해', 1),
#  ('반지하', 1),
#  ('사고', 1),
#  ('국민', 1),
#  ('투명', 1),
#  ('야외', 1),
#  ('감면', 1),
#  ('행동', 1),
#  ('편집', 1),
#  ('사용법', 1),
#  ('프리허그', 1),
#  ('결심', 1),
#  ('자마자', 1),
#  ('갖춰졌', 1),
#  ('정규직', 1),
#  ('노동자', 1),
#  ('처우', 1),
#  ('확실히', 1),
#  ('이쪽', 1),
#  ('특수', 1),
#  ('설립', 1),
#  ('일회', 1),
#  ('전수', 1),
#  ('할까요', 1),
#  ('정형', 1),
#  ('수원', 1),
#  ('모녀', 1),
#  ('사건', 1),
#  ('갈까', 1),
#  ('강도', 1),
#  ('근로', 1),
#  ('수월', 1),
#  ('뉴스', 1),
#  ('다룬', 1),
#  ('증상', 1),
#  ('불러', 1),
#  ('들어야', 1),
#  ('성별', 1),
#  ('계발', 1),
#  ('주말', 1),
#  ('섬세', 1),
#  ('당장', 1),
#  ('미진', 1),
#  ('결과물', 1),
#  ('보일', 1),
#  ('정착', 1),
#  ('솔직', 1),
#  ('적자', 1),
#  ...]

# %%
with open('/content/drive/MyDrive/파이널 프로젝트/data/stopword.txt', 'r') as f:
    stopwords = [line.strip() for line in f.readlines()]
remove_stopwords = [x for x in remove_one_word if x not in stopwords]
len(remove_stopwords)
# Out:
# 6916

# %%
Counter(remove_stopwords).most_common()
# Out:
# [('지원', 390),
#  ('청년', 170),
#  ('필요', 149),
#  ('상담', 141),
#  ('경제', 137),
#  ('고립', 116),
#  ('활동', 102),
#  ('프로그램', 100),
#  ('정책', 75),
#  ('홍보', 68),
#  ('취업', 68),
#  ('도움', 64),
#  ('다양', 64),
#  ('심리', 61),
#  ('생활', 49),
#  ('참여', 46),
#  ('일자리', 46),
#  ('취미', 44),
#  ('돈', 39),
#  ('중요', 36),
#  ('적극', 36),
#  ('은둔', 35),
#  ('치료', 33),
#  ('모임', 31),
#  ('기회', 31),
#  ('연계', 31),
#  ('제공', 30),
#  ('아요', 28),
#  ('지속', 28),
#  ('가족', 27),
#  ('신청', 27),
#  ('정신', 26),
#  ('서비스', 25),
#  ('관심', 24),
#  ('실질', 24),
#  ('교육', 23),
#  ('지원금', 23),
#  ('운동', 23),
#  ('온라인', 23),
#  ('사업', 22),
#  ('가장', 22),
#  ('비슷', 22),
#  ('방법', 22),
#  ('친구', 21),
#  ('경험', 21),
#  ('마음', 21),
#  ('금전', 20),
#  ('센터', 20),
#  ('방안', 19),
#  ('여러', 19),
#  ('직접', 18),
#  ('대화', 18),
#  ('찾아가', 18),
#  ('나가', 18),
#  ('개인', 18),
#  ('만나', 18),
#  ('도와', 17),
#  ('본인', 17),
#  ('마련', 17),
#  ('소통', 17),
#  ('제도', 16),
#  ('힘들', 16),
#  ('스스로', 15),
#  ('나올', 15),
#  ('상황', 15),
#  ('끼리', 15),
#  ('나갈', 14),
#  ('가능', 14),
#  ('서울시', 14),
#  ('자유', 13),
#  ('부담', 13),
#  ('희망', 13),
#  ('줘야', 13),
#  ('복지', 13),
#  ('시스템', 13),
#  ('먼저', 13),
#  ('접근', 13),
#  ('대상', 13),
#  ('주변', 13),
#  ('장기', 12),
#  ('의지', 12),
#  ('안정', 12),
#  ('방문', 12),
#  ('전문', 12),
#  ('운영', 12),
#  ('나이', 12),
#  ('커뮤니티', 12),
#  ('개월', 12),
#  ('직장', 12),
#  ('사회생활', 12),
#  ('자립', 11),
#  ('효과', 11),
#  ('진행', 11),
#  ('세상', 11),
#  ('생기', 11),
#  ('자체', 11),
#  ('시설', 11),
#  ('자주', 11),
#  ('자연', 11),
#  ('스럽', 11),
#  ('형성', 11),
#  ('네요', 11),
#  ('우울', 11),
#  ('부분', 11),
#  ('아서', 11),
#  ('병원', 11),
#  ('인터넷', 11),
#  ('위해', 11),
#  ('환경', 11),
#  ('비용', 10),
#  ('알려', 10),
#  ('너무', 10),
#  ('직업', 10),
#  ('심리치료', 10),
#  ('대부분', 10),
#  ('해결', 10),
#  ('이유', 10),
#  ('문화', 10),
#  ('취직', 9),
#  ('현금', 9),
#  ('개발', 9),
#  ('봉사', 9),
#  ('정부', 9),
#  ('알선', 9),
#  ('규칙', 9),
#  ('관련', 9),
#  ('생활비', 9),
#  ('공간', 9),
#  ('재정', 9),
#  ('됩니다', 9),
#  ('어려움', 8),
#  ('현실', 8),
#  ('분위기', 8),
#  ('지급', 8),
#  ('전화', 8),
#  ('해결책', 8),
#  ('미래', 8),
#  ('상처', 8),
#  ('편안', 8),
#  ('원인', 8),
#  ('시작', 8),
#  ('극복', 8),
#  ('정서', 8),
#  ('관계', 8),
#  ('자발', 8),
#  ('비대면', 7),
#  ('내용', 7),
#  ('고민', 7),
#  ('유도', 7),
#  ('관리', 7),
#  ('최대한', 7),
#  ('힘든', 7),
#  ('보장', 7),
#  ('익명', 7),
#  ('비대', 7),
#  ('게끔', 7),
#  ('정말', 7),
#  ('교류', 7),
#  ('외부', 7),
#  ('전문가', 7),
#  ('아무', 7),
#  ('처지', 7),
#  ('정기', 7),
#  ('오프라인', 7),
#  ('주거', 7),
#  ('서울', 7),
#  ('뭔가', 7),
#  ('부족', 7),
#  ('혜택', 7),
#  ('어도', 7),
#  ('어려운', 7),
#  ('졌으면', 7),
#  ('연락', 7),
#  ('더욱', 7),
#  ('리커버리', 7),
#  ('보여', 6),
#  ('시켜', 6),
#  ('정보', 6),
#  ('진심', 6),
#  ('주기', 6),
#  ('해도', 6),
#  ('꾸준히', 6),
#  ('어렵', 6),
#  ('해당', 6),
#  ('처음', 6),
#  ('사각지대', 6),
#  ('요즘', 6),
#  ('장소', 6),
#  ('형식', 6),
#  ('기간', 6),
#  ('대상자', 6),
#  ('발굴', 6),
#  ('이용', 6),
#  ('사이트', 6),
#  ('광고', 6),
#  ('클래스', 6),
#  ('만든다', 6),
#  ('문자', 6),
#  ('살아가', 6),
#  ('용기', 6),
#  ('지역', 6),
#  ('라는', 6),
#  ('흥미', 6),
#  ('현재', 6),
#  ('나와', 6),
#  ('또래', 6),
#  ('부탁', 6),
#  ('준비', 5),
#  ('체험', 5),
#  ('자살', 5),
#  ('느낄', 5),
#  ('인식', 5),
#  ('본다', 5),
#  ('제대로', 5),
#  ('이야기', 5),
#  ('인생', 5),
#  ('느끼', 5),
#  ('다가가', 5),
#  ('누군가', 5),
#  ('이해', 5),
#  ('늘리', 5),
#  ('일회성', 5),
#  ('계기', 5),
#  ('입장', 5),
#  ('존재', 5),
#  ('세금', 5),
#  ('과정', 5),
#  ('산책', 5),
#  ('채널', 5),
#  ('맞춤', 5),
#  ('개선', 5),
#  ('청소년', 5),
#  ('학교', 5),
#  ('거주', 5),
#  ('조사', 5),
#  ('확실', 5),
#  ('제한', 5),
#  ('단체', 5),
#  ('이미', 5),
#  ('신체', 5),
#  ('으니', 5),
#  ('자격증', 5),
#  ('그냥', 5),
#  ('공감대', 5),
#  ('파악', 5),
#  ('체계', 5),
#  ('려는', 5),
#  ('채팅', 5),
#  ('밖에', 5),
#  ('감사', 5),
#  ('반복', 5),
#  ('한다는', 5),
#  ('소득', 5),
#  ('공부', 5),
#  ('려면', 5),
#  ('적응', 5),
#  ('마다', 5),
#  ('들어가', 5),
#  ('확대', 5),
#  ('상태', 5),
#  ('찾아내', 5),
#  ('요청', 5),
#  ('기본', 5),
#  ('응원', 5),
#  ('매체', 5),
#  ('단어', 5),
#  ('영상', 5),
#  ('주택', 4),
#  ('로운', 4),
#  ('또는', 4),
#  ('가벼운', 4),
#  ('차근차근', 4),
#  ('단계', 4),
#  ('여가', 4),
#  ('조언', 4),
#  ('진정', 4),
#  ('대면', 4),
#  ('듭니다', 4),
#  ('괜찮', 4),
#  ('포인트', 4),
#  ('목적', 4),
#  ('일상', 4),
#  ('인데', 4),
#  ('자금', 4),
#  ('우울증', 4),
#  ('부모', 4),
#  ('걱정', 4),
#  ('보내', 4),
#  ('병행', 4),
#  ('창업', 4),
#  ('멘토', 4),
#  ('줘서', 4),
#  ('담사', 4),
#  ('케어', 4),
#  ('실제', 4),
#  ('봐야', 4),
#  ('활성', 4),
#  ('외출', 4),
#  ('세대', 4),
#  ('훈련', 4),
#  ('인지', 4),
#  ('부담없이', 4),
#  ('페이지', 4),
#  ('노출', 4),
#  ('바우처', 4),
#  ('데이', 4),
#  ('강화', 4),
#  ('사용', 4),
#  ('자리', 4),
#  ('일어나', 4),
#  ('성취감', 4),
#  ('챌린지', 4),
#  ('달성', 4),
#  ('물고기', 4),
#  ('프로젝트', 4),
#  ('선택', 4),
#  ('절차', 4),
#  ('려고', 4),
#  ('외톨이', 4),
#  ('추천', 4),
#  ('보호', 4),
#  ('다니', 4),
#  ('새로운', 4),
#  ('걸로', 4),
#  ('검사', 4),
#  ('제일', 4),
#  ('건강', 4),
#  ('못했', 4),
#  ('시대', 4),
#  ('창출', 4),
#  ('노력', 4),
#  ('적절', 4),
#  ('편하', 4),
#  ('가정', 4),
#  ('분야', 4),
#  ('연결', 4),
#  ('근본', 4),
#  ('가볍', 4),
#  ('코로나', 4),
#  ('수준', 4),
#  ('을까', 4),
#  ('이끌', 4),
#  ('점점', 4),
#  ('더더욱', 4),
#  ('위치', 4),
#  ('교통비', 4),
#  ('해준다', 4),
#  ('굳이', 4),
#  ('불안', 4),
#  ('기관', 4),
#  ('코치', 4),
#  ('푸른', 4),
#  ('고래', 4),
#  ('주세요', 3),
#  ('규모', 3),
#  ('모여서', 3),
#  ('금액', 3),
#  ('예방', 3),
#  ('대책', 3),
#  ('고자', 3),
#  ('동아리', 3),
#  ('로서', 3),
#  ('진로', 3),
#  ('시행', 3),
#  ('위주', 3),
#  ('딱히', 3),
#  ('을까요', 3),
#  ('수업', 3),
#  ('공원', 3),
#  ('게임', 3),
#  ('탁상행정', 3),
#  ('노동', 3),
#  ('절대', 3),
#  ('결과', 3),
#  ('계속', 3),
#  ('활발', 3),
#  ('중증', 3),
#  ('자존', 3),
#  ('순간', 3),
#  ('구나', 3),
#  ('길러', 3),
#  ('배움', 3),
#  ('장려', 3),
#  ('휴대폰', 3),
#  ('버스', 3),
#  ('제발', 3),
#  ('동기', 3),
#  ('부여', 3),
#  ('단절', 3),
#  ('알리', 3),
#  ('그만', 3),
#  ('카카오톡', 3),
#  ('모아', 3),
#  ('쉬운', 3),
#  ('모여', 3),
#  ('즐기', 3),
#  ('서로', 3),
#  ('만남', 3),
#  ('이동', 3),
#  ('카톡', 3),
#  ('없애', 3),
#  ('보통', 3),
#  ('방식', 3),
#  ('나와서', 3),
#  ('나눌', 3),
#  ('충분', 3),
#  ('주민', 3),
#  ('일시', 3),
#  ('조건', 3),
#  ('소모임', 3),
#  ('연령', 3),
#  ('무료', 3),
#  ('신청자', 3),
#  ('는다', 3),
#  ('위로', 3),
#  ('으며', 3),
#  ('직장인', 3),
#  ('소개', 3),
#  ('아침', 3),
#  ('강제', 3),
#  ('경력', 3),
#  ('멘토링', 3),
#  ('주선', 3),
#  ('이루', 3),
#  ('목표', 3),
#  ('바랍니다', 3),
#  ('등록', 3),
#  ('창구', 3),
#  ('구요', 3),
#  ('만족', 3),
#  ('끝나', 3),
#  ('캠페인', 3),
#  ('인력', 3),
#  ('친밀감', 3),
#  ('보단', 3),
#  ('니까요', 3),
#  ('므로', 3),
#  ('단기', 3),
#  ('감정', 3),
#  ('알아보', 3),
#  ('불편', 3),
#  ('강요', 3),
#  ('서서히', 3),
#  ('보살핌', 3),
#  ('실업', 3),
#  ('그렇게', 3),
#  ('시기', 3),
#  ('발견', 3),
#  ('점차', 3),
#  ('성향', 3),
#  ('꾸준', 3),
#  ('생겼으면', 3),
#  ('공유', 3),
#  ('은데', 3),
#  ('생계', 3),
#  ('원하', 3),
#  ('일정', 3),
#  ('마케팅', 3),
#  ('을지', 3),
#  ('모든', 3),
#  ('못한', 3),
#  ('몰랐', 3),
#  ('개설', 3),
#  ('공무원', 3),
#  ('재활', 3),
#  ('절실', 3),
#  ('참석', 3),
#  ('대출', 3),
#  ('드립니다', 3),
#  ('메신저', 3),
#  ('일본', 3),
#  ('운둔', 3),
#  ('약물', 3),
#  ('기준', 3),
#  ('비밀', 3),
#  ('조심', 3),
#  ('스러운', 3),
#  ('부작용', 3),
#  ('무조건', 3),
#  ('보인다', 3),
#  ('실행', 3),
#  ('접근성', 3),
#  ('지인', 3),
#  ('인간', 3),
#  ('끌어내', 3),
#  ('늘려', 3),
#  ('확인', 3),
#  ('얘기', 3),
#  ('만날', 3),
#  ('홈페이지', 3),
#  ('겁니다', 3),
#  ('지향', 3),
#  ('성과', 3),
#  ('학원', 3),
#  ('가량', 3),
#  ('하나하나', 3),
#  ('사무실', 3),
#  ('구직', 2),
#  ('임대', 2),
#  ('실직', 2),
#  ('식사', 2),
#  ('포함', 2),
#  ('이벤트', 2),
#  ('증진', 2),
#  ('순위', 2),
#  ('회복', 2),
#  ('이겨', 2),
#  ('기인', 2),
#  ('지원자', 2),
#  ('계열', 2),
#  ('가진', 2),
#  ('국가', 2),
#  ('쿠폰', 2),
#  ('무작정', 2),
#  ('거부', 2),
#  ('실용', 2),
#  ('좌절', 2),
#  ('이전', 2),
#  ('달리', 2),
#  ('가치', 2),
#  ('월세', 2),
#  ('변경', 2),
#  ('콘서트', 2),
#  ('돌아가', 2),
#  ('신경', 2),
#  ('유튜브', 2),
#  ('어떨지', 2),
#  ('이러', 2),
#  ('선별', 2),
#  ('신원', 2),
#  ('맞춰서', 2),
#  ('홀로', 2),
#  ('공공', 2),
#  ('대해', 2),
#  ('격려', 2),
#  ('액티비티', 2),
#  ('단순', 2),
#  ('된다', 2),
#  ('어떠', 2),
#  ('영역', 2),
#  ('독서', 2),
#  ('구제', 2),
#  ('이어진', 2),
#  ('봅니다', 2),
#  ('높여', 2),
#  ('괴롭힘', 2),
#  ('과거', 2),
#  ('어떤지', 2),
#  ('더라구요', 2),
#  ('확충', 2),
#  ('긍정', 2),
#  ('전달', 2),
#  ('억지로', 2),
#  ('네트워크', 2),
#  ('처방', 2),
#  ('진단', 2),
#  ('집중', 2),
#  ('익숙', 2),
#  ('버리', 2),
#  ('탈출', 2),
#  ('시민', 2),
#  ('시청', 2),
#  ('강의', 2),
#  ('기획', 2),
#  ('은지', 2),
#  ('였으면', 2),
#  ('나와야', 2),
#  ('한때', 2),
#  ('내밀', 2),
#  ('가져가', 2),
#  ('지나치', 2),
#  ('나약', 2),
#  ('낭비', 2),
#  ('사소', 2),
#  ('정작', 2),
#  ('회성', 2),
#  ('높인다', 2),
#  ('천천히', 2),
#  ('질환', 2),
#  ('자의', 2),
#  ('다가갈', 2),
#  ('접촉', 2),
#  ('실제로', 2),
#  ('이후', 2),
#  ('생계비', 2),
#  ('가구', 2),
#  ('에요', 2),
#  ('무기력', 2),
#  ('아무것', 2),
#  ('주로', 2),
#  ('간단', 2),
#  ('랜덤', 2),
#  ('인턴', 2),
#  ('구청', 2),
#  ('적성', 2),
#  ('양질', 2),
#  ('여행', 2),
#  ('포털', 2),
#  ('안내', 2),
#  ('모집', 2),
#  ('찾아봐', 2),
#  ('건가', 2),
#  ('텐데', 2),
#  ('모이', 2),
#  ('들어줄', 2),
#  ('이라도', 2),
#  ('기업', 2),
#  ('둔하', 2),
#  ('물질', 2),
#  ('인해', 2),
#  ('인증', 2),
#  ('하루', 2),
#  ('높이', 2),
#  ('엄청난', 2),
#  ('공감', 2),
#  ('주소', 2),
#  ('나요', 2),
#  ('당사자', 2),
#  ('지지', 2),
#  ('압박감', 2),
#  ('범죄', 2),
#  ('피해자', 2),
#  ('비난', 2),
#  ('져야', 2),
#  ('표현', 2),
#  ('감이', 2),
#  ('갑자기', 2),
#  ('그만두', 2),
#  ('가질', 2),
#  ('어려울', 2),
#  ('실업자', 2),
#  ('간편', 2),
#  ('여야', 2),
#  ('꺼리', 2),
#  ('면접', 2),
#  ('다닐', 2),
#  ('배송', 2),
#  ('즐길', 2),
#  ('항상', 2),
#  ('무서워', 2),
#  ('뭔지', 2),
#  ('할꺼', 2),
#  ('외로움', 2),
#  ('살아갈', 2),
#  ('강연', 2),
#  ('부정', 2),
#  ('전반', 2),
#  ('조성', 2),
#  ('찾아보', 2),
#  ('격월', 2),
#  ('벗어날', 2),
#  ('체크', 2),
#  ('지내', 2),
#  ('선생', 2),
#  ('이름', 2),
#  ('저렴', 2),
#  ('대응', 2),
#  ('모색', 2),
#  ('도와야', 2),
#  ('살리', 2),
#  ('아님', 2),
#  ('저소득', 2),
#  ('육체', 2),
#  ('히키코모리', 2),
#  ('질병', 2),
#  ('여겨진다', 2),
#  ('성실', 2),
#  ('매우', 2),
#  ('리라', 2),
#  ('도와준다', 2),
#  ('의문', 2),
#  ('확률', 2),
#  ('으므로', 2),
#  ('인한', 2),
#  ('취향', 2),
#  ('심각', 2),
#  ('티비', 2),
#  ('불쾌', 2),
#  ('능력', 2),
#  ('기르', 2),
#  ('찾아갈', 2),
#  ('동네', 2),
#  ('완화', 2),
#  ('보살펴', 2),
#  ('급하', 2),
#  ('그나마', 2),
#  ('단기간', 2),
#  ('패배감', 2),
#  ('빠지', 2),
#  ('집니다', 2),
#  ('강제성', 2),
#  ('어려워하', 2),
#  ('낯선', 2),
#  ('리프', 2),
#  ('스러워', 2),
#  ('된다면', 2),
#  ('화상', 2),
#  ('유능', 2),
#  ('수입', 2),
#  ('활력', 2),
#  ('걸으며', 2),
#  ('쓰레기', 2),
#  ('유지', 2),
#  ('제시', 2),
#  ('대인', 2),
#  ('방면', 2),
#  ('알려줘야', 2),
#  ('시도', 2),
#  ('카페', 2),
#  ('둔한', 2),
#  ('독려', 2),
#  ('만드', 2),
#  ('성격', 2),
#  ('그래야', 2),
#  ('자괴감', 2),
#  ('든다', 2),
#  ('헬스', 2),
#  ('도덕', 2),
#  ('보상', 2),
#  ('특히', 2),
#  ('요리', 2),
#  ('아무런', 2),
#  ('내일', 2),
#  ('바람', 2),
#  ('즐겁', 2),
#  ('그룹', 2),
#  ('부끄럽', 2),
#  ('장점', 2),
#  ('보험', 2),
#  ('프리랜서', 2),
#  ('단편', 2),
#  ('신고', 2),
#  ('모니터링', 2),
#  ('실시', 2),
#  ('움직이', 2),
#  ('종교', 2),
#  ('어울릴', 2),
#  ('무기력증', 2),
#  ('탈피', 2),
#  ('미디어', 2),
#  ('누가', 2),
#  ('나쁘', 2),
#  ('연애', 2),
#  ('학생', 2),
#  ('안타깝', 2),
#  ('주변인', 2),
#  ('전체', 2),
#  ('이렇게', 2),
#  ('설문', 2),
#  ('따른', 2),
#  ('자조', 2),
#  ('고통', 2),
#  ('알림', 2),
#  ('돌봄', 2),
#  ('레터', 2),
#  ('영화', 2),
#  ('초대', 2),
#  ('라면', 2),
#  ('역량', 2),
#  ('도시', 2),
#  ('원할', 2),
#  ('구축', 2),
#  ('인가', 2),
#  ('해소', 2),
#  ('보임', 2),
#  ('와요', 2),
#  ('버린', 2),
#  ('관찰', 2),
#  ('모으', 2),
#  ('셔서', 2),
#  ('극빈층', 2),
#  ('계층', 2),
#  ('특정', 2),
#  ('반영', 2),
#  ('거주지', 2),
#  ('장벽', 2),
#  ('만큼', 2),
#  ('시킬', 2),
#  ('업무', 2),
#  ('갈수록', 2),
#  ('방황', 2),
#  ('일원', 2),
#  ('정해져', 2),
#  ('서적', 2),
#  ('지정', 2),
#  ('식비', 2),
#  ('영향', 2),
#  ('요인', 2),
#  ('으면서', 2),
#  ('낙인', 2),
#  ('모습', 2),
#  ('신다면', 2),
#  ('초년생', 2),
#  ('집단', 2),
#  ('터놓', 2),
#  ('교감', 2),
#  ('방향', 2),
#  ('무리', 2),
#  ('플랫', 2),
#  ('필수', 2),
#  ('생색', 1),
#  ('내기', 1),
#  ('근거리', 1),
#  ('인근', 1),
#  ('줘라', 1),
#  ('크레이', 1),
#  ('병증', 1),
#  ('빠진', 1),
#  ('물붓', 1),
#  ('지원서', 1),
#  ('고서', 1),
#  ('가져', 1),
#  ('선배', 1),
#  ('설정', 1),
#  ('코칭', 1),
#  ('선입견', 1),
#  ('무성의', 1),
#  ('실적', 1),
#  ('보조', 1),
#  ('줘요', 1),
#  ('횟수', 1),
#  ('바깥', 1),
#  ('휴식', 1),
#  ('달라지', 1),
#  ('기술', 1),
#  ('연수', 1),
#  ('받아들이', 1),
#  ('의미', 1),
#  ('느껴', 1),
#  ('도울', 1),
#  ('나마', 1),
#  ('역할', 1),
#  ('헌혈', 1),
#  ('서베이', 1),
#  ('헤이', 1),
#  ('사후', 1),
#  ('연극', 1),
#  ('관람', 1),
#  ('장기전', 1),
#  ('널리', 1),
#  ('수해', 1),
#  ('반지하', 1),
#  ('사고', 1),
#  ('국민', 1),
#  ('투명', 1),
#  ('야외', 1),
#  ('감면', 1),
#  ('행동', 1),
#  ('편집', 1),
#  ('사용법', 1),
#  ('프리허그', 1),
#  ('결심', 1),
#  ('갖춰졌', 1),
#  ('정규직', 1),
#  ('노동자', 1),
#  ('처우', 1),
#  ('확실히', 1),
#  ('특수', 1),
#  ('설립', 1),
#  ('일회', 1),
#  ('전수', 1),
#  ('할까요', 1),
#  ('정형', 1),
#  ('수원', 1),
#  ('모녀', 1),
#  ('사건', 1),
#  ('갈까', 1),
#  ('강도', 1),
#  ('근로', 1),
#  ('수월', 1),
#  ('뉴스', 1),
#  ('다룬', 1),
#  ('증상', 1),
#  ('불러', 1),
#  ('들어야', 1),
#  ('성별', 1),
#  ('계발', 1),
#  ('주말', 1),
#  ('섬세', 1),
#  ('미진', 1),
#  ('결과물', 1),
#  ('보일', 1),
#  ('정착', 1),
#  ('솔직', 1),
#  ('적자', 1),
#  ('통상', 1),
#  ('유년', 1),
#  ('시절', 1),
#  ('비롯', 1),
#  ('어릴', 1),
#  ('총제', 1),
#  ('드러내', 1),
#  ('치유', 1),
#  ('예전', 1),
#  ('당해서', 1),
#  ('무서웠', 1),
#  ('드리', 1),
#  ('깨달', 1),
#  ('견해', 1),
#  ('견문', 1),
#  ('넓히', 1),
#  ('저런', 1),
#  ('간접', 1),
#  ('조그만', 1),
#  ('세계', 1),
#  ('관점', 1),
#  ('바라볼', 1),
#  ('매칭', 1),
#  ('임시', 1),
#  ('거처', 1),
#  ('세심', 1),
#  ('내세운', 1),
#  ('사전', 1),
#  ('연습', 1),
#  ('목욕', 1),
#  ('메세지', 1),
#  ('고맙', 1),
#  ('픽업', 1),
#  ('구내', 1),
#  ('셔틀', 1),
#  ('데려다', 1),
#  ('동영상', 1),
#  ('작업', 1),
#  ('달라져야', 1),
#  ('해져', 1),
#  ('안다면', 1),
#  ('맡기', 1),
#  ('차원', 1),
#  ('꾸려', 1),
#  ('바리스타', 1),
#  ('워드', 1),
#  ('시험료', 1),
#  ('수요', 1),
#  ('떨어지', 1),
#  ('환원', 1),
#  ('순환', 1),
#  ('이끈', 1),
#  ('못할', 1),
#  ('정비', 1),
#  ('한다던', 1),
#  ('기록', 1),
#  ('제출', 1),
#  ('한다던가', 1),
#  ('넉넉', 1),
#  ('초반', 1),
#  ('불화', 1),
#  ('했으나', 1),
#  ('어쩔', 1),
#  ('고쳐졌', 1),
#  ('평생', 1),
#  ('숙제', 1),
#  ('다르', 1),
#  ('나태', 1),
#  ('만든다고', 1),
#  ('놔두', 1),
#  ('어차피', 1),
#  ('행복', 1),
#  ('생산', 1),
#  ('모를', 1),
#  ('메일', 1),
#  ('그닥', 1),
#  ('합숙', 1),
#  ('캠핑', 1),
#  ('서바이벌', 1),
#  ('독립심', 1),
#  ('다과', 1),
#  ('고충', 1),
#  ('학력', 1),
#  ('이룰', 1),
#  ('섣불리', 1),
#  ('음지', 1),
#  ('사명감', 1),
#  ('셔야', 1),
#  ('중단', 1),
#  ('권해', 1),
#  ('절대로', 1),
#  ('다님', 1),
#  ('반대', 1),
#  ('대안', 1),
#  ('바란다', 1),
#  ('메신져', 1),
#  ('싫어하', 1),
#  ('감당', 1),
#  ('뒷받침', 1),
#  ('공용', 1),
#  ('이제', 1),
#  ('반지', 1),
#  ('올리', 1),
#  ('몰두', 1),
#  ('강구', 1),
#  ('대내외', 1),
#  ('강압', 1),
#  ('올라와', 1),
#  ('으니까', 1),
#  ('두둑히', 1),
#  ('후기', 1),
#  ('현물', 1),
#  ('부합', 1),
#  ('코너', 1),
#  ('현수막', 1),
#  ...]

# %%
minimum_count = 20
more_than_one_time= []
for i in tqdm(range(len(remove_stopwords))):
    tmp = remove_stopwords[i]
    if remove_stopwords.count(tmp) >= minimum_count:
        more_than_one_time.append(tmp)

more_than_one_time
# Out:
# 100%|██████████| 6916/6916 [00:01<00:00, 4354.25it/s]
# ['청년',
#  '사업',
#  '필요',
#  '경제',
#  '도움',
#  '상담',
#  '홍보',
#  '아요',
#  '취업',
#  '모임',
#  '프로그램',
#  '참여',
#  '지원',
#  '정책',
#  '경제',
#  '지원',
#  '다양',
#  '홍보',
#  '활동',
#  '돈',
#  '지원',
#  '지원',
#  '경제',
#  '지속',
#  '지원',
#  '치료',
#  '관심',
#  '참여',
#  '심리',
#  '가장',
#  '중요',
#  '지원',
#  '비슷',
#  '모임',
#  '치료',
#  '취미',
#  '활동',
#  '다양',
#  '관심',
#  '정신',
#  '실질',
#  '도움',
#  '다양',
#  '활동',
#  '경제',
#  '지원',
#  '청년',
#  '다양',
#  '친구',
#  '정책',
#  '정책',
#  '방법',
#  '필요',
#  '금전',
#  '지원',
#  '고립',
#  '청년',
#  '중요',
#  '경제',
#  '돈',
#  '제공',
#  '지속',
#  '활동',
#  '방법',
#  '취업',
#  '경제',
#  '지원',
#  '지속',
#  '지원',
#  '필요',
#  '심리',
#  '상담',
#  '프로그램',
#  '필요',
#  '교육',
#  '교육',
#  '기회',
#  '활동',
#  '방법',
#  '경험',
#  '고립',
#  '생활',
#  '방법',
#  '활동',
#  '참여',
#  '참여',
#  '지원',
#  '정책',
#  '지원',
#  '정신',
#  '고립',
#  '청년',
#  '취업',
#  '연계',
#  '사업',
#  '돈',
#  '지속',
#  '지원',
#  '중요',
#  '기회',
#  '서비스',
#  '상담',
#  '홍보',
#  '상담',
#  '취업',
#  '지원',
#  '가족',
#  '금전',
#  '지원금',
#  '지원',
#  '기회',
#  '친구',
#  '경제',
#  '활동',
#  '참여',
#  '프로그램',
#  '취업',
#  '연계',
#  '청년',
#  '활동',
#  '돈',
#  '돈',
#  '방법',
#  '프로그램',
#  '교육',
#  '운동',
#  '상담',
#  '지원',
#  '친구',
#  '사업',
#  '지원',
#  '정책',
#  '지원',
#  '서비스',
#  '도움',
#  '필요',
#  '적극',
#  '지원',
#  '일자리',
#  '청년',
#  '경제',
#  '지원',
#  '지속',
#  '경제',
#  '지원',
#  '경험',
#  '청년',
#  '경제',
#  '지원',
#  '경제',
#  '상담',
#  '도움',
#  '도움',
#  '필요',
#  '상담',
#  '청년',
#  '고립',
#  '청년',
#  '도움',
#  '고립',
#  '정책',
#  '관심',
#  '일자리',
#  '제공',
#  '경제',
#  '활동',
#  '참여',
#  '정책',
#  '청년',
#  '지원',
#  '가장',
#  '중요',
#  '돈',
#  '경제',
#  '지원',
#  '고립',
#  '지속',
#  '관심',
#  '필요',
#  '정책',
#  '적극',
#  '홍보',
#  '필요',
#  '경제',
#  '지원',
#  '필요',
#  '경제',
#  '지원',
#  '프로그램',
#  '적극',
#  '고립',
#  '청년',
#  '참여',
#  '적극',
#  '경제',
#  '지원',
#  '취업',
#  '연계',
#  '지원',
#  '필요',
#  '참여',
#  '활동',
#  '프로그램',
#  '참여',
#  '모임',
#  '다양',
#  '일자리',
#  '취업',
#  '기회',
#  '제공',
#  '정책',
#  '방법',
#  '활동',
#  '일자리',
#  '일자리',
#  '취업',
#  '필요',
#  '지원',
#  '다양',
#  '지원',
#  '필요',
#  '고립',
#  '청년',
#  '지원',
#  '사업',
#  '상담',
#  '정책',
#  '홍보',
#  '방법',
#  '가족',
#  '상담',
#  '활동',
#  '프로그램',
#  '마음',
#  '정책',
#  '취업',
#  '활동',
#  '지원',
#  '적극',
#  '돈',
#  '지원',
#  '지원금',
#  '관심',
#  '활동',
#  '경제',
#  '지원',
#  '온라인',
#  '홍보',
#  '지원',
#  '정책',
#  '상담',
#  '치료',
#  '취업',
#  '활동',
#  '경제',
#  '지원',
#  '상담',
#  '지원',
#  '서비스',
#  '교육',
#  '온라인',
#  '홍보',
#  '금전',
#  '지원',
#  '심리',
#  '상담',
#  '가족',
#  '취업',
#  '지원',
#  '상담',
#  '가장',
#  '생활',
#  '운동',
#  '프로그램',
#  '참여',
#  '프로그램',
#  '마음',
#  '다양',
#  '고립',
#  '경제',
#  '지원',
#  '상담',
#  '활동',
#  '활동',
#  '필요',
#  '방법',
#  '운동',
#  '프로그램',
#  '적극',
#  '운동',
#  '다양',
#  '활동',
#  '취업',
#  '필요',
#  '제공',
#  '지원',
#  '홍보',
#  '참여',
#  '생활',
#  '도움',
#  '프로그램',
#  '다양',
#  '활동',
#  '기회',
#  '적극',
#  '기회',
#  '고립',
#  '참여',
#  '돈',
#  '고립',
#  '청년',
#  '지원',
#  '사업',
#  '사업',
#  '지원',
#  '고립',
#  '청년',
#  '지원',
#  '정책',
#  '가장',
#  '중요',
#  '은둔',
#  '고립',
#  '청년',
#  '가장',
#  '중요',
#  '돈',
#  '지원',
#  '돈',
#  '돈',
#  '지원',
#  '경제',
#  '가족',
#  '은둔',
#  '경험',
#  '돈',
#  '청년',
#  '서비스',
#  '지원',
#  '고립',
#  '청년',
#  '지원',
#  '돈',
#  '관심',
#  '생활',
#  '은둔',
#  '고립',
#  '필요',
#  '지원',
#  '친구',
#  '프로그램',
#  '상담',
#  '상담',
#  '지원',
#  '지원',
#  '아요',
#  '활동',
#  '홍보',
#  '도움',
#  '도움',
#  '중요',
#  '비슷',
#  '다양',
#  '상담',
#  '프로그램',
#  '온라인',
#  '지원',
#  '경제',
#  '심리',
#  '지원',
#  '비슷',
#  '취미',
#  '프로그램',
#  '상담',
#  '다양',
#  '필요',
#  '정책',
#  '심리',
#  '상담',
#  '정신',
#  '상담',
#  '상담',
#  '상담',
#  '정신',
#  '치료',
#  '청년',
#  '치료',
#  '청년',
#  '정신',
#  '치료',
#  '필요',
#  '정책',
#  '실질',
#  '정책',
#  '금전',
#  '지원',
#  '경제',
#  '지원',
#  '상담',
#  '상담',
#  '지속',
#  '상담',
#  '필요',
#  '제공',
#  '심리',
#  '상담',
#  '지속',
#  '관심',
#  '필요',
#  '지원',
#  '다양',
#  '서비스',
#  '정책',
#  '경험',
#  '친구',
#  '돈',
#  '경제',
#  '지원',
#  '지원',
#  '일자리',
#  '지원',
#  '지원',
#  '취업',
#  '지원',
#  '서비스',
#  '교육',
#  '고립',
#  '취업',
#  '경제',
#  '활동',
#  '다양',
#  '활동',
#  '프로그램',
#  '실질',
#  '필요',
#  '가장',
#  '중요',
#  '지원',
#  '경제',
#  '정신',
#  '고립',
#  '청년',
#  '지원',
#  '지원',
#  '필요',
#  '상담',
#  '가장',
#  '필요',
#  '심리',
#  '상담',
#  '고립',
#  '은둔',
#  '도움',
#  '취미',
#  '프로그램',
#  '지원',
#  '일자리',
#  '상담',
#  '치료',
#  '지원',
#  '필요',
#  '지원',
#  '금전',
#  '프로그램',
#  '경제',
#  '지원',
#  '취미',
#  '일자리',
#  '제공',
#  '경제',
#  '지원',
#  '지속',
#  '관심',
#  '경제',
#  '지원',
#  '서비스',
#  '지원',
#  '지원',
#  '정책',
#  '필요',
#  '연계',
#  '프로그램',
#  '적극',
#  '홍보',
#  '활동',
#  '필요',
#  '지원',
#  '실질',
#  '취미',
#  '활동',
#  '지원',
#  '경제',
#  '지원',
#  '필요',
#  '금전',
#  '지원',
#  '활동',
#  '지원',
#  '돈',
#  '일자리',
#  '지원',
#  '프로그램',
#  '서비스',
#  '제공',
#  '일자리',
#  '지원',
#  '상담',
#  '취미',
#  '활동',
#  '비슷',
#  '기회',
#  '제공',
#  '상담',
#  '취미',
#  '프로그램',
#  '일자리',
#  '모임',
#  '지원',
#  '다양',
#  '활동',
#  '홍보',
#  '홍보',
#  '필요',
#  '필요',
#  '지원',
#  '다양',
#  '센터',
#  '홍보',
#  '취미',
#  '운동',
#  '모임',
#  '참여',
#  '제공',
#  '고립',
#  '청년',
#  '적극',
#  '지원',
#  '모임',
#  '활동',
#  '고립',
#  '활동',
#  '생활',
#  '연계',
#  '센터',
#  '취미',
#  '활동',
#  '일자리',
#  '제공',
#  '다양',
#  '지원',
#  '다양',
#  '취미',
#  '활동',
#  '청년',
#  '연계',
#  '지원',
#  '프로그램',
#  '활동',
#  '지속',
#  '청년',
#  '홍보',
#  '필요',
#  '지원',
#  '상담',
#  '홍보',
#  '활동',
#  '모임',
#  '청년',
#  '아요',
#  '상담',
#  '생활',
#  '지원',
#  '생활',
#  '지원',
#  '고립',
#  '사업',
#  '경제',
#  '고립',
#  '온라인',
#  '홍보',
#  '심리',
#  '상담',
#  '취미',
#  '생활',
#  '프로그램',
#  '운동',
#  '기회',
#  '제공',
#  '실질',
#  '도움',
#  '필요',
#  '지원',
#  '아요',
#  '일자리',
#  '정신',
#  '상담',
#  '경제',
#  '지원',
#  '지원',
#  '참여',
#  '프로그램',
#  '온라인',
#  '취미',
#  '활동',
#  '지원',
#  '고립',
#  '은둔',
#  '지원',
#  '일자리',
#  '연계',
#  '지원',
#  '홍보',
#  '필요',
#  '취미',
#  '생활',
#  '지원',
#  '고립',
#  '청년',
#  '온라인',
#  '상담',
#  '센터',
#  '마음',
#  '필요',
#  '경제',
#  '지원',
#  '필요',
#  '경험',
#  '생활',
#  '고립',
#  '생활',
#  '생활',
#  '지원',
#  '프로그램',
#  '지원',
#  '지원',
#  '생활',
#  '활동',
#  '프로그램',
#  '경험',
#  '생활',
#  '필요',
#  '경험',
#  '고립',
#  '은둔',
#  '생활',
#  '지원',
#  '필요',
#  '정신',
#  '상담',
#  '지원',
#  '방법',
#  '지속',
#  '프로그램',
#  '프로그램',
#  '연계',
#  '지원',
#  '상담',
#  '경제',
#  '프로그램',
#  '필요',
#  '필요',
#  '취업',
#  '생활',
#  '생활',
#  '실질',
#  '도움',
#  '경제',
#  '지원',
#  '적극',
#  '취업',
#  '도움',
#  '심리',
#  '상담',
#  '상담',
#  '필요',
#  '친구',
#  '프로그램',
#  '필요',
#  '상담',
#  '활동',
#  '경제',
#  '지원',
#  '상담',
#  '치료',
#  '지속',
#  '지원',
#  '온라인',
#  '상담',
#  '다양',
#  '지원',
#  '모임',
#  '실질',
#  '지원',
#  '필요',
#  '은둔',
#  '은둔',
#  '지원',
#  '지원',
#  '필요',
#  '지원',
#  '취업',
#  '도움',
#  '심리',
#  '지원',
#  '돈',
#  '지원',
#  '심리',
#  '상담',
#  '홍보',
#  '다양',
#  '경제',
#  '지원',
#  '비슷',
#  '취미',
#  '활동',
#  '실질',
#  '일자리',
#  '도움',
#  '제공',
#  '실질',
#  '방법',
#  '실질',
#  '방법',
#  '일자리',
#  '지원',
#  '도움',
#  '활동',
#  '정신',
#  '실질',
#  '도움',
#  '지원',
#  '청년',
#  '은둔',
#  '심리',
#  '치료',
#  '필요',
#  '필요',
#  '고립',
#  '상담',
#  '온라인',
#  '아요',
#  '청년',
#  '기회',
#  '경제',
#  '지원',
#  '청년',
#  '지원',
#  '도움',
#  '지원',
#  '적극',
#  '홍보',
#  '취미',
#  '생활',
#  '지원',
#  '금전',
#  '지원',
#  '필요',
#  '지원',
#  '마음',
#  '치료',
#  '치료',
#  '모임',
#  '상담',
#  '활동',
#  '지원',
#  '활동',
#  '일자리',
#  '경제',
#  '지원',
#  '은둔',
#  '청년',
#  '고립',
#  '청년',
#  '경제',
#  '지원',
#  '정책',
#  '지원',
#  '홍보',
#  '신청',
#  '지원금',
#  '상담',
#  '마음',
#  '고립',
#  '적극',
#  '홍보',
#  '참여',
#  '상담',
#  '청년',
#  '프로그램',
#  '고립',
#  '중요',
#  '중요',
#  '다양',
#  '일자리',
#  '지원',
#  '일자리',
#  '지원',
#  '청년',
#  '지원',
#  '온라인',
#  '심리',
#  '상담',
#  '지원',
#  '필요',
#  '상담',
#  '센터',
#  '아요',
#  '지원',
#  '경험',
#  '경제',
#  '지원',
#  '지원',
#  '아요',
#  '청년',
#  '활동',
#  '지원',
#  '필요',
#  '실질',
#  '도움',
#  '심리',
#  '다양',
#  '생활',
#  '홍보',
#  '경제',
#  '도움',
#  '필요',
#  '관심',
#  '다양',
#  '프로그램',
#  '생활',
#  '활동',
#  '경제',
#  '지원',
#  '지원',
#  '경제',
#  '교육',
#  '필요',
#  '심리',
#  '지원',
#  '중요',
#  '고립',
#  '고립',
#  '청년',
#  '마음',
#  '상담',
#  '일자리',
#  '연계',
#  '사업',
#  '심리',
#  '상담',
#  '정신',
#  '치료',
#  '가족',
#  '상담',
#  '필요',
#  '아요',
#  '상담',
#  '가장',
#  '돈',
#  '돈',
#  '취업',
#  '일자리',
#  '연계',
#  '정책',
#  '필요',
#  '심리',
#  '상담',
#  '돈',
#  '취업',
#  '필요',
#  '정책',
#  '다양',
#  '홍보',
#  '필요',
#  '고립',
#  '청년',
#  '필요',
#  '마음',
#  '프로그램',
#  '신청',
#  '마음',
#  '신청',
#  '신청',
#  '신청',
#  '온라인',
#  '신청',
#  '신청',
#  '센터',
#  '신청',
#  '은둔',
#  '필요',
#  '참여',
#  '가족',
#  '상담',
#  '도움',
#  '정책',
#  '필요',
#  '청년',
#  '일자리',
#  '비슷',
#  '취미',
#  '생활',
#  '활동',
#  '지원',
#  '심리',
#  '청년',
#  '경제',
#  '지원',
#  '기회',
#  '제공',
#  '필요',
#  '청년',
#  '가족',
#  '상담',
#  '비슷',
#  '가족',
#  '필요',
#  '정책',
#  '필요',
#  '정책',
#  '심리',
#  '지원',
#  '청년',
#  '참여',
#  '정책',
#  '방법',
#  '고립',
#  '은둔',
#  '청년',
#  '가족',
#  '중요',
#  '가족',
#  '교육',
#  '방법',
#  '정책',
#  '아요',
#  '적극',
#  '홍보',
#  '활동',
#  '필요',
#  '청년',
#  '다양',
#  '중요',
#  '지원금',
#  '취업',
#  '취업',
#  '고립',
#  '청년',
#  '신청',
#  '경제',
#  '다양',
#  '일자리',
#  '비슷',
#  '중요',
#  '운동',
#  '중요',
#  '다양',
#  '생활',
#  '지원',
#  '취미',
#  '생활',
#  '지원',
#  '정책',
#  '친구',
#  '필요',
#  '관심',
#  '필요',
#  '상담',
#  '지원',
#  '프로그램',
#  '생활',
#  '프로그램',
#  '연계',
#  '필요',
#  '지원',
#  '프로그램',
#  '홍보',
#  '홍보',
#  '활동',
#  '참여',
#  '기회',
#  '제공',
#  '금전',
#  '도움',
#  '경제',
#  '지원',
#  '지원',
#  '지원',
#  '지원',
#  '마음',
#  '신청',
#  '도움',
#  '돈',
#  '경제',
#  '지원',
#  '가장',
#  '중요',
#  '경제',
#  '지원',
#  '상담',
#  ...]

# %%
df.to_csv('/content/drive/MyDrive/파이널 프로젝트/data/의견사항 분석.csv')

# %% [markdown]
# ## 사용자 사전 추가 방법

# %%
from konlpy.tag import Mecab
text = "코랩 비대면 플로깅"

tokenizer = Mecab()
tokenizer.pos(text)
# Out:
# [('코랩', 'NNP'), ('비대면', 'NNP'), ('플', 'NNG'), ('로', 'JKB'), ('깅', 'UNKNOWN')]

# %%
cd /content
# Out:
# /content

# %%
with open("../tmp/mecab-ko-dic-2.1.1-20180720/user-dic/nnp.csv", 'r', encoding='utf-8') as f:
  file_data = f.readlines()

# %%
file_data
# Out:
# ['코랩,,,,NNP,*,T,코랩,*,*,*,*,*\n',
#  '비대면,,,,NNP,*,T,비대면,*,*,*,*,*\n',
#  '경제활동,,,,NNP,*,T,경제활동,*,*,*,*,*\n',
#  '자기개발활동,,,,NNP,*,T,자기개발활동,*,*,*,*,*\n',
#  '은둔청년,,,,NNP,*,T,은둔청년,*,*,*,*,*\n',
#  '은둔생활플로깅,,,,NNP,*,T,은둔생활플로깅,*,*,*,*,*\n',
#  '불안정자,,,,NNP,*,F,불안정자,*,*,*,*,*\n',
#  '적극적,,,,NNP,*,T,적극적,*,*,*,*,*\n',
#  '임대주택,,,,NNP,*,T,임대주택,*,*,*,*,*\n',
#  '취업준비생,,,,NNP,*,T,취업준비생,*,*,*,*,*\n',
#  '푸른고래,,,,NNP,*,T,푸른고래,*,*,*,*,*\n',
#  '리커버리,,,,NNP,*,F,리커버리,*,*,*,*,*\n',
#  '모임식사,,,,NNP,*,F,모임식사,*,*,*,*,*\n',
#  '걷기,,,,NNP,*,F,걷기,*,*,*,*,*\n',
#  '소규모,,,,NNP,*,F,소규모,*,*,*,*,*\n',
#  '자살예방대책,,,,NNP,*,T,자살예방대책,*,*,*,*,*\n',
#  '장기적,,,,NNP,*,T,장기적,*,*,*,*,*\n',
#  '경제적,,,,NNP,*,T,경제적,*,*,*,*,*\n',
#  '레크레이션,,,,NNP,*,T,레크레이션,*,*,*,*,*\n',
#  '지속적,,,,NNP,*,T,지속적,*,*,*,*,*\n',
#  '심리적,,,,NNP,*,T,심리적,*,*,*,*,*\n',
#  '의지,,,,NNP,*,F,의지,*,*,*,*,*\n',
#  '정신적,,,,NNP,*,T,정신적,*,*,*,*,*\n',
#  '진정성,,,,NNP,*,T,진정성,*,*,*,*,*\n',
#  '금전적,,,,NNP,*,T,금전적,*,*,*,*,*\n',
#  '은둔,,,,NNP,*,T,은둔,*,*,*,*,*\n',
#  '실용성,,,,NNP,*,T,실용성,*,*,*,*,*\n',
#  '자기개발,,,,NNP,*,T,자기개발,*,*,*,*,*\n',
#  '봉사활동,,,,NNP,*,T,봉사활동,*,*,*,*,*\n',
#  '고립청년,,,,NNP,*,T,고립청년,*,*,*,*,*\n',
#  '사후관리,,,,NNP,*,F,사후관리,*,*,*,*,*\n']

# %%
# !pip install jamo
# Out:
# Requirement already satisfied: jamo in /usr/local/lib/python3.10/dist-packages (0.4.1)

# %%
from jamo import h2j, j2hcj

def get_jongsung_TF(sample_text):
  sample_text_list = list(sample_text)
  last_word = sample_text_list[-1]
  last_word_jamo_list = list(j2hcj(h2j(last_word)))
  last_jamo = last_word_jamo_list[-1]

  jongsung_TF = "T"

  if last_jamo in ['ㅏ', 'ㅑ', 'ㅓ', 'ㅕ', 'ㅗ', 'ㅛ', 'ㅜ', 'ㅠ', 'ㅡ', 'ㅣ', 'ㅘ', 'ㅚ', 'ㅙ', 'ㅝ', 'ㅞ', 'ㅢ', 'ㅐ,ㅔ', 'ㅟ', 'ㅖ', 'ㅒ']:
    jongsung_TF = "F"

  return jongsung_TF

# %%
word_list = ['코랩', '비대면','경제활동', '자기개발활동', '은둔청년', '은둔생활', '플로깅','불안정자', '적극적', '임대주택', '취업준비생', '푸른고래', '리커버리', '모임식사', '걷기', '소규모', '자살예방대책', '장기적', '경제적', '레크레이션', '지속적', '심리적', '의지', '정신적', '진정성', '금전적', '은둔', '실용성', '자기개발', '봉사활동', '고립청년', '사후관리' ]

file_data = []

for word in word_list:
  jongsung_TF = get_jongsung_TF(word)
  line = '{},,,,NNP,*,{},{},*,*,*,*,*\n'.format(word, jongsung_TF, word)
  file_data.append(line)

with open("../tmp/mecab-ko-dic-2.1.1-20180720/user-dic/nnp.csv", 'w', encoding='utf-8') as f:
  for line in file_data:
    f.write(line)

# %%
with open("../tmp/mecab-ko-dic-2.1.1-20180720/user-dic/nnp.csv", 'r', encoding='utf-8') as f:
  file_data = f.readlines()

file_data
# Out:
# ['코랩,,,,NNP,*,T,코랩,*,*,*,*,*\n',
#  '비대면,,,,NNP,*,T,비대면,*,*,*,*,*\n',
#  '경제활동,,,,NNP,*,T,경제활동,*,*,*,*,*\n',
#  '자기개발활동,,,,NNP,*,T,자기개발활동,*,*,*,*,*\n',
#  '은둔청년,,,,NNP,*,T,은둔청년,*,*,*,*,*\n',
#  '은둔생활,,,,NNP,*,T,은둔생활,*,*,*,*,*\n',
#  '플로깅,,,,NNP,*,T,플로깅,*,*,*,*,*\n',
#  '불안정자,,,,NNP,*,F,불안정자,*,*,*,*,*\n',
#  '적극적,,,,NNP,*,T,적극적,*,*,*,*,*\n',
#  '임대주택,,,,NNP,*,T,임대주택,*,*,*,*,*\n',
#  '취업준비생,,,,NNP,*,T,취업준비생,*,*,*,*,*\n',
#  '푸른고래,,,,NNP,*,T,푸른고래,*,*,*,*,*\n',
#  '리커버리,,,,NNP,*,F,리커버리,*,*,*,*,*\n',
#  '모임식사,,,,NNP,*,F,모임식사,*,*,*,*,*\n',
#  '걷기,,,,NNP,*,F,걷기,*,*,*,*,*\n',
#  '소규모,,,,NNP,*,F,소규모,*,*,*,*,*\n',
#  '자살예방대책,,,,NNP,*,T,자살예방대책,*,*,*,*,*\n',
#  '장기적,,,,NNP,*,T,장기적,*,*,*,*,*\n',
#  '경제적,,,,NNP,*,T,경제적,*,*,*,*,*\n',
#  '레크레이션,,,,NNP,*,T,레크레이션,*,*,*,*,*\n',
#  '지속적,,,,NNP,*,T,지속적,*,*,*,*,*\n',
#  '심리적,,,,NNP,*,T,심리적,*,*,*,*,*\n',
#  '의지,,,,NNP,*,F,의지,*,*,*,*,*\n',
#  '정신적,,,,NNP,*,T,정신적,*,*,*,*,*\n',
#  '진정성,,,,NNP,*,T,진정성,*,*,*,*,*\n',
#  '금전적,,,,NNP,*,T,금전적,*,*,*,*,*\n',
#  '은둔,,,,NNP,*,T,은둔,*,*,*,*,*\n',
#  '실용성,,,,NNP,*,T,실용성,*,*,*,*,*\n',
#  '자기개발,,,,NNP,*,T,자기개발,*,*,*,*,*\n',
#  '봉사활동,,,,NNP,*,T,봉사활동,*,*,*,*,*\n',
#  '고립청년,,,,NNP,*,T,고립청년,*,*,*,*,*\n',
#  '사후관리,,,,NNP,*,F,사후관리,*,*,*,*,*\n']

# %%
# !bash ../tmp/mecab-ko-dic-2.1.1-20180720/tools/add-userdic.sh
# Out:
# generating userdic...
# nnp.csv
# /tmp/mecab-ko-dic-2.1.1-20180720/tools/../model.def is not a binary model. reopen it as text mode...
# reading /tmp/mecab-ko-dic-2.1.1-20180720/tools/../user-dic/nnp.csv ...
# done!
# person.csv
# /tmp/mecab-ko-dic-2.1.1-20180720/tools/../model.def is not a binary model. reopen it as text mode...
# reading /tmp/mecab-ko-dic-2.1.1-20180720/tools/../user-dic/person.csv ...
# done!
# place.csv
# /tmp/mecab-ko-dic-2.1.1-20180720/tools/../model.def is not a binary model. reopen it as text mode...
# reading /tmp/mecab-ko-dic-2.1.1-20180720/tools/../user-dic/place.csv ...
# done!
# test -z "model.bin matrix.bin char.bin sys.dic unk.dic" || rm -f model.bin matrix.bin char.bin sys.dic unk.dic
# /usr/local/libexec/mecab/mecab-dict-index -d . -o . -f UTF-8 -t UTF-8
# reading ./unk.def ... 13
# emitting double-array: 100% |###########################################|
# reading ./NR.csv ... 482
# reading ./VCN.csv ... 7
# reading ./XSV.csv ... 23
# reading ./Hanja.csv ... 125750
# reading ./EC.csv ... 2547
# reading ./user-place.csv ... 2
# reading ./Wikipedia.csv ... 36762
# reading ./CoinedWord.csv ... 148
# reading ./ETM.csv ... 133
# reading ./VX.csv ... 125
# reading ./ETN.csv ... 14
# reading ./user-nnp.csv ... 32
# reading ./Preanalysis.csv ... 5
# reading ./J.csv ... 416
# reading ./Symbol.csv ... 16
# reading ./XSN.csv ... 124
# reading ./Person-actor.csv ... 99230
# reading ./VCP.csv ... 9
# reading ./Person.csv ... 196459
# reading ./Group.csv ... 3176
# reading ./MM.csv ... 453
# reading ./user-person.csv ... 1
# reading ./Place-station.csv ... 1145
# reading ./MAG.csv ... 14242
# reading ./XR.csv ... 3637
# reading ./NNB.csv ... 140
# reading ./NNBC.csv ... 677
# reading ./VV.csv ... 7331
# reading ./Foreign.csv ... 11690
# reading ./Place-address.csv ... 19301
# reading ./Place.csv ... 30303
# reading ./MAJ.csv ... 240
# reading ./NNP.csv ... 2371
# reading ./VA.csv ... 2360
# reading ./Inflect.csv ... 44820
# reading ./EP.csv ... 51
# reading ./EF.csv ... 1820
# reading ./NorthKorea.csv ... 3
# reading ./NP.csv ... 342
# reading ./NNG.csv ... 208524
# reading ./IC.csv ... 1305
# reading ./XPN.csv ... 83
# reading ./XSA.csv ... 19
# emitting double-array: 100% |###########################################|
# reading ./matrix.def ... 3822x2693
# emitting matrix      : 100% |###########################################|
#
# done!
# echo To enable dictionary, rewrite /usr/local/etc/mecabrc as \"dicdir = /usr/local/lib/mecab/dic/mecab-ko-dic\"
# To enable dictionary, rewrite /usr/local/etc/mecabrc as "dicdir = /usr/local/lib/mecab/dic/mecab-ko-dic"

# %%
cd /tmp/mecab-ko-dic-2.1.1-20180720
# Out:
# /tmp/mecab-ko-dic-2.1.1-20180720

# %%
pwd
# Out:
# '/tmp/mecab-ko-dic-2.1.1-20180720'

# %%
# !make install
# Out:
# make[1]: Entering directory '/tmp/mecab-ko-dic-2.1.1-20180720'
# make[1]: Nothing to be done for 'install-exec-am'.
#  /usr/bin/mkdir -p '/usr/local/lib/mecab/dic/mecab-ko-dic'
#  /usr/bin/install -c -m 644 model.bin matrix.bin char.bin sys.dic unk.dic left-id.def right-id.def rewrite.def pos-id.def dicrc '/usr/local/lib/mecab/dic/mecab-ko-dic'
# make[1]: Leaving directory '/tmp/mecab-ko-dic-2.1.1-20180720'

# %%
from konlpy.tag import Mecab
text = "코랩 비대면 플로깅"

tokenizer = Mecab()
tokenizer.pos(text)
# Out:
# [('코랩', 'NNP'), ('비대면', 'NNP'), ('플로깅', 'NNP')]
